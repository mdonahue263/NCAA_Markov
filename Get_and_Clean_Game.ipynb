# %%
import requests
import json
import pandas as pd
import numpy as np
# from tensorflow import keras

# %%
def pull_game(game_id):
    """
    Use Requests to hit hidden API endpoint on NCAA for play-by-play
    Args:
        game_id: INT or STR, 7 digits as far as I can tell
        smallest seems to be 6197002, starting this season
        6196001 seems to still be D1 mens bball but in the future??
        Need to see what happens when we try to ping A) future games and B)non basketball
        6195001 is a hockey game, see what happens there
        Ice Hockey is mentioned in ['meta']['title'], but basketball does not do that
        Trying soccer - 6191603
        Same conclusion with soccer. This will be annoying but might be worth checking if all other sports do that
        No - lacross has exact same title as bball. We can get past this by checking all the text for a buzzword
        
        
    
    """
    global r
    url = "https://data.ncaa.com/casablanca/game/{}/pbp.json".format(str(game_id))
    r = requests.get(url)
    #check if "Layup" exists in the content otherwise fail
    cont = r.content
    
    if ('Layup' not in str(cont)) and ('layup' not in str(cont)) and ('LAYUP' not in str(cont)):
        raise Exception('This may be the wrong sport')
    
    
    
    json_copy = json.loads(r.content)
    
    if json_copy == {'Message': 'Object not found.'}:
        raise Exception("Invalid game_id or future game_id")
    
    #pull date
    date=json_copy['updatedTimestamp']
    
    #pull data from json object
    meta_info = json_copy['meta']['teams']
    
    game=json_copy['periods']
    
    #don't yet know how to handle overtime
    if len(game) != 2:
        raise ValueError
    
    first_half=game[0]
    second_half=game[1]
    
    #Initialize empty dataframe
    box_score=pd.DataFrame()
    
    #scores will be 0 until scoring_started is True
    scoring_started=False
    
    #iterate through first_half states
    for item in first_half['playStats']:
        score=item['score']
        time=item['time']
        v_text=item['visitorText']
        h_text=item['homeText']
        
        #if score field is blank, either 0-0 or same as previous score
        if (len(score) == 0):
            if (scoring_started==False):
                home_score=0
                away_score=0
            else:
                #no code necessary here but for show:
                home_score=home_score
                away_score=away_score
                
        #otherwise, it is in the format "AWAY-HOME"
        elif len(score) != 0:
            scoring_started=True
            away_score, home_score = score.split('-')
            away_score=int(away_score)
            home_score=int(home_score)
            
        half=1

        #create row for state
        current_state = pd.DataFrame({'Period':half,
                                      'Time':time,
                                       'Away':away_score,
                                      'Home':home_score,
                                  'Home_Text':h_text,
                                  'Away_Text':v_text},index=[0])
        box_score=pd.concat([box_score,current_state])
        
        #same iterations but no need for "first Score" logic
    for item in second_half['playStats']:
        score=item['score']
        time=item['time']
        v_text=item['visitorText']
        h_text=item['homeText']
        if len(score) == 0:
                home_score=home_score
                away_score=away_score
        else:
            scoring_started=True
            away_score, home_score = score.split('-')
            away_score=int(away_score)
            home_score=int(home_score)
            
        half=2

        current_state = pd.DataFrame({'Period':half,
                                      'Time':time,
                                       'Away':away_score,
                                      'Home':home_score,
                                  'Home_Text':h_text,
                                  'Away_Text':v_text},index=[0])
        box_score=pd.concat([box_score,current_state])
        
        
    box_score=box_score.reset_index(drop=True)
    return box_score

# %%
game1=pull_game(6200082)

# %%
game1
# Out:
#      Period   Time  Away  Home                                Home_Text  \
# 0         1  19:46     0     0   Layup MISSED by CU's Kalkbrenner, Ryan
# 1         1  19:43     0     0
# 2         1  19:31     0     0
# 3         1  19:27     0     0  CU Defensive REBOUND by Alexander, Trey
# 4         1  19:22     0     0             Foul on CU's Alexander, Trey
# ..      ...    ...   ...   ...                                      ...
# 420       2  00:05    99    98  Free Throw GOOD by CU's Alexander, Trey
# 421       2  00:05    99    98    Subbing out for CU - Ashworth, Steven
# 422       2  00:05    99    98        Subbing in for CU - Miller, Mason
# 423       2  00:00    99    98
# 424       2  00:00    99    98         CU Steal by Farabello, Francisco
#
#                                        Away_Text
# 0
# 1    Butler Defensive REBOUND by Telfort, Jahmyl
# 2    3 Pointer MISSED by Butler's Brooks, Pierre
# 3
# 4
# ..                                           ...
# 420
# 421
# 422
# 423             Butler Turnover by Moore, Landon
# 424
#
# [425 rows x 6 columns]

# %%
game2=pull_game(6200081)

# %%
game2
# Out:
#      Period   Time  Away  Home                                     Home_Text  \
# 0         1  19:38     0     0
# 1         1  19:36     0     0              Nevada Defensive REBOUND by team
# 2         1  19:23     0     0
# 3         1  19:06     0     3  3 Pointer GOOD by Nevada's Blackshear, Kenan
# 4         1  19:06     0     3                 Nevada Assist by Coleman, Tre
# ..      ...    ...   ...   ...                                           ...
# 499       2  00:48    60    90    Free Throw GOOD by Nevada's Rolison, Tyler
# 500       2  00:29    60    90
# 501       2  00:24    60    90
# 502       2  00:24    60    90
# 503       2  00:22    60    90  Nevada Defensive REBOUND by Mcintosh, Hunter
#
#                                     Away_Text
# 0      Jumper MISSED by SJSU's Gorener, Tibet
# 1
# 2              Foul on SJSU's Diongue, Adrame
# 3
# 4
# ..                                        ...
# 499
# 500     Layup MISSED by SJSU's Davis, Latrell
# 501  SJSU Offensive REBOUND by Humer, William
# 502     Layup MISSED by SJSU's Humer, William
# 503
#
# [504 rows x 6 columns]

# %%
json.loads(r.content)['periods'][0]
# Out:
# {'periodNumber': '1',
#  'periodDisplay': '1st Half',
#  'playStats': [{'score': '',
#    'time': '19:38',
#    'visitorText': "Jumper MISSED by SJSU's Gorener, Tibet",
#    'homeText': ''},
#   {'score': '',
#    'time': '19:36',
#    'visitorText': '',
#    'homeText': 'Nevada Defensive REBOUND by team'},
#   {'score': '',
#    'time': '19:23',
#    'visitorText': "Foul on SJSU's Diongue, Adrame",
#    'homeText': ''},
#   {'score': '0-3',
#    'time': '19:06',
#    'visitorText': '',
#    'homeText': "3 Pointer GOOD by Nevada's Blackshear, Kenan"},
#   {'score': '',
#    'time': '19:06',
#    'visitorText': '',
#    'homeText': 'Nevada Assist by Coleman, Tre'},
#   {'score': '3-3',
#    'time': '18:39',
#    'visitorText': "3 Pointer GOOD by SJSU's Anderson, Trey",
#    'homeText': ''},
#   {'score': '',
#    'time': '18:39',
#    'visitorText': 'SJSU Assist by Amey jr., Myron',
#    'homeText': ''},
#   {'score': '3-5',
#    'time': '18:26',
#    'visitorText': '',
#    'homeText': "Jumper GOOD by Nevada's Blackshear, Kenan"},
#   {'score': '6-5',
#    'time': '18:09',
#    'visitorText': "3 Pointer GOOD by SJSU's Cardenas, Alvaro",
#    'homeText': ''},
#   {'score': '6-8',
#    'time': '17:50',
#    'visitorText': '',
#    'homeText': "3 Pointer GOOD by Nevada's Davidson, Nick"},
#   {'score': '',
#    'time': '17:50',
#    'visitorText': '',
#    'homeText': 'Nevada Assist by Blackshear, Kenan'},
#   {'score': '',
#    'time': '17:35',
#    'visitorText': 'SJSU Turnover by Amey jr., Myron',
#    'homeText': ''},
#   {'score': '',
#    'time': '17:21',
#    'visitorText': '',
#    'homeText': "Jumper MISSED by Nevada's Lucas, Jarod"},
#   {'score': '',
#    'time': '17:19',
#    'visitorText': '',
#    'homeText': 'Nevada Offensive REBOUND by Davidson, Nick'},
#   {'score': '',
#    'time': '17:19',
#    'visitorText': "Foul on SJSU's Anderson, Trey",
#    'homeText': ''},
#   {'score': '',
#    'time': '17:19',
#    'visitorText': 'Subbing out for SJSU - Diongue, Adrame',
#    'homeText': ''},
#   {'score': '',
#    'time': '17:19',
#    'visitorText': 'Subbing in for SJSU - Seixas, Diogo',
#    'homeText': ''},
#   {'score': '6-10',
#    'time': '17:12',
#    'visitorText': '',
#    'homeText': "Jumper GOOD by Nevada's Lucas, Jarod"},
#   {'score': '',
#    'time': '17:12',
#    'visitorText': '',
#    'homeText': 'Nevada Assist by Coleman, Tre'},
#   {'score': '',
#    'time': '16:56',
#    'visitorText': "3 Pointer MISSED by SJSU's Gorener, Tibet",
#    'homeText': ''},
#   {'score': '',
#    'time': '16:55',
#    'visitorText': '',
#    'homeText': 'Nevada Defensive REBOUND by team'},
#   {'score': '',
#    'time': '16:45',
#    'visitorText': '',
#    'homeText': 'Nevada Turnover by Blackshear, Kenan'},
#   {'score': '',
#    'time': '16:45',
#    'visitorText': 'SJSU Steal by Seixas, Diogo',
#    'homeText': ''},
#   {'score': '',
#    'time': '16:35',
#    'visitorText': "3 Pointer MISSED by SJSU's Amey jr., Myron",
#    'homeText': ''},
#   {'score': '',
#    'time': '16:32',
#    'visitorText': '',
#    'homeText': 'Nevada Defensive REBOUND by Coleman, Tre'},
#   {'score': '',
#    'time': '16:25',
#    'visitorText': '',
#    'homeText': "Jumper MISSED by Nevada's Lucas, Jarod"},
#   {'score': '',
#    'time': '16:23',
#    'visitorText': '',
#    'homeText': 'Nevada Offensive REBOUND by Davidson, Nick'},
#   {'score': '',
#    'time': '16:23',
#    'visitorText': "Foul on SJSU's Amey jr., Myron",
#    'homeText': ''},
#   {'score': '',
#    'time': '16:23',
#    'visitorText': '',
#    'homeText': "Free Throw MISSED by Nevada's Davidson, Nick"},
#   {'score': '',
#    'time': '16:23',
#    'visitorText': '',
#    'homeText': 'Nevada gets a REBOUND from a dead ball.'},
#   {'score': '',
#    'time': '16:23',
#    'visitorText': '',
#    'homeText': 'Subbing out for Nevada - Hymes, K.j.'},
#   {'score': '',
#    'time': '16:23',
#    'visitorText': '',
#    'homeText': 'Subbing in for Nevada - Foster, Daniel'},
#   {'score': '',
#    'time': '16:23',
#    'visitorText': 'Subbing out for SJSU - Anderson, Trey',
#    'homeText': ''},
#   {'score': '',
#    'time': '16:23',
#    'visitorText': 'Subbing in for SJSU - Anderson, Garrett',
#    'homeText': ''},
#   {'score': '6-11',
#    'time': '16:23',
#    'visitorText': '',
#    'homeText': "Free Throw GOOD by Nevada's Davidson, Nick"},
#   {'score': '',
#    'time': '16:08',
#    'visitorText': "Jumper MISSED by SJSU's Cardenas, Alvaro",
#    'homeText': ''},
#   {'score': '',
#    'time': '16:04',
#    'visitorText': 'SJSU Offensive REBOUND by Cardenas, Alvaro',
#    'homeText': ''},
#   {'score': '',
#    'time': '16:01',
#    'visitorText': "Jumper MISSED by SJSU's Gorener, Tibet",
#    'homeText': ''},
#   {'score': '',
#    'time': '15:56',
#    'visitorText': 'SJSU Offensive REBOUND by Gorener, Tibet',
#    'homeText': ''},
#   {'score': '',
#    'time': '15:56',
#    'visitorText': "Layup MISSED by SJSU's Gorener, Tibet",
#    'homeText': ''},
#   {'score': '',
#    'time': '15:55',
#    'visitorText': '',
#    'homeText': 'Nevada Defensive REBOUND by Davidson, Nick'},
#   {'score': '',
#    'time': '15:39',
#    'visitorText': '',
#    'homeText': "Layup MISSED by Nevada's Coleman, Tre"},
#   {'score': '',
#    'time': '15:35',
#    'visitorText': '',
#    'homeText': 'Nevada Offensive REBOUND by team'},
#   {'score': '',
#    'time': '15:35',
#    'visitorText': 'Media timeout',
#    'homeText': ''},
#   {'score': '6-14',
#    'time': '15:28',
#    'visitorText': '',
#    'homeText': "3 Pointer GOOD by Nevada's Lucas, Jarod"},
#   {'score': '',
#    'time': '15:28',
#    'visitorText': '',
#    'homeText': 'Nevada Assist by Blackshear, Kenan'},
#   {'score': '',
#    'time': '15:13',
#    'visitorText': 'SJSU Turnover by Seixas, Diogo',
#    'homeText': ''},
#   {'score': '',
#    'time': '15:13',
#    'visitorText': '',
#    'homeText': 'Nevada Steal by Coleman, Tre'},
#   {'score': '',
#    'time': '15:13',
#    'visitorText': 'Subbing out for SJSU - Seixas, Diogo',
#    'homeText': ''},
#   {'score': '',
#    'time': '15:13',
#    'visitorText': 'Subbing in for SJSU - Wise, Christian',
#    'homeText': ''},
#   {'score': '',
#    'time': '15:02',
#    'visitorText': '',
#    'homeText': "3 Pointer MISSED by Nevada's Coleman, Tre"},
#   {'score': '',
#    'time': '14:58',
#    'visitorText': 'SJSU Defensive REBOUND by Cardenas, Alvaro',
#    'homeText': ''},
#   {'score': '',
#    'time': '14:49',
#    'visitorText': '',
#    'homeText': "Foul on Nevada's Blackshear, Kenan"},
#   {'score': '',
#    'time': '14:49',
#    'visitorText': '',
#    'homeText': 'Subbing out for Nevada - Blackshear, Kenan'},
#   {'score': '',
#    'time': '14:49',
#    'visitorText': '',
#    'homeText': 'Subbing in for Nevada - Mcintosh, Hunter'},
#   {'score': '',
#    'time': '14:49',
#    'visitorText': 'Subbing out for SJSU - Gorener, Tibet',
#    'homeText': ''},
#   {'score': '',
#    'time': '14:49',
#    'visitorText': 'Subbing in for SJSU - Anderson, Trey',
#    'homeText': ''},
#   {'score': '8-14',
#    'time': '14:37',
#    'visitorText': "Jumper GOOD by SJSU's Amey jr., Myron",
#    'homeText': ''},
#   {'score': '',
#    'time': '14:15',
#    'visitorText': '',
#    'homeText': 'Nevada Turnover by Lucas, Jarod'},
#   {'score': '',
#    'time': '14:15',
#    'visitorText': 'SJSU Steal by Cardenas, Alvaro',
#    'homeText': ''},
#   {'score': '',
#    'time': '14:06',
#    'visitorText': 'SJSU Turnover by Wise, Christian',
#    'homeText': ''},
#   {'score': '',
#    'time': '14:06',
#    'visitorText': '',
#    'homeText': 'Nevada Steal by Foster, Daniel'},
#   {'score': '8-17',
#    'time': '13:59',
#    'visitorText': '',
#    'homeText': "3 Pointer GOOD by Nevada's Lucas, Jarod"},
#   {'score': '',
#    'time': '13:59',
#    'visitorText': '',
#    'homeText': 'Nevada Assist by Mcintosh, Hunter'},
#   {'score': '',
#    'time': '13:58',
#    'visitorText': "Foul on SJSU's Anderson, Garrett",
#    'homeText': ''},
#   {'score': '',
#    'time': '13:58',
#    'visitorText': 'Subbing out for SJSU - Anderson, Garrett',
#    'homeText': ''},
#   {'score': '',
#    'time': '13:58',
#    'visitorText': 'Subbing in for SJSU - Davis, Latrell',
#    'homeText': ''},
#   {'score': '8-18',
#    'time': '13:58',
#    'visitorText': '',
#    'homeText': "Free Throw GOOD by Nevada's Lucas, Jarod"},
#   {'score': '',
#    'time': '13:58',
#    'visitorText': '',
#    'homeText': 'Subbing out for Nevada - Coleman, Tre'},
#   {'score': '',
#    'time': '13:58',
#    'visitorText': '',
#    'homeText': 'Subbing in for Nevada - Pope, Tylan'},
#   {'score': '11-18',
#    'time': '13:45',
#    'visitorText': "3 Pointer GOOD by SJSU's Amey jr., Myron",
#    'homeText': ''},
#   {'score': '',
#    'time': '13:45',
#    'visitorText': 'SJSU Assist by Anderson, Trey',
#    'homeText': ''},
#   {'score': '',
#    'time': '13:33',
#    'visitorText': '',
#    'homeText': "Jumper MISSED by Nevada's Lucas, Jarod"},
#   {'score': '',
#    'time': '13:28',
#    'visitorText': '',
#    'homeText': 'Nevada Offensive REBOUND by Pope, Tylan'},
#   {'score': '',
#    'time': '13:18',
#    'visitorText': "Foul on SJSU's Anderson, Trey",
#    'homeText': ''},
#   {'score': '',
#    'time': '13:18',
#    'visitorText': 'Subbing out for SJSU - Anderson, Trey',
#    'homeText': ''},
#   {'score': '',
#    'time': '13:18',
#    'visitorText': 'Subbing in for SJSU - Gorener, Tibet',
#    'homeText': ''},
#   {'score': '11-20',
#    'time': '13:16',
#    'visitorText': '',
#    'homeText': "Layup GOOD by Nevada's Davidson, Nick"},
#   {'score': '',
#    'time': '13:16',
#    'visitorText': '',
#    'homeText': 'Nevada Assist by Mcintosh, Hunter'},
#   {'score': '',
#    'time': '13:00',
#    'visitorText': "3 Pointer MISSED by SJSU's Gorener, Tibet",
#    'homeText': ''},
#   {'score': '',
#    'time': '12:56',
#    'visitorText': '',
#    'homeText': 'Nevada Defensive REBOUND by Mcintosh, Hunter'},
#   {'score': '',
#    'time': '12:45',
#    'visitorText': "Foul on SJSU's Wise, Christian",
#    'homeText': ''},
#   {'score': '11-21',
#    'time': '12:45',
#    'visitorText': '',
#    'homeText': "Free Throw GOOD by Nevada's Davidson, Nick"},
#   {'score': '',
#    'time': '12:45',
#    'visitorText': 'Subbing out for SJSU - Wise, Christian',
#    'homeText': ''},
#   {'score': '',
#    'time': '12:45',
#    'visitorText': 'Subbing in for SJSU - Diongue, Adrame',
#    'homeText': ''},
#   {'score': '',
#    'time': '12:45',
#    'visitorText': '',
#    'homeText': 'Subbing out for Nevada - Lucas, Jarod'},
#   {'score': '',
#    'time': '12:45',
#    'visitorText': '',
#    'homeText': 'Subbing in for Nevada - Blackshear, Kenan'},
#   {'score': '11-22',
#    'time': '12:45',
#    'visitorText': '',
#    'homeText': "Free Throw GOOD by Nevada's Davidson, Nick"},
#   {'score': '',
#    'time': '12:45',
#    'visitorText': '',
#    'homeText': 'Subbing out for Nevada - Davidson, Nick'},
#   {'score': '',
#    'time': '12:45',
#    'visitorText': '',
#    'homeText': 'Subbing in for Nevada - Hymes, K.j.'},
#   {'score': '',
#    'time': '12:25',
#    'visitorText': '',
#    'homeText': "Foul on Nevada's Foster, Daniel"},
#   {'score': '',
#    'time': '12:18',
#    'visitorText': "3 Pointer MISSED by SJSU's Amey jr., Myron",
#    'homeText': ''},
#   {'score': '',
#    'time': '12:14',
#    'visitorText': '',
#    'homeText': 'Nevada Defensive REBOUND by Foster, Daniel'},
#   {'score': '',
#    'time': '11:57',
#    'visitorText': "Foul on SJSU's Cardenas, Alvaro",
#    'homeText': ''},
#   {'score': '',
#    'time': '11:57',
#    'visitorText': 'Media timeout',
#    'homeText': ''},
#   {'score': '',
#    'time': '11:57',
#    'visitorText': 'Subbing out for SJSU - Amey jr., Myron',
#    'homeText': ''},
#   {'score': '',
#    'time': '11:57',
#    'visitorText': 'Subbing out for SJSU - Davis, Latrell',
#    'homeText': ''},
#   {'score': '',
#    'time': '11:57',
#    'visitorText': 'Subbing in for SJSU - Anderson, Garrett',
#    'homeText': ''},
#   {'score': '',
#    'time': '11:57',
#    'visitorText': 'Subbing in for SJSU - Mitchell jr., Rickey',
#    'homeText': ''},
#   {'score': '',
#    'time': '11:57',
#    'visitorText': '',
#    'homeText': "Free Throw MISSED by Nevada's Mcintosh, Hunter"},
#   {'score': '',
#    'time': '11:57',
#    'visitorText': '',
#    'homeText': 'Nevada gets a REBOUND from a dead ball.'},
#   {'score': '11-23',
#    'time': '11:57',
#    'visitorText': '',
#    'homeText': "Free Throw GOOD by Nevada's Mcintosh, Hunter"},
#   {'score': '',
#    'time': '11:43',
#    'visitorText': "Layup MISSED by SJSU's Diongue, Adrame",
#    'homeText': ''},
#   {'score': '',
#    'time': '11:39',
#    'visitorText': '',
#    'homeText': 'Nevada Defensive REBOUND by Mcintosh, Hunter'},
#   {'score': '',
#    'time': '11:26',
#    'visitorText': '',
#    'homeText': "3 Pointer MISSED by Nevada's Mcintosh, Hunter"},
#   {'score': '',
#    'time': '11:23',
#    'visitorText': 'SJSU Defensive REBOUND by Diongue, Adrame',
#    'homeText': ''},
#   {'score': '',
#    'time': '11:23',
#    'visitorText': '',
#    'homeText': "Foul on Nevada's Blackshear, Kenan"},
#   {'score': '',
#    'time': '10:53',
#    'visitorText': "3 Pointer MISSED by SJSU's Mitchell jr., Rickey",
#    'homeText': ''},
#   {'score': '',
#    'time': '10:48',
#    'visitorText': '',
#    'homeText': 'Nevada Defensive REBOUND by Blackshear, Kenan'},
#   {'score': '',
#    'time': '10:44',
#    'visitorText': "Foul on SJSU's Diongue, Adrame",
#    'homeText': ''},
#   {'score': '',
#    'time': '10:44',
#    'visitorText': '',
#    'homeText': "Free Throw MISSED by Nevada's Blackshear, Kenan"},
#   {'score': '',
#    'time': '10:44',
#    'visitorText': '',
#    'homeText': 'Nevada gets a REBOUND from a dead ball.'},
#   {'score': '',
#    'time': '10:44',
#    'visitorText': '',
#    'homeText': 'Subbing out for Nevada - Mcintosh, Hunter'},
#   {'score': '',
#    'time': '10:44',
#    'visitorText': '',
#    'homeText': 'Subbing out for Nevada - Foster, Daniel'},
#   {'score': '',
#    'time': '10:44',
#    'visitorText': '',
#    'homeText': 'Subbing in for Nevada - Lucas, Jarod'},
#   {'score': '',
#    'time': '10:44',
#    'visitorText': '',
#    'homeText': 'Subbing in for Nevada - Coleman, Tre'},
#   {'score': '',
#    'time': '10:44',
#    'visitorText': 'Subbing out for SJSU - Diongue, Adrame',
#    'homeText': ''},
#   {'score': '',
#    'time': '10:44',
#    'visitorText': 'Subbing out for SJSU - Cardenas, Alvaro',
#    'homeText': ''},
#   {'score': '',
#    'time': '10:44',
#    'visitorText': 'Subbing in for SJSU - Amey jr., Myron',
#    'homeText': ''},
#   {'score': '',
#    'time': '10:44',
#    'visitorText': 'Subbing in for SJSU - Seixas, Diogo',
#    'homeText': ''},
#   {'score': '11-24',
#    'time': '10:44',
#    'visitorText': '',
#    'homeText': "Free Throw GOOD by Nevada's Blackshear, Kenan"},
#   {'score': '',
#    'time': '10:44',
#    'visitorText': '',
#    'homeText': 'Subbing out for Nevada - Blackshear, Kenan'},
#   {'score': '',
#    'time': '10:44',
#    'visitorText': '',
#    'homeText': 'Subbing in for Nevada - Rolison, Tyler'},
#   {'score': '',
#    'time': '10:21',
#    'visitorText': 'SJSU Turnover by Amey jr., Myron',
#    'homeText': ''},
#   {'score': '',
#    'time': '10:21',
#    'visitorText': '',
#    'homeText': 'Nevada Steal by Rolison, Tyler'},
#   {'score': '',
#    'time': '10:08',
#    'visitorText': "Foul on SJSU's Mitchell jr., Rickey",
#    'homeText': ''},
#   {'score': '11-25',
#    'time': '10:08',
#    'visitorText': '',
#    'homeText': "Free Throw GOOD by Nevada's Rolison, Tyler"},
#   {'score': '11-26',
#    'time': '10:08',
#    'visitorText': '',
#    'homeText': "Free Throw GOOD by Nevada's Rolison, Tyler"},
#   {'score': '',
#    'time': '09:50',
#    'visitorText': 'SJSU Turnover by Amey jr., Myron',
#    'homeText': ''},
#   {'score': '',
#    'time': '09:36',
#    'visitorText': "Foul on SJSU's Seixas, Diogo",
#    'homeText': ''},
#   {'score': '11-27',
#    'time': '09:36',
#    'visitorText': '',
#    'homeText': "Free Throw GOOD by Nevada's Hymes, K.j."},
#   {'score': '',
#    'time': '09:36',
#    'visitorText': 'Subbing out for SJSU - Seixas, Diogo',
#    'homeText': ''},
#   {'score': '',
#    'time': '09:36',
#    'visitorText': 'Subbing in for SJSU - Humer, William',
#    'homeText': ''},
#   {'score': '',
#    'time': '09:35',
#    'visitorText': '',
#    'homeText': "Free Throw MISSED by Nevada's Hymes, K.j."},
#   {'score': '',
#    'time': '09:34',
#    'visitorText': 'SJSU Defensive REBOUND by Gorener, Tibet',
#    'homeText': ''},
#   {'score': '',
#    'time': '09:18',
#    'visitorText': "Layup MISSED by SJSU's Anderson, Garrett",
#    'homeText': ''},
#   {'score': '',
#    'time': '09:15',
#    'visitorText': '',
#    'homeText': 'Nevada Defensive REBOUND by Rolison, Tyler'},
#   {'score': '',
#    'time': '09:11',
#    'visitorText': '',
#    'homeText': "3 Pointer MISSED by Nevada's Lucas, Jarod"},
#   {'score': '',
#    'time': '09:07',
#    'visitorText': 'SJSU Defensive REBOUND by Mitchell jr., Rickey',
#    'homeText': ''},
#   {'score': '',
#    'time': '09:04',
#    'visitorText': 'SJSU Turnover by Humer, William',
#    'homeText': ''},
#   {'score': '',
#    'time': '08:53',
#    'visitorText': '',
#    'homeText': "Layup MISSED by Nevada's Coleman, Tre"},
#   {'score': '',
#    'time': '08:52',
#    'visitorText': 'SJSU Defensive REBOUND by Amey jr., Myron',
#    'homeText': ''},
#   {'score': '',
#    'time': '08:52',
#    'visitorText': '',
#    'homeText': "Foul on Nevada's Pope, Tylan"},
#   {'score': '',
#    'time': '08:52',
#    'visitorText': 'Subbing out for SJSU - Anderson, Garrett',
#    'homeText': ''},
#   {'score': '',
#    'time': '08:52',
#    'visitorText': 'Subbing out for SJSU - Mitchell jr., Rickey',
#    'homeText': ''},
#   {'score': '',
#    'time': '08:52',
#    'visitorText': 'Subbing in for SJSU - Cardenas, Alvaro',
#    'homeText': ''},
#   {'score': '',
#    'time': '08:52',
#    'visitorText': 'Subbing in for SJSU - Anderson, Trey',
#    'homeText': ''},
#   {'score': '',
#    'time': '08:36',
#    'visitorText': '',
#    'homeText': "Foul on Nevada's Rolison, Tyler"},
#   {'score': '',
#    'time': '08:36',
#    'visitorText': '',
#    'homeText': 'Subbing out for Nevada - Hymes, K.j.'},
#   {'score': '',
#    'time': '08:36',
#    'visitorText': '',
#    'homeText': 'Subbing in for Nevada - Davidson, Nick'},
#   {'score': '',
#    'time': '08:21',
#    'visitorText': "Jumper MISSED by SJSU's Cardenas, Alvaro",
#    'homeText': ''},
#   {'score': '',
#    'time': '08:18',
#    'visitorText': '',
#    'homeText': 'Nevada Defensive REBOUND by Davidson, Nick'},
#   {'score': '',
#    'time': '08:08',
#    'visitorText': "Foul on SJSU's Gorener, Tibet",
#    'homeText': ''},
#   {'score': '11-28',
#    'time': '08:08',
#    'visitorText': '',
#    'homeText': "Free Throw GOOD by Nevada's Pope, Tylan"},
#   {'score': '',
#    'time': '08:07',
#    'visitorText': '',
#    'homeText': "Free Throw MISSED by Nevada's Pope, Tylan"},
#   {'score': '',
#    'time': '08:05',
#    'visitorText': '',
#    'homeText': 'Nevada Offensive REBOUND by Davidson, Nick'},
#   {'score': '11-30',
#    'time': '08:02',
#    'visitorText': '',
#    'homeText': "Slam Dunk GOOD by Nevada's Pope, Tylan"},
#   {'score': '',
#    'time': '08:02',
#    'visitorText': '',
#    'homeText': 'Nevada Assist by Davidson, Nick'},
#   {'score': '',
#    'time': '07:58',
#    'visitorText': 'SJSU takes a 30-second time out.',
#    'homeText': ''},
#   {'score': '',
#    'time': '07:58',
#    'visitorText': 'Media timeout',
#    'homeText': ''},
#   {'score': '',
#    'time': '07:58',
#    'visitorText': 'Subbing out for SJSU - Humer, William',
#    'homeText': ''},
#   {'score': '',
#    'time': '07:58',
#    'visitorText': 'Subbing in for SJSU - Wise, Christian',
#    'homeText': ''},
#   {'score': '13-30',
#    'time': '07:37',
#    'visitorText': "Layup GOOD by SJSU's Amey jr., Myron",
#    'homeText': ''},
#   {'score': '13-33',
#    'time': '07:18',
#    'visitorText': '',
#    'homeText': "3 Pointer GOOD by Nevada's Rolison, Tyler"},
#   {'score': '',
#    'time': '07:18',
#    'visitorText': '',
#    'homeText': 'Nevada Assist by Pope, Tylan'},
#   {'score': '15-33',
#    'time': '07:00',
#    'visitorText': "Jumper GOOD by SJSU's Gorener, Tibet",
#    'homeText': ''},
#   {'score': '15-36',
#    'time': '06:35',
#    'visitorText': '',
#    'homeText': "3 Pointer GOOD by Nevada's Pope, Tylan"},
#   {'score': '',
#    'time': '06:35',
#    'visitorText': '',
#    'homeText': 'Nevada Assist by Lucas, Jarod'},
#   {'score': '',
#    'time': '06:14',
#    'visitorText': "3 Pointer MISSED by SJSU's Gorener, Tibet",
#    'homeText': ''},
#   {'score': '',
#    'time': '06:10',
#    'visitorText': '',
#    'homeText': 'Nevada Defensive REBOUND by Rolison, Tyler'},
#   {'score': '',
#    'time': '06:07',
#    'visitorText': "Foul on SJSU's Gorener, Tibet",
#    'homeText': ''},
#   {'score': '',
#    'time': '06:07',
#    'visitorText': '',
#    'homeText': "Free Throw MISSED by Nevada's Rolison, Tyler"},
#   {'score': '',
#    'time': '06:07',
#    'visitorText': '',
#    'homeText': 'Nevada gets a REBOUND from a dead ball.'},
#   {'score': '',
#    'time': '06:07',
#    'visitorText': '',
#    'homeText': 'Subbing out for Nevada - Pope, Tylan'},
#   {'score': '',
#    'time': '06:07',
#    'visitorText': '',
#    'homeText': 'Subbing in for Nevada - Foster, Daniel'},
#   {'score': '',
#    'time': '06:07',
#    'visitorText': 'Subbing out for SJSU - Gorener, Tibet',
#    'homeText': ''},
#   {'score': '',
#    'time': '06:07',
#    'visitorText': 'Subbing in for SJSU - Davis, Latrell',
#    'homeText': ''},
#   {'score': '15-37',
#    'time': '06:07',
#    'visitorText': '',
#    'homeText': "Free Throw GOOD by Nevada's Rolison, Tyler"},
#   {'score': '',
#    'time': '05:43',
#    'visitorText': "3 Pointer MISSED by SJSU's Anderson, Trey",
#    'homeText': ''},
#   {'score': '',
#    'time': '05:40',
#    'visitorText': '',
#    'homeText': 'Nevada Defensive REBOUND by Lucas, Jarod'},
#   {'score': '15-39',
#    'time': '05:28',
#    'visitorText': '',
#    'homeText': "Layup GOOD by Nevada's Davidson, Nick"},
#   {'score': '',
#    'time': '05:28',
#    'visitorText': '',
#    'homeText': 'Nevada Assist by Coleman, Tre'},
#   {'score': '17-39',
#    'time': '04:58',
#    'visitorText': "Jumper GOOD by SJSU's Amey jr., Myron",
#    'homeText': ''},
#   {'score': '',
#    'time': '04:58',
#    'visitorText': 'SJSU Assist by Davis, Latrell',
#    'homeText': ''},
#   {'score': '17-42',
#    'time': '04:33',
#    'visitorText': '',
#    'homeText': "3 Pointer GOOD by Nevada's Rolison, Tyler"},
#   {'score': '',
#    'time': '04:33',
#    'visitorText': '',
#    'homeText': 'Nevada Assist by Lucas, Jarod'},
#   {'score': '',
#    'time': '04:05',
#    'visitorText': "3 Pointer MISSED by SJSU's Anderson, Trey",
#    'homeText': ''},
#   {'score': '',
#    'time': '04:02',
#    'visitorText': '',
#    'homeText': 'Nevada Defensive REBOUND by Lucas, Jarod'},
#   {'score': '',
#    'time': '03:49',
#    'visitorText': '',
#    'homeText': "3 Pointer MISSED by Nevada's Coleman, Tre"},
#   {'score': '',
#    'time': '03:46',
#    'visitorText': '',
#    'homeText': 'Nevada Offensive REBOUND by Davidson, Nick'},
#   {'score': '17-44',
#    'time': '03:38',
#    'visitorText': '',
#    'homeText': "Slam Dunk GOOD by Nevada's Davidson, Nick"},
#   {'score': '',
#    'time': '03:38',
#    'visitorText': '',
#    'homeText': 'Nevada Assist by Foster, Daniel'},
#   {'score': '',
#    'time': '03:19',
#    'visitorText': "Jumper MISSED by SJSU's Anderson, Trey",
#    'homeText': ''},
#   {'score': '',
#    'time': '03:16',
#    'visitorText': '',
#    'homeText': 'Nevada Defensive REBOUND by Davidson, Nick'},
#   {'score': '',
#    'time': '03:09',
#    'visitorText': '',
#    'homeText': "Layup MISSED by Nevada's Rolison, Tyler"},
#   {'score': '',
#    'time': '03:05',
#    'visitorText': '',
#    'homeText': 'Nevada Offensive REBOUND by Foster, Daniel'},
#   {'score': '',
#    'time': '03:03',
#    'visitorText': '',
#    'homeText': "3 Pointer MISSED by Nevada's Coleman, Tre"},
#   {'score': '',
#    'time': '02:55',
#    'visitorText': 'SJSU Defensive REBOUND by Amey jr., Myron',
#    'homeText': ''},
#   {'score': '',
#    'time': '02:48',
#    'visitorText': "3 Pointer MISSED by SJSU's Amey jr., Myron",
#    'homeText': ''},
#   {'score': '',
#    'time': '02:46',
#    'visitorText': '',
#    'homeText': 'Nevada Defensive REBOUND by Foster, Daniel'},
#   {'score': '',
#    'time': '02:46',
#    'visitorText': "Foul on SJSU's Wise, Christian",
#    'homeText': ''},
#   {'score': '',
#    'time': '02:46',
#    'visitorText': 'Media timeout',
#    'homeText': ''},
#   {'score': '',
#    'time': '02:46',
#    'visitorText': '',
#    'homeText': 'Subbing out for Nevada - Rolison, Tyler'},
#   {'score': '',
#    'time': '02:46',
#    'visitorText': '',
#    'homeText': 'Subbing in for Nevada - Mcintosh, Hunter'},
#   {'score': '',
#    'time': '02:46',
#    'visitorText': 'Subbing out for SJSU - Anderson, Trey',
#    'homeText': ''},
#   {'score': '',
#    'time': '02:46',
#    'visitorText': 'Subbing out for SJSU - Wise, Christian',
#    'homeText': ''},
#   {'score': '',
#    'time': '02:46',
#    'visitorText': 'Subbing in for SJSU - Diongue, Adrame',
#    'homeText': ''},
#   {'score': '',
#    'time': '02:46',
#    'visitorText': 'Subbing in for SJSU - Seixas, Diogo',
#    'homeText': ''},
#   {'score': '17-45',
#    'time': '02:46',
#    'visitorText': '',
#    'homeText': "Free Throw GOOD by Nevada's Foster, Daniel"},
#   {'score': '17-46',
#    'time': '02:46',
#    'visitorText': '',
#    'homeText': "Free Throw GOOD by Nevada's Foster, Daniel"},
#   {'score': '19-46',
#    'time': '02:20',
#    'visitorText': "Layup GOOD by SJSU's Davis, Latrell",
#    'homeText': ''},
#   {'score': '19-48',
#    'time': '02:04',
#    'visitorText': '',
#    'homeText': "Jumper GOOD by Nevada's Lucas, Jarod"},
#   {'score': '',
#    'time': '02:04',
#    'visitorText': '',
#    'homeText': 'Nevada Assist by Mcintosh, Hunter'},
#   {'score': '',
#    'time': '01:57',
#    'visitorText': '',
#    'homeText': "Foul on Nevada's Lucas, Jarod"},
#   {'score': '',
#    'time': '01:57',
#    'visitorText': "Free Throw MISSED by SJSU's Davis, Latrell",
#    'homeText': ''},
#   {'score': '',
#    'time': '01:57',
#    'visitorText': 'SJSU gets a REBOUND from a dead ball.',
#    'homeText': ''},
#   {'score': '',
#    'time': '01:57',
#    'visitorText': '',
#    'homeText': 'Subbing out for Nevada - Lucas, Jarod'},
#   {'score': '',
#    'time': '01:57',
#    'visitorText': '',
#    'homeText': 'Subbing out for Nevada - Davidson, Nick'},
#   {'score': '',
#    'time': '01:57',
#    'visitorText': '',
#    'homeText': 'Subbing in for Nevada - Robinson, Amire'},
#   {'score': '',
#    'time': '01:57',
#    'visitorText': '',
#    'homeText': 'Subbing in for Nevada - Gardner, Jazz'},
#   {'score': '20-48',
#    'time': '01:57',
#    'visitorText': "Free Throw GOOD by SJSU's Davis, Latrell",
#    'homeText': ''},
#   {'score': '',
#    'time': '01:39',
#    'visitorText': '',
#    'homeText': "Layup MISSED by Nevada's Foster, Daniel"},
#   {'score': '',
#    'time': '01:35',
#    'visitorText': '',
#    'homeText': 'Nevada Offensive REBOUND by Gardner, Jazz'},
#   {'score': '',
#    'time': '01:35',
#    'visitorText': '',
#    'homeText': "Layup MISSED by Nevada's Gardner, Jazz"},
#   {'score': '',
#    'time': '01:33',
#    'visitorText': '',
#    'homeText': 'Nevada Offensive REBOUND by Gardner, Jazz'},
#   {'score': '',
#    'time': '01:33',
#    'visitorText': '',
#    'homeText': "Layup MISSED by Nevada's Gardner, Jazz"},
#   {'score': '',
#    'time': '01:30',
#    'visitorText': '',
#    'homeText': 'Nevada Offensive REBOUND by Coleman, Tre'},
#   {'score': '',
#    'time': '01:27',
#    'visitorText': "Foul on SJSU's Diongue, Adrame",
#    'homeText': ''},
#   {'score': '20-49',
#    'time': '01:27',
#    'visitorText': '',
#    'homeText': "Free Throw GOOD by Nevada's Gardner, Jazz"},
#   {'score': '',
#    'time': '01:27',
#    'visitorText': 'Subbing out for SJSU - Diongue, Adrame',
#    'homeText': ''},
#   {'score': '',
#    'time': '01:27',
#    'visitorText': 'Subbing in for SJSU - Humer, William',
#    'homeText': ''},
#   {'score': '',
#    'time': '01:26',
#    'visitorText': '',
#    'homeText': "Free Throw MISSED by Nevada's Gardner, Jazz"},
#   {'score': '',
#    'time': '01:25',
#    'visitorText': 'SJSU Defensive REBOUND by Amey jr., Myron',
#    'homeText': ''},
#   {'score': '22-49',
#    'time': '01:14',
#    'visitorText': "Jumper GOOD by SJSU's Cardenas, Alvaro",
#    'homeText': ''},
#   {'score': '',
#    'time': '00:56',
#    'visitorText': '',
#    'homeText': "3 Pointer MISSED by Nevada's Coleman, Tre"},
#   {'score': '',
#    'time': '00:52',
#    'visitorText': 'SJSU Defensive REBOUND by Seixas, Diogo',
#    'homeText': ''},
#   {'score': '24-49',
#    'time': '00:30',
#    'visitorText': "Jumper GOOD by SJSU's Cardenas, Alvaro",
#    'homeText': ''},
#   {'score': '',
#    'time': '00:30',
#    'visitorText': 'SJSU Assist by Amey jr., Myron',
#    'homeText': ''},
#   {'score': '',
#    'time': '00:23',
#    'visitorText': '',
#    'homeText': 'Nevada takes a 30-second time out.'},
#   {'score': '',
#    'time': '00:23',
#    'visitorText': '',
#    'homeText': 'Subbing out for Nevada - Coleman, Tre'},
#   {'score': '',
#    'time': '00:23',
#    'visitorText': '',
#    'homeText': 'Subbing in for Nevada - Lucas, Jarod'},
#   {'score': '',
#    'time': '00:23',
#    'visitorText': 'Subbing out for SJSU - Humer, William',
#    'homeText': ''},
#   {'score': '',
#    'time': '00:23',
#    'visitorText': 'Subbing in for SJSU - Wise, Christian',
#    'homeText': ''},
#   {'score': '',
#    'time': '00:03',
#    'visitorText': '',
#    'homeText': "Jumper MISSED by Nevada's Mcintosh, Hunter"},
#   {'score': '',
#    'time': '00:03',
#    'visitorText': 'SJSU Block by Wise, Christian',
#    'homeText': ''},
#   {'score': '',
#    'time': '00:03',
#    'visitorText': 'SJSU Defensive REBOUND by Amey jr., Myron',
#    'homeText': ''}]}

# %%
def pull_game_v2(game_id):
    """
    Use Requests to hit hidden API endpoint on NCAA for play-by-play
    Args:
        game_id: INT or STR, 7 digits as far as I can tell
        smallest seems to be 6197002, starting this season
        6196001 seems to still be D1 mens bball but in the future??
        Need to see what happens when we try to ping A) future games and B)non basketball
        6195001 is a hockey game, see what happens there
        Ice Hockey is mentioned in ['meta']['title'], but basketball does not do that
        Trying soccer - 6191603
        Same conclusion with soccer. This will be annoying but might be worth checking if all other sports do that
        No - lacross has exact same title as bball. We can get past this by checking all the text for a buzzword
        
        
    
    """
    global r
    url = "https://data.ncaa.com/casablanca/game/{}/pbp.json".format(str(game_id))
    r = requests.get(url)
    #check if "Layup" exists in the content otherwise fail
    cont = r.content
    
    if ('Layup' not in str(cont)) and ('layup' not in str(cont)) and ('LAYUP' not in str(cont)):
        raise Exception('This may be the wrong sport')
    
    
    
    json_copy = json.loads(r.content)
    
    if json_copy == {'Message': 'Object not found.'}:
        raise Exception("Invalid game_id or future game_id")
    
    #pull date
    date=json_copy['updatedTimestamp']
    
    #pull data from json object
    meta_info = json_copy['meta']['teams']

    team1 = [meta_info[0]['homeTeam'],meta_info[0]['id'],meta_info[0]['shortName']]
    team2 = [meta_info[1]['homeTeam'],meta_info[1]['id'],meta_info[1]['shortName']]

    team_data = pd.DataFrame([team1,team2],columns=['home','id','name'])

    game=json_copy['periods']
    
    #don't yet know how to handle overtime
    if len(game) != 2:
        raise ValueError
    
    first_half=game[0]
    second_half=game[1]
    
    #Initialize empty dataframe
    box_score=pd.DataFrame()
    
    #scores will be 0 until scoring_started is True
    scoring_started=False
    
    #iterate through first_half states
    for item in first_half['playStats']:
        score=item['score']
        time=item['time']
        v_text=item['visitorText']
        h_text=item['homeText']

        if len(h_text) == 0:
            all_text = v_text
        else:
            all_text = h_text
        
        #if score field is blank, either 0-0 or same as previous score
        if (len(score) == 0):
            if (scoring_started==False):
                home_score=0
                away_score=0
            else:
                #no code necessary here but for show:
                home_score=home_score
                away_score=away_score
                
        #otherwise, it is in the format "AWAY-HOME"
        elif len(score) != 0:
            scoring_started=True
            away_score, home_score = score.split('-')
            away_score=int(away_score)
            home_score=int(home_score)
            
        half=1

        #create row for state
        current_state = pd.DataFrame({'Period':half,
                                      'TIME':time,
                                       'Away':away_score,
                                      'Home':home_score,
                                  'PLAY':all_text},index=[0])
        box_score=pd.concat([box_score,current_state])
        
        #same iterations but no need for "first Score" logic
    for item in second_half['playStats']:
        score=item['score']
        time=item['time']
        v_text=item['visitorText']
        h_text=item['homeText']
        if len(score) == 0:
                home_score=home_score
                away_score=away_score
        else:
            scoring_started=True
            away_score, home_score = score.split('-')
            away_score=int(away_score)
            home_score=int(home_score)

        if len(h_text) == 0:
            all_text = v_text
        else:
            all_text = h_text
            
        half=2

        current_state = pd.DataFrame({'Period':half,
                                      'TIME':time,
                                       'Away':away_score,
                                      'Home':home_score,
                                  'PLAY':all_text},index=[0])
        box_score=pd.concat([box_score,current_state])
        
        
    box_score=box_score.reset_index(drop=True)
    return {'data': box_score, 'teams': team_data}

# %%
game2=pull_game_v2(6200081)

# %%
game2['teams']
# Out:
#     home    id          name
# 0   true  1628        Nevada
# 1  false   260  San Jose St.

# %%
json.loads(r.content)
# Out:
# {'inputMD5Sum': '47bf94a1262e4fc8e052f15e59e06103',
#  'updatedTimestamp': '2024-02-06 03:00:07 ET',
#  'meta': {'title': ' Play-By-Play',
#   'description': 'Play-By-Play for Nevada vs San Jose St.',
#   'division': 'd1',
#   'status': 'Final',
#   'period': '',
#   'minutes': '',
#   'seconds': '',
#   'teams': [{'homeTeam': 'true',
#     'id': '1628',
#     'seoName': 'nevada',
#     'sixCharAbbr': 'NEVADA',
#     'shortName': 'Nevada',
#     'nickName': 'Wolf Pack',
#     'color': '#041E42'},
#    {'homeTeam': 'false',
#     'id': '260',
#     'seoName': 'san-jose-st',
#     'sixCharAbbr': 'SJSU',
#     'shortName': 'San Jose St.',
#     'nickName': 'Spartans',
#     'color': '#233A82'}]},
#  'periods': [{'periodNumber': '1',
#    'periodDisplay': '1st Half',
#    'playStats': [{'score': '',
#      'time': '19:38',
#      'visitorText': "Jumper MISSED by SJSU's Gorener, Tibet",
#      'homeText': ''},
#     {'score': '',
#      'time': '19:36',
#      'visitorText': '',
#      'homeText': 'Nevada Defensive REBOUND by team'},
#     {'score': '',
#      'time': '19:23',
#      'visitorText': "Foul on SJSU's Diongue, Adrame",
#      'homeText': ''},
#     {'score': '0-3',
#      'time': '19:06',
#      'visitorText': '',
#      'homeText': "3 Pointer GOOD by Nevada's Blackshear, Kenan"},
#     {'score': '',
#      'time': '19:06',
#      'visitorText': '',
#      'homeText': 'Nevada Assist by Coleman, Tre'},
#     {'score': '3-3',
#      'time': '18:39',
#      'visitorText': "3 Pointer GOOD by SJSU's Anderson, Trey",
#      'homeText': ''},
#     {'score': '',
#      'time': '18:39',
#      'visitorText': 'SJSU Assist by Amey jr., Myron',
#      'homeText': ''},
#     {'score': '3-5',
#      'time': '18:26',
#      'visitorText': '',
#      'homeText': "Jumper GOOD by Nevada's Blackshear, Kenan"},
#     {'score': '6-5',
#      'time': '18:09',
#      'visitorText': "3 Pointer GOOD by SJSU's Cardenas, Alvaro",
#      'homeText': ''},
#     {'score': '6-8',
#      'time': '17:50',
#      'visitorText': '',
#      'homeText': "3 Pointer GOOD by Nevada's Davidson, Nick"},
#     {'score': '',
#      'time': '17:50',
#      'visitorText': '',
#      'homeText': 'Nevada Assist by Blackshear, Kenan'},
#     {'score': '',
#      'time': '17:35',
#      'visitorText': 'SJSU Turnover by Amey jr., Myron',
#      'homeText': ''},
#     {'score': '',
#      'time': '17:21',
#      'visitorText': '',
#      'homeText': "Jumper MISSED by Nevada's Lucas, Jarod"},
#     {'score': '',
#      'time': '17:19',
#      'visitorText': '',
#      'homeText': 'Nevada Offensive REBOUND by Davidson, Nick'},
#     {'score': '',
#      'time': '17:19',
#      'visitorText': "Foul on SJSU's Anderson, Trey",
#      'homeText': ''},
#     {'score': '',
#      'time': '17:19',
#      'visitorText': 'Subbing out for SJSU - Diongue, Adrame',
#      'homeText': ''},
#     {'score': '',
#      'time': '17:19',
#      'visitorText': 'Subbing in for SJSU - Seixas, Diogo',
#      'homeText': ''},
#     {'score': '6-10',
#      'time': '17:12',
#      'visitorText': '',
#      'homeText': "Jumper GOOD by Nevada's Lucas, Jarod"},
#     {'score': '',
#      'time': '17:12',
#      'visitorText': '',
#      'homeText': 'Nevada Assist by Coleman, Tre'},
#     {'score': '',
#      'time': '16:56',
#      'visitorText': "3 Pointer MISSED by SJSU's Gorener, Tibet",
#      'homeText': ''},
#     {'score': '',
#      'time': '16:55',
#      'visitorText': '',
#      'homeText': 'Nevada Defensive REBOUND by team'},
#     {'score': '',
#      'time': '16:45',
#      'visitorText': '',
#      'homeText': 'Nevada Turnover by Blackshear, Kenan'},
#     {'score': '',
#      'time': '16:45',
#      'visitorText': 'SJSU Steal by Seixas, Diogo',
#      'homeText': ''},
#     {'score': '',
#      'time': '16:35',
#      'visitorText': "3 Pointer MISSED by SJSU's Amey jr., Myron",
#      'homeText': ''},
#     {'score': '',
#      'time': '16:32',
#      'visitorText': '',
#      'homeText': 'Nevada Defensive REBOUND by Coleman, Tre'},
#     {'score': '',
#      'time': '16:25',
#      'visitorText': '',
#      'homeText': "Jumper MISSED by Nevada's Lucas, Jarod"},
#     {'score': '',
#      'time': '16:23',
#      'visitorText': '',
#      'homeText': 'Nevada Offensive REBOUND by Davidson, Nick'},
#     {'score': '',
#      'time': '16:23',
#      'visitorText': "Foul on SJSU's Amey jr., Myron",
#      'homeText': ''},
#     {'score': '',
#      'time': '16:23',
#      'visitorText': '',
#      'homeText': "Free Throw MISSED by Nevada's Davidson, Nick"},
#     {'score': '',
#      'time': '16:23',
#      'visitorText': '',
#      'homeText': 'Nevada gets a REBOUND from a dead ball.'},
#     {'score': '',
#      'time': '16:23',
#      'visitorText': '',
#      'homeText': 'Subbing out for Nevada - Hymes, K.j.'},
#     {'score': '',
#      'time': '16:23',
#      'visitorText': '',
#      'homeText': 'Subbing in for Nevada - Foster, Daniel'},
#     {'score': '',
#      'time': '16:23',
#      'visitorText': 'Subbing out for SJSU - Anderson, Trey',
#      'homeText': ''},
#     {'score': '',
#      'time': '16:23',
#      'visitorText': 'Subbing in for SJSU - Anderson, Garrett',
#      'homeText': ''},
#     {'score': '6-11',
#      'time': '16:23',
#      'visitorText': '',
#      'homeText': "Free Throw GOOD by Nevada's Davidson, Nick"},
#     {'score': '',
#      'time': '16:08',
#      'visitorText': "Jumper MISSED by SJSU's Cardenas, Alvaro",
#      'homeText': ''},
#     {'score': '',
#      'time': '16:04',
#      'visitorText': 'SJSU Offensive REBOUND by Cardenas, Alvaro',
#      'homeText': ''},
#     {'score': '',
#      'time': '16:01',
#      'visitorText': "Jumper MISSED by SJSU's Gorener, Tibet",
#      'homeText': ''},
#     {'score': '',
#      'time': '15:56',
#      'visitorText': 'SJSU Offensive REBOUND by Gorener, Tibet',
#      'homeText': ''},
#     {'score': '',
#      'time': '15:56',
#      'visitorText': "Layup MISSED by SJSU's Gorener, Tibet",
#      'homeText': ''},
#     {'score': '',
#      'time': '15:55',
#      'visitorText': '',
#      'homeText': 'Nevada Defensive REBOUND by Davidson, Nick'},
#     {'score': '',
#      'time': '15:39',
#      'visitorText': '',
#      'homeText': "Layup MISSED by Nevada's Coleman, Tre"},
#     {'score': '',
#      'time': '15:35',
#      'visitorText': '',
#      'homeText': 'Nevada Offensive REBOUND by team'},
#     {'score': '',
#      'time': '15:35',
#      'visitorText': 'Media timeout',
#      'homeText': ''},
#     {'score': '6-14',
#      'time': '15:28',
#      'visitorText': '',
#      'homeText': "3 Pointer GOOD by Nevada's Lucas, Jarod"},
#     {'score': '',
#      'time': '15:28',
#      'visitorText': '',
#      'homeText': 'Nevada Assist by Blackshear, Kenan'},
#     {'score': '',
#      'time': '15:13',
#      'visitorText': 'SJSU Turnover by Seixas, Diogo',
#      'homeText': ''},
#     {'score': '',
#      'time': '15:13',
#      'visitorText': '',
#      'homeText': 'Nevada Steal by Coleman, Tre'},
#     {'score': '',
#      'time': '15:13',
#      'visitorText': 'Subbing out for SJSU - Seixas, Diogo',
#      'homeText': ''},
#     {'score': '',
#      'time': '15:13',
#      'visitorText': 'Subbing in for SJSU - Wise, Christian',
#      'homeText': ''},
#     {'score': '',
#      'time': '15:02',
#      'visitorText': '',
#      'homeText': "3 Pointer MISSED by Nevada's Coleman, Tre"},
#     {'score': '',
#      'time': '14:58',
#      'visitorText': 'SJSU Defensive REBOUND by Cardenas, Alvaro',
#      'homeText': ''},
#     {'score': '',
#      'time': '14:49',
#      'visitorText': '',
#      'homeText': "Foul on Nevada's Blackshear, Kenan"},
#     {'score': '',
#      'time': '14:49',
#      'visitorText': '',
#      'homeText': 'Subbing out for Nevada - Blackshear, Kenan'},
#     {'score': '',
#      'time': '14:49',
#      'visitorText': '',
#      'homeText': 'Subbing in for Nevada - Mcintosh, Hunter'},
#     {'score': '',
#      'time': '14:49',
#      'visitorText': 'Subbing out for SJSU - Gorener, Tibet',
#      'homeText': ''},
#     {'score': '',
#      'time': '14:49',
#      'visitorText': 'Subbing in for SJSU - Anderson, Trey',
#      'homeText': ''},
#     {'score': '8-14',
#      'time': '14:37',
#      'visitorText': "Jumper GOOD by SJSU's Amey jr., Myron",
#      'homeText': ''},
#     {'score': '',
#      'time': '14:15',
#      'visitorText': '',
#      'homeText': 'Nevada Turnover by Lucas, Jarod'},
#     {'score': '',
#      'time': '14:15',
#      'visitorText': 'SJSU Steal by Cardenas, Alvaro',
#      'homeText': ''},
#     {'score': '',
#      'time': '14:06',
#      'visitorText': 'SJSU Turnover by Wise, Christian',
#      'homeText': ''},
#     {'score': '',
#      'time': '14:06',
#      'visitorText': '',
#      'homeText': 'Nevada Steal by Foster, Daniel'},
#     {'score': '8-17',
#      'time': '13:59',
#      'visitorText': '',
#      'homeText': "3 Pointer GOOD by Nevada's Lucas, Jarod"},
#     {'score': '',
#      'time': '13:59',
#      'visitorText': '',
#      'homeText': 'Nevada Assist by Mcintosh, Hunter'},
#     {'score': '',
#      'time': '13:58',
#      'visitorText': "Foul on SJSU's Anderson, Garrett",
#      'homeText': ''},
#     {'score': '',
#      'time': '13:58',
#      'visitorText': 'Subbing out for SJSU - Anderson, Garrett',
#      'homeText': ''},
#     {'score': '',
#      'time': '13:58',
#      'visitorText': 'Subbing in for SJSU - Davis, Latrell',
#      'homeText': ''},
#     {'score': '8-18',
#      'time': '13:58',
#      'visitorText': '',
#      'homeText': "Free Throw GOOD by Nevada's Lucas, Jarod"},
#     {'score': '',
#      'time': '13:58',
#      'visitorText': '',
#      'homeText': 'Subbing out for Nevada - Coleman, Tre'},
#     {'score': '',
#      'time': '13:58',
#      'visitorText': '',
#      'homeText': 'Subbing in for Nevada - Pope, Tylan'},
#     {'score': '11-18',
#      'time': '13:45',
#      'visitorText': "3 Pointer GOOD by SJSU's Amey jr., Myron",
#      'homeText': ''},
#     {'score': '',
#      'time': '13:45',
#      'visitorText': 'SJSU Assist by Anderson, Trey',
#      'homeText': ''},
#     {'score': '',
#      'time': '13:33',
#      'visitorText': '',
#      'homeText': "Jumper MISSED by Nevada's Lucas, Jarod"},
#     {'score': '',
#      'time': '13:28',
#      'visitorText': '',
#      'homeText': 'Nevada Offensive REBOUND by Pope, Tylan'},
#     {'score': '',
#      'time': '13:18',
#      'visitorText': "Foul on SJSU's Anderson, Trey",
#      'homeText': ''},
#     {'score': '',
#      'time': '13:18',
#      'visitorText': 'Subbing out for SJSU - Anderson, Trey',
#      'homeText': ''},
#     {'score': '',
#      'time': '13:18',
#      'visitorText': 'Subbing in for SJSU - Gorener, Tibet',
#      'homeText': ''},
#     {'score': '11-20',
#      'time': '13:16',
#      'visitorText': '',
#      'homeText': "Layup GOOD by Nevada's Davidson, Nick"},
#     {'score': '',
#      'time': '13:16',
#      'visitorText': '',
#      'homeText': 'Nevada Assist by Mcintosh, Hunter'},
#     {'score': '',
#      'time': '13:00',
#      'visitorText': "3 Pointer MISSED by SJSU's Gorener, Tibet",
#      'homeText': ''},
#     {'score': '',
#      'time': '12:56',
#      'visitorText': '',
#      'homeText': 'Nevada Defensive REBOUND by Mcintosh, Hunter'},
#     {'score': '',
#      'time': '12:45',
#      'visitorText': "Foul on SJSU's Wise, Christian",
#      'homeText': ''},
#     {'score': '11-21',
#      'time': '12:45',
#      'visitorText': '',
#      'homeText': "Free Throw GOOD by Nevada's Davidson, Nick"},
#     {'score': '',
#      'time': '12:45',
#      'visitorText': 'Subbing out for SJSU - Wise, Christian',
#      'homeText': ''},
#     {'score': '',
#      'time': '12:45',
#      'visitorText': 'Subbing in for SJSU - Diongue, Adrame',
#      'homeText': ''},
#     {'score': '',
#      'time': '12:45',
#      'visitorText': '',
#      'homeText': 'Subbing out for Nevada - Lucas, Jarod'},
#     {'score': '',
#      'time': '12:45',
#      'visitorText': '',
#      'homeText': 'Subbing in for Nevada - Blackshear, Kenan'},
#     {'score': '11-22',
#      'time': '12:45',
#      'visitorText': '',
#      'homeText': "Free Throw GOOD by Nevada's Davidson, Nick"},
#     {'score': '',
#      'time': '12:45',
#      'visitorText': '',
#      'homeText': 'Subbing out for Nevada - Davidson, Nick'},
#     {'score': '',
#      'time': '12:45',
#      'visitorText': '',
#      'homeText': 'Subbing in for Nevada - Hymes, K.j.'},
#     {'score': '',
#      'time': '12:25',
#      'visitorText': '',
#      'homeText': "Foul on Nevada's Foster, Daniel"},
#     {'score': '',
#      'time': '12:18',
#      'visitorText': "3 Pointer MISSED by SJSU's Amey jr., Myron",
#      'homeText': ''},
#     {'score': '',
#      'time': '12:14',
#      'visitorText': '',
#      'homeText': 'Nevada Defensive REBOUND by Foster, Daniel'},
#     {'score': '',
#      'time': '11:57',
#      'visitorText': "Foul on SJSU's Cardenas, Alvaro",
#      'homeText': ''},
#     {'score': '',
#      'time': '11:57',
#      'visitorText': 'Media timeout',
#      'homeText': ''},
#     {'score': '',
#      'time': '11:57',
#      'visitorText': 'Subbing out for SJSU - Amey jr., Myron',
#      'homeText': ''},
#     {'score': '',
#      'time': '11:57',
#      'visitorText': 'Subbing out for SJSU - Davis, Latrell',
#      'homeText': ''},
#     {'score': '',
#      'time': '11:57',
#      'visitorText': 'Subbing in for SJSU - Anderson, Garrett',
#      'homeText': ''},
#     {'score': '',
#      'time': '11:57',
#      'visitorText': 'Subbing in for SJSU - Mitchell jr., Rickey',
#      'homeText': ''},
#     {'score': '',
#      'time': '11:57',
#      'visitorText': '',
#      'homeText': "Free Throw MISSED by Nevada's Mcintosh, Hunter"},
#     {'score': '',
#      'time': '11:57',
#      'visitorText': '',
#      'homeText': 'Nevada gets a REBOUND from a dead ball.'},
#     {'score': '11-23',
#      'time': '11:57',
#      'visitorText': '',
#      'homeText': "Free Throw GOOD by Nevada's Mcintosh, Hunter"},
#     {'score': '',
#      'time': '11:43',
#      'visitorText': "Layup MISSED by SJSU's Diongue, Adrame",
#      'homeText': ''},
#     {'score': '',
#      'time': '11:39',
#      'visitorText': '',
#      'homeText': 'Nevada Defensive REBOUND by Mcintosh, Hunter'},
#     {'score': '',
#      'time': '11:26',
#      'visitorText': '',
#      'homeText': "3 Pointer MISSED by Nevada's Mcintosh, Hunter"},
#     {'score': '',
#      'time': '11:23',
#      'visitorText': 'SJSU Defensive REBOUND by Diongue, Adrame',
#      'homeText': ''},
#     {'score': '',
#      'time': '11:23',
#      'visitorText': '',
#      'homeText': "Foul on Nevada's Blackshear, Kenan"},
#     {'score': '',
#      'time': '10:53',
#      'visitorText': "3 Pointer MISSED by SJSU's Mitchell jr., Rickey",
#      'homeText': ''},
#     {'score': '',
#      'time': '10:48',
#      'visitorText': '',
#      'homeText': 'Nevada Defensive REBOUND by Blackshear, Kenan'},
#     {'score': '',
#      'time': '10:44',
#      'visitorText': "Foul on SJSU's Diongue, Adrame",
#      'homeText': ''},
#     {'score': '',
#      'time': '10:44',
#      'visitorText': '',
#      'homeText': "Free Throw MISSED by Nevada's Blackshear, Kenan"},
#     {'score': '',
#      'time': '10:44',
#      'visitorText': '',
#      'homeText': 'Nevada gets a REBOUND from a dead ball.'},
#     {'score': '',
#      'time': '10:44',
#      'visitorText': '',
#      'homeText': 'Subbing out for Nevada - Mcintosh, Hunter'},
#     {'score': '',
#      'time': '10:44',
#      'visitorText': '',
#      'homeText': 'Subbing out for Nevada - Foster, Daniel'},
#     {'score': '',
#      'time': '10:44',
#      'visitorText': '',
#      'homeText': 'Subbing in for Nevada - Lucas, Jarod'},
#     {'score': '',
#      'time': '10:44',
#      'visitorText': '',
#      'homeText': 'Subbing in for Nevada - Coleman, Tre'},
#     {'score': '',
#      'time': '10:44',
#      'visitorText': 'Subbing out for SJSU - Diongue, Adrame',
#      'homeText': ''},
#     {'score': '',
#      'time': '10:44',
#      'visitorText': 'Subbing out for SJSU - Cardenas, Alvaro',
#      'homeText': ''},
#     {'score': '',
#      'time': '10:44',
#      'visitorText': 'Subbing in for SJSU - Amey jr., Myron',
#      'homeText': ''},
#     {'score': '',
#      'time': '10:44',
#      'visitorText': 'Subbing in for SJSU - Seixas, Diogo',
#      'homeText': ''},
#     {'score': '11-24',
#      'time': '10:44',
#      'visitorText': '',
#      'homeText': "Free Throw GOOD by Nevada's Blackshear, Kenan"},
#     {'score': '',
#      'time': '10:44',
#      'visitorText': '',
#      'homeText': 'Subbing out for Nevada - Blackshear, Kenan'},
#     {'score': '',
#      'time': '10:44',
#      'visitorText': '',
#      'homeText': 'Subbing in for Nevada - Rolison, Tyler'},
#     {'score': '',
#      'time': '10:21',
#      'visitorText': 'SJSU Turnover by Amey jr., Myron',
#      'homeText': ''},
#     {'score': '',
#      'time': '10:21',
#      'visitorText': '',
#      'homeText': 'Nevada Steal by Rolison, Tyler'},
#     {'score': '',
#      'time': '10:08',
#      'visitorText': "Foul on SJSU's Mitchell jr., Rickey",
#      'homeText': ''},
#     {'score': '11-25',
#      'time': '10:08',
#      'visitorText': '',
#      'homeText': "Free Throw GOOD by Nevada's Rolison, Tyler"},
#     {'score': '11-26',
#      'time': '10:08',
#      'visitorText': '',
#      'homeText': "Free Throw GOOD by Nevada's Rolison, Tyler"},
#     {'score': '',
#      'time': '09:50',
#      'visitorText': 'SJSU Turnover by Amey jr., Myron',
#      'homeText': ''},
#     {'score': '',
#      'time': '09:36',
#      'visitorText': "Foul on SJSU's Seixas, Diogo",
#      'homeText': ''},
#     {'score': '11-27',
#      'time': '09:36',
#      'visitorText': '',
#      'homeText': "Free Throw GOOD by Nevada's Hymes, K.j."},
#     {'score': '',
#      'time': '09:36',
#      'visitorText': 'Subbing out for SJSU - Seixas, Diogo',
#      'homeText': ''},
#     {'score': '',
#      'time': '09:36',
#      'visitorText': 'Subbing in for SJSU - Humer, William',
#      'homeText': ''},
#     {'score': '',
#      'time': '09:35',
#      'visitorText': '',
#      'homeText': "Free Throw MISSED by Nevada's Hymes, K.j."},
#     {'score': '',
#      'time': '09:34',
#      'visitorText': 'SJSU Defensive REBOUND by Gorener, Tibet',
#      'homeText': ''},
#     {'score': '',
#      'time': '09:18',
#      'visitorText': "Layup MISSED by SJSU's Anderson, Garrett",
#      'homeText': ''},
#     {'score': '',
#      'time': '09:15',
#      'visitorText': '',
#      'homeText': 'Nevada Defensive REBOUND by Rolison, Tyler'},
#     {'score': '',
#      'time': '09:11',
#      'visitorText': '',
#      'homeText': "3 Pointer MISSED by Nevada's Lucas, Jarod"},
#     {'score': '',
#      'time': '09:07',
#      'visitorText': 'SJSU Defensive REBOUND by Mitchell jr., Rickey',
#      'homeText': ''},
#     {'score': '',
#      'time': '09:04',
#      'visitorText': 'SJSU Turnover by Humer, William',
#      'homeText': ''},
#     {'score': '',
#      'time': '08:53',
#      'visitorText': '',
#      'homeText': "Layup MISSED by Nevada's Coleman, Tre"},
#     {'score': '',
#      'time': '08:52',
#      'visitorText': 'SJSU Defensive REBOUND by Amey jr., Myron',
#      'homeText': ''},
#     {'score': '',
#      'time': '08:52',
#      'visitorText': '',
#      'homeText': "Foul on Nevada's Pope, Tylan"},
#     {'score': '',
#      'time': '08:52',
#      'visitorText': 'Subbing out for SJSU - Anderson, Garrett',
#      'homeText': ''},
#     {'score': '',
#      'time': '08:52',
#      'visitorText': 'Subbing out for SJSU - Mitchell jr., Rickey',
#      'homeText': ''},
#     {'score': '',
#      'time': '08:52',
#      'visitorText': 'Subbing in for SJSU - Cardenas, Alvaro',
#      'homeText': ''},
#     {'score': '',
#      'time': '08:52',
#      'visitorText': 'Subbing in for SJSU - Anderson, Trey',
#      'homeText': ''},
#     {'score': '',
#      'time': '08:36',
#      'visitorText': '',
#      'homeText': "Foul on Nevada's Rolison, Tyler"},
#     {'score': '',
#      'time': '08:36',
#      'visitorText': '',
#      'homeText': 'Subbing out for Nevada - Hymes, K.j.'},
#     {'score': '',
#      'time': '08:36',
#      'visitorText': '',
#      'homeText': 'Subbing in for Nevada - Davidson, Nick'},
#     {'score': '',
#      'time': '08:21',
#      'visitorText': "Jumper MISSED by SJSU's Cardenas, Alvaro",
#      'homeText': ''},
#     {'score': '',
#      'time': '08:18',
#      'visitorText': '',
#      'homeText': 'Nevada Defensive REBOUND by Davidson, Nick'},
#     {'score': '',
#      'time': '08:08',
#      'visitorText': "Foul on SJSU's Gorener, Tibet",
#      'homeText': ''},
#     {'score': '11-28',
#      'time': '08:08',
#      'visitorText': '',
#      'homeText': "Free Throw GOOD by Nevada's Pope, Tylan"},
#     {'score': '',
#      'time': '08:07',
#      'visitorText': '',
#      'homeText': "Free Throw MISSED by Nevada's Pope, Tylan"},
#     {'score': '',
#      'time': '08:05',
#      'visitorText': '',
#      'homeText': 'Nevada Offensive REBOUND by Davidson, Nick'},
#     {'score': '11-30',
#      'time': '08:02',
#      'visitorText': '',
#      'homeText': "Slam Dunk GOOD by Nevada's Pope, Tylan"},
#     {'score': '',
#      'time': '08:02',
#      'visitorText': '',
#      'homeText': 'Nevada Assist by Davidson, Nick'},
#     {'score': '',
#      'time': '07:58',
#      'visitorText': 'SJSU takes a 30-second time out.',
#      'homeText': ''},
#     {'score': '',
#      'time': '07:58',
#      'visitorText': 'Media timeout',
#      'homeText': ''},
#     {'score': '',
#      'time': '07:58',
#      'visitorText': 'Subbing out for SJSU - Humer, William',
#      'homeText': ''},
#     {'score': '',
#      'time': '07:58',
#      'visitorText': 'Subbing in for SJSU - Wise, Christian',
#      'homeText': ''},
#     {'score': '13-30',
#      'time': '07:37',
#      'visitorText': "Layup GOOD by SJSU's Amey jr., Myron",
#      'homeText': ''},
#     {'score': '13-33',
#      'time': '07:18',
#      'visitorText': '',
#      'homeText': "3 Pointer GOOD by Nevada's Rolison, Tyler"},
#     {'score': '',
#      'time': '07:18',
#      'visitorText': '',
#      'homeText': 'Nevada Assist by Pope, Tylan'},
#     {'score': '15-33',
#      'time': '07:00',
#      'visitorText': "Jumper GOOD by SJSU's Gorener, Tibet",
#      'homeText': ''},
#     {'score': '15-36',
#      'time': '06:35',
#      'visitorText': '',
#      'homeText': "3 Pointer GOOD by Nevada's Pope, Tylan"},
#     {'score': '',
#      'time': '06:35',
#      'visitorText': '',
#      'homeText': 'Nevada Assist by Lucas, Jarod'},
#     {'score': '',
#      'time': '06:14',
#      'visitorText': "3 Pointer MISSED by SJSU's Gorener, Tibet",
#      'homeText': ''},
#     {'score': '',
#      'time': '06:10',
#      'visitorText': '',
#      'homeText': 'Nevada Defensive REBOUND by Rolison, Tyler'},
#     {'score': '',
#      'time': '06:07',
#      'visitorText': "Foul on SJSU's Gorener, Tibet",
#      'homeText': ''},
#     {'score': '',
#      'time': '06:07',
#      'visitorText': '',
#      'homeText': "Free Throw MISSED by Nevada's Rolison, Tyler"},
#     {'score': '',
#      'time': '06:07',
#      'visitorText': '',
#      'homeText': 'Nevada gets a REBOUND from a dead ball.'},
#     {'score': '',
#      'time': '06:07',
#      'visitorText': '',
#      'homeText': 'Subbing out for Nevada - Pope, Tylan'},
#     {'score': '',
#      'time': '06:07',
#      'visitorText': '',
#      'homeText': 'Subbing in for Nevada - Foster, Daniel'},
#     {'score': '',
#      'time': '06:07',
#      'visitorText': 'Subbing out for SJSU - Gorener, Tibet',
#      'homeText': ''},
#     {'score': '',
#      'time': '06:07',
#      'visitorText': 'Subbing in for SJSU - Davis, Latrell',
#      'homeText': ''},
#     {'score': '15-37',
#      'time': '06:07',
#      'visitorText': '',
#      'homeText': "Free Throw GOOD by Nevada's Rolison, Tyler"},
#     {'score': '',
#      'time': '05:43',
#      'visitorText': "3 Pointer MISSED by SJSU's Anderson, Trey",
#      'homeText': ''},
#     {'score': '',
#      'time': '05:40',
#      'visitorText': '',
#      'homeText': 'Nevada Defensive REBOUND by Lucas, Jarod'},
#     {'score': '15-39',
#      'time': '05:28',
#      'visitorText': '',
#      'homeText': "Layup GOOD by Nevada's Davidson, Nick"},
#     {'score': '',
#      'time': '05:28',
#      'visitorText': '',
#      'homeText': 'Nevada Assist by Coleman, Tre'},
#     {'score': '17-39',
#      'time': '04:58',
#      'visitorText': "Jumper GOOD by SJSU's Amey jr., Myron",
#      'homeText': ''},
#     {'score': '',
#      'time': '04:58',
#      'visitorText': 'SJSU Assist by Davis, Latrell',
#      'homeText': ''},
#     {'score': '17-42',
#      'time': '04:33',
#      'visitorText': '',
#      'homeText': "3 Pointer GOOD by Nevada's Rolison, Tyler"},
#     {'score': '',
#      'time': '04:33',
#      'visitorText': '',
#      'homeText': 'Nevada Assist by Lucas, Jarod'},
#     {'score': '',
#      'time': '04:05',
#      'visitorText': "3 Pointer MISSED by SJSU's Anderson, Trey",
#      'homeText': ''},
#     {'score': '',
#      'time': '04:02',
#      'visitorText': '',
#      'homeText': 'Nevada Defensive REBOUND by Lucas, Jarod'},
#     {'score': '',
#      'time': '03:49',
#      'visitorText': '',
#      'homeText': "3 Pointer MISSED by Nevada's Coleman, Tre"},
#     {'score': '',
#      'time': '03:46',
#      'visitorText': '',
#      'homeText': 'Nevada Offensive REBOUND by Davidson, Nick'},
#     {'score': '17-44',
#      'time': '03:38',
#      'visitorText': '',
#      'homeText': "Slam Dunk GOOD by Nevada's Davidson, Nick"},
#     {'score': '',
#      'time': '03:38',
#      'visitorText': '',
#      'homeText': 'Nevada Assist by Foster, Daniel'},
#     {'score': '',
#      'time': '03:19',
#      'visitorText': "Jumper MISSED by SJSU's Anderson, Trey",
#      'homeText': ''},
#     {'score': '',
#      'time': '03:16',
#      'visitorText': '',
#      'homeText': 'Nevada Defensive REBOUND by Davidson, Nick'},
#     {'score': '',
#      'time': '03:09',
#      'visitorText': '',
#      'homeText': "Layup MISSED by Nevada's Rolison, Tyler"},
#     {'score': '',
#      'time': '03:05',
#      'visitorText': '',
#      'homeText': 'Nevada Offensive REBOUND by Foster, Daniel'},
#     {'score': '',
#      'time': '03:03',
#      'visitorText': '',
#      'homeText': "3 Pointer MISSED by Nevada's Coleman, Tre"},
#     {'score': '',
#      'time': '02:55',
#      'visitorText': 'SJSU Defensive REBOUND by Amey jr., Myron',
#      'homeText': ''},
#     {'score': '',
#      'time': '02:48',
#      'visitorText': "3 Pointer MISSED by SJSU's Amey jr., Myron",
#      'homeText': ''},
#     {'score': '',
#      'time': '02:46',
#      'visitorText': '',
#      'homeText': 'Nevada Defensive REBOUND by Foster, Daniel'},
#     {'score': '',
#      'time': '02:46',
#      'visitorText': "Foul on SJSU's Wise, Christian",
#      'homeText': ''},
#     {'score': '',
#      'time': '02:46',
#      'visitorText': 'Media timeout',
#      'homeText': ''},
#     {'score': '',
#      'time': '02:46',
#      'visitorText': '',
#      'homeText': 'Subbing out for Nevada - Rolison, Tyler'},
#     {'score': '',
#      'time': '02:46',
#      'visitorText': '',
#      'homeText': 'Subbing in for Nevada - Mcintosh, Hunter'},
#     {'score': '',
#      'time': '02:46',
#      'visitorText': 'Subbing out for SJSU - Anderson, Trey',
#      'homeText': ''},
#     {'score': '',
#      'time': '02:46',
#      'visitorText': 'Subbing out for SJSU - Wise, Christian',
#      'homeText': ''},
#     {'score': '',
#      'time': '02:46',
#      'visitorText': 'Subbing in for SJSU - Diongue, Adrame',
#      'homeText': ''},
#     {'score': '',
#      'time': '02:46',
#      'visitorText': 'Subbing in for SJSU - Seixas, Diogo',
#      'homeText': ''},
#     {'score': '17-45',
#      'time': '02:46',
#      'visitorText': '',
#      'homeText': "Free Throw GOOD by Nevada's Foster, Daniel"},
#     {'score': '17-46',
#      'time': '02:46',
#      'visitorText': '',
#      'homeText': "Free Throw GOOD by Nevada's Foster, Daniel"},
#     {'score': '19-46',
#      'time': '02:20',
#      'visitorText': "Layup GOOD by SJSU's Davis, Latrell",
#      'homeText': ''},
#     {'score': '19-48',
#      'time': '02:04',
#      'visitorText': '',
#      'homeText': "Jumper GOOD by Nevada's Lucas, Jarod"},
#     {'score': '',
#      'time': '02:04',
#      'visitorText': '',
#      'homeText': 'Nevada Assist by Mcintosh, Hunter'},
#     {'score': '',
#      'time': '01:57',
#      'visitorText': '',
#      'homeText': "Foul on Nevada's Lucas, Jarod"},
#     {'score': '',
#      'time': '01:57',
#      'visitorText': "Free Throw MISSED by SJSU's Davis, Latrell",
#      'homeText': ''},
#     {'score': '',
#      'time': '01:57',
#      'visitorText': 'SJSU gets a REBOUND from a dead ball.',
#      'homeText': ''},
#     {'score': '',
#      'time': '01:57',
#      'visitorText': '',
#      'homeText': 'Subbing out for Nevada - Lucas, Jarod'},
#     {'score': '',
#      'time': '01:57',
#      'visitorText': '',
#      'homeText': 'Subbing out for Nevada - Davidson, Nick'},
#     {'score': '',
#      'time': '01:57',
#      'visitorText': '',
#      'homeText': 'Subbing in for Nevada - Robinson, Amire'},
#     {'score': '',
#      'time': '01:57',
#      'visitorText': '',
#      'homeText': 'Subbing in for Nevada - Gardner, Jazz'},
#     {'score': '20-48',
#      'time': '01:57',
#      'visitorText': "Free Throw GOOD by SJSU's Davis, Latrell",
#      'homeText': ''},
#     {'score': '',
#      'time': '01:39',
#      'visitorText': '',
#      'homeText': "Layup MISSED by Nevada's Foster, Daniel"},
#     {'score': '',
#      'time': '01:35',
#      'visitorText': '',
#      'homeText': 'Nevada Offensive REBOUND by Gardner, Jazz'},
#     {'score': '',
#      'time': '01:35',
#      'visitorText': '',
#      'homeText': "Layup MISSED by Nevada's Gardner, Jazz"},
#     {'score': '',
#      'time': '01:33',
#      'visitorText': '',
#      'homeText': 'Nevada Offensive REBOUND by Gardner, Jazz'},
#     {'score': '',
#      'time': '01:33',
#      'visitorText': '',
#      'homeText': "Layup MISSED by Nevada's Gardner, Jazz"},
#     {'score': '',
#      'time': '01:30',
#      'visitorText': '',
#      'homeText': 'Nevada Offensive REBOUND by Coleman, Tre'},
#     {'score': '',
#      'time': '01:27',
#      'visitorText': "Foul on SJSU's Diongue, Adrame",
#      'homeText': ''},
#     {'score': '20-49',
#      'time': '01:27',
#      'visitorText': '',
#      'homeText': "Free Throw GOOD by Nevada's Gardner, Jazz"},
#     {'score': '',
#      'time': '01:27',
#      'visitorText': 'Subbing out for SJSU - Diongue, Adrame',
#      'homeText': ''},
#     {'score': '',
#      'time': '01:27',
#      'visitorText': 'Subbing in for SJSU - Humer, William',
#      'homeText': ''},
#     {'score': '',
#      'time': '01:26',
#      'visitorText': '',
#      'homeText': "Free Throw MISSED by Nevada's Gardner, Jazz"},
#     {'score': '',
#      'time': '01:25',
#      'visitorText': 'SJSU Defensive REBOUND by Amey jr., Myron',
#      'homeText': ''},
#     {'score': '22-49',
#      'time': '01:14',
#      'visitorText': "Jumper GOOD by SJSU's Cardenas, Alvaro",
#      'homeText': ''},
#     {'score': '',
#      'time': '00:56',
#      'visitorText': '',
#      'homeText': "3 Pointer MISSED by Nevada's Coleman, Tre"},
#     {'score': '',
#      'time': '00:52',
#      'visitorText': 'SJSU Defensive REBOUND by Seixas, Diogo',
#      'homeText': ''},
#     {'score': '24-49',
#      'time': '00:30',
#      'visitorText': "Jumper GOOD by SJSU's Cardenas, Alvaro",
#      'homeText': ''},
#     {'score': '',
#      'time': '00:30',
#      'visitorText': 'SJSU Assist by Amey jr., Myron',
#      'homeText': ''},
#     {'score': '',
#      'time': '00:23',
#      'visitorText': '',
#      'homeText': 'Nevada takes a 30-second time out.'},
#     {'score': '',
#      'time': '00:23',
#      'visitorText': '',
#      'homeText': 'Subbing out for Nevada - Coleman, Tre'},
#     {'score': '',
#      'time': '00:23',
#      'visitorText': '',
#      'homeText': 'Subbing in for Nevada - Lucas, Jarod'},
#     {'score': '',
#      'time': '00:23',
#      'visitorText': 'Subbing out for SJSU - Humer, William',
#      'homeText': ''},
#     {'score': '',
#      'time': '00:23',
#      'visitorText': 'Subbing in for SJSU - Wise, Christian',
#      'homeText': ''},
#     {'score': '',
#      'time': '00:03',
#      'visitorText': '',
#      'homeText': "Jumper MISSED by Nevada's Mcintosh, Hunter"},
#     {'score': '',
#      'time': '00:03',
#      'visitorText': 'SJSU Block by Wise, Christian',
#      'homeText': ''},
#     {'score': '',
#      'time': '00:03',
#      'visitorText': 'SJSU Defensive REBOUND by Amey jr., Myron',
#      'homeText': ''}]},
#   {'periodNumber': '2',
#    'periodDisplay': '2nd Half',
#    'playStats': [{'score': '',
#      'time': '20:00',
#      'visitorText': '',
#      'homeText': 'Subbing out for Nevada - Mcintosh, Hunter'},
#     {'score': '',
#      'time': '20:00',
#      'visitorText': '',
#      'homeText': 'Subbing out for Nevada - Robinson, Amire'},
#     {'score': '',
#      'time': '20:00',
#      'visitorText': '',
#      'homeText': 'Subbing out for Nevada - Foster, Daniel'},
#     {'score': '',
#      'time': '20:00',
#      'visitorText': '',
#      'homeText': 'Subbing out for Nevada - Gardner, Jazz'},
#     {'score': '',
#      'time': '20:00',
#      'visitorText': '',
#      'homeText': 'Subbing in for Nevada - Coleman, Tre'},
#     {'score': '',
#      'time': '20:00',
#      'visitorText': '',
#      'homeText': 'Subbing in for Nevada - Davidson, Nick'},
#     {'score': '',
#      'time': '20:00',
#      'visitorText': '',
#      'homeText': 'Subbing in for Nevada - Blackshear, Kenan'},
#     {'score': '',
#      'time': '20:00',
#      'visitorText': '',
#      'homeText': 'Subbing in for Nevada - Hymes, K.j.'},
#     {'score': '',
#      'time': '20:00',
#      'visitorText': 'Subbing out for SJSU - Davis, Latrell',
#      'homeText': ''},
#     {'score': '',
#      'time': '20:00',
#      'visitorText': 'Subbing in for SJSU - Anderson, Garrett',
#      'homeText': ''},
#     {'score': '24-52',
#      'time': '19:50',
#      'visitorText': '',
#      'homeText': "3 Pointer GOOD by Nevada's Davidson, Nick"},
#     {'score': '',
#      'time': '19:50',
#      'visitorText': '',
#      'homeText': 'Nevada Assist by Blackshear, Kenan'},
#     {'score': '',
#      'time': '19:34',
#      'visitorText': 'SJSU Turnover by Amey jr., Myron',
#      'homeText': ''},
#     {'score': '',
#      'time': '19:34',
#      'visitorText': '',
#      'homeText': 'Nevada Steal by Blackshear, Kenan'},
#     {'score': '24-55',
#      'time': '19:06',
#      'visitorText': '',
#      'homeText': "3 Pointer GOOD by Nevada's Lucas, Jarod"},
#     {'score': '',
#      'time': '19:06',
#      'visitorText': '',
#      'homeText': 'Nevada Assist by Davidson, Nick'},
#     {'score': '',
#      'time': '18:39',
#      'visitorText': "3 Pointer MISSED by SJSU's Seixas, Diogo",
#      'homeText': ''},
#     {'score': '',
#      'time': '18:35',
#      'visitorText': '',
#      'homeText': 'Nevada Defensive REBOUND by Coleman, Tre'},
#     {'score': '',
#      'time': '18:26',
#      'visitorText': '',
#      'homeText': "Jumper MISSED by Nevada's Lucas, Jarod"},
#     {'score': '',
#      'time': '18:22',
#      'visitorText': 'SJSU Defensive REBOUND by Anderson, Garrett',
#      'homeText': ''},
#     {'score': '',
#      'time': '18:08',
#      'visitorText': "3 Pointer MISSED by SJSU's Anderson, Garrett",
#      'homeText': ''},
#     {'score': '',
#      'time': '18:03',
#      'visitorText': '',
#      'homeText': 'Nevada Defensive REBOUND by Coleman, Tre'},
#     {'score': '24-58',
#      'time': '17:59',
#      'visitorText': '',
#      'homeText': "3 Pointer GOOD by Nevada's Coleman, Tre"},
#     {'score': '',
#      'time': '17:59',
#      'visitorText': '',
#      'homeText': 'Nevada Assist by Blackshear, Kenan'},
#     {'score': '',
#      'time': '17:46',
#      'visitorText': 'SJSU Turnover by Cardenas, Alvaro',
#      'homeText': ''},
#     {'score': '',
#      'time': '17:46',
#      'visitorText': '',
#      'homeText': 'Nevada Steal by Hymes, K.j.'},
#     {'score': '24-61',
#      'time': '17:38',
#      'visitorText': '',
#      'homeText': "3 Pointer GOOD by Nevada's Davidson, Nick"},
#     {'score': '',
#      'time': '17:24',
#      'visitorText': "3 Pointer MISSED by SJSU's Amey jr., Myron",
#      'homeText': ''},
#     {'score': '',
#      'time': '17:21',
#      'visitorText': '',
#      'homeText': 'Nevada Defensive REBOUND by Lucas, Jarod'},
#     {'score': '',
#      'time': '17:14',
#      'visitorText': "Foul on SJSU's Wise, Christian",
#      'homeText': ''},
#     {'score': '',
#      'time': '17:14',
#      'visitorText': 'Subbing out for SJSU - Amey jr., Myron',
#      'homeText': ''},
#     {'score': '',
#      'time': '17:14',
#      'visitorText': 'Subbing out for SJSU - Anderson, Garrett',
#      'homeText': ''},
#     {'score': '',
#      'time': '17:14',
#      'visitorText': 'Subbing out for SJSU - Cardenas, Alvaro',
#      'homeText': ''},
#     {'score': '',
#      'time': '17:14',
#      'visitorText': 'Subbing out for SJSU - Wise, Christian',
#      'homeText': ''},
#     {'score': '',
#      'time': '17:14',
#      'visitorText': 'Subbing out for SJSU - Seixas, Diogo',
#      'homeText': ''},
#     {'score': '',
#      'time': '17:14',
#      'visitorText': 'Subbing in for SJSU - Mitchell jr., Rickey',
#      'homeText': ''},
#     {'score': '',
#      'time': '17:14',
#      'visitorText': 'Subbing in for SJSU - Diongue, Adrame',
#      'homeText': ''},
#     {'score': '',
#      'time': '17:14',
#      'visitorText': 'Subbing in for SJSU - Gorener, Tibet',
#      'homeText': ''},
#     {'score': '',
#      'time': '17:14',
#      'visitorText': 'Subbing in for SJSU - Davis, Latrell',
#      'homeText': ''},
#     {'score': '',
#      'time': '17:14',
#      'visitorText': 'Subbing in for SJSU - Anderson, Trey',
#      'homeText': ''},
#     {'score': '24-63',
#      'time': '17:04',
#      'visitorText': '',
#      'homeText': "Layup GOOD by Nevada's Lucas, Jarod"},
#     {'score': '',
#      'time': '17:04',
#      'visitorText': '',
#      'homeText': 'Nevada Assist by Blackshear, Kenan'},
#     {'score': '',
#      'time': '16:51',
#      'visitorText': '',
#      'homeText': "Foul on Nevada's Blackshear, Kenan"},
#     {'score': '',
#      'time': '16:51',
#      'visitorText': "Free Throw MISSED by SJSU's Davis, Latrell",
#      'homeText': ''},
#     {'score': '',
#      'time': '16:51',
#      'visitorText': 'SJSU gets a REBOUND from a dead ball.',
#      'homeText': ''},
#     {'score': '',
#      'time': '16:50',
#      'visitorText': "Free Throw MISSED by SJSU's Davis, Latrell",
#      'homeText': ''},
#     {'score': '',
#      'time': '16:48',
#      'visitorText': 'SJSU Offensive REBOUND by Diongue, Adrame',
#      'homeText': ''},
#     {'score': '',
#      'time': '16:45',
#      'visitorText': '',
#      'homeText': 'Subbing out for Nevada - Hymes, K.j.'},
#     {'score': '',
#      'time': '16:45',
#      'visitorText': '',
#      'homeText': 'Subbing in for Nevada - Foster, Daniel'},
#     {'score': '',
#      'time': '16:29',
#      'visitorText': "3 Pointer MISSED by SJSU's Gorener, Tibet",
#      'homeText': ''},
#     {'score': '',
#      'time': '16:26',
#      'visitorText': '',
#      'homeText': 'Nevada Defensive REBOUND by Davidson, Nick'},
#     {'score': '24-65',
#      'time': '16:24',
#      'visitorText': '',
#      'homeText': "Layup GOOD by Nevada's Blackshear, Kenan"},
#     {'score': '',
#      'time': '16:24',
#      'visitorText': "Foul on SJSU's Mitchell jr., Rickey",
#      'homeText': ''},
#     {'score': '',
#      'time': '16:23',
#      'visitorText': '',
#      'homeText': "Free Throw MISSED by Nevada's Blackshear, Kenan"},
#     {'score': '',
#      'time': '16:22',
#      'visitorText': 'SJSU Defensive REBOUND by Diongue, Adrame',
#      'homeText': ''},
#     {'score': '',
#      'time': '16:06',
#      'visitorText': 'SJSU Turnover by Gorener, Tibet',
#      'homeText': ''},
#     {'score': '',
#      'time': '16:06',
#      'visitorText': '',
#      'homeText': 'Nevada Steal by Lucas, Jarod'},
#     {'score': '24-67',
#      'time': '15:58',
#      'visitorText': '',
#      'homeText': "Layup GOOD by Nevada's Lucas, Jarod"},
#     {'score': '26-67',
#      'time': '15:50',
#      'visitorText': "Layup GOOD by SJSU's Anderson, Trey",
#      'homeText': ''},
#     {'score': '',
#      'time': '15:50',
#      'visitorText': 'SJSU Assist by Diongue, Adrame',
#      'homeText': ''},
#     {'score': '',
#      'time': '15:50',
#      'visitorText': '',
#      'homeText': "Foul on Nevada's Blackshear, Kenan"},
#     {'score': '',
#      'time': '15:50',
#      'visitorText': 'Media timeout',
#      'homeText': ''},
#     {'score': '',
#      'time': '15:50',
#      'visitorText': '',
#      'homeText': 'Subbing out for Nevada - Blackshear, Kenan'},
#     {'score': '',
#      'time': '15:50',
#      'visitorText': '',
#      'homeText': 'Subbing in for Nevada - Rolison, Tyler'},
#     {'score': '',
#      'time': '15:50',
#      'visitorText': 'Subbing out for SJSU - Gorener, Tibet',
#      'homeText': ''},
#     {'score': '',
#      'time': '15:50',
#      'visitorText': 'Subbing in for SJSU - Cardenas, Alvaro',
#      'homeText': ''},
#     {'score': '27-67',
#      'time': '15:50',
#      'visitorText': "Free Throw GOOD by SJSU's Anderson, Trey",
#      'homeText': ''},
#     {'score': '',
#      'time': '15:24',
#      'visitorText': '',
#      'homeText': "Jumper MISSED by Nevada's Davidson, Nick"},
#     {'score': '',
#      'time': '15:24',
#      'visitorText': 'SJSU Block by Anderson, Trey',
#      'homeText': ''},
#     {'score': '',
#      'time': '15:18',
#      'visitorText': '',
#      'homeText': 'Nevada Offensive REBOUND by Davidson, Nick'},
#     {'score': '27-69',
#      'time': '15:18',
#      'visitorText': '',
#      'homeText': "Layup GOOD by Nevada's Davidson, Nick"},
#     {'score': '29-69',
#      'time': '15:00',
#      'visitorText': "Slam Dunk GOOD by SJSU's Diongue, Adrame",
#      'homeText': ''},
#     {'score': '',
#      'time': '15:00',
#      'visitorText': 'SJSU Assist by Anderson, Trey',
#      'homeText': ''},
#     {'score': '',
#      'time': '14:37',
#      'visitorText': '',
#      'homeText': "3 Pointer MISSED by Nevada's Foster, Daniel"},
#     {'score': '',
#      'time': '14:34',
#      'visitorText': '',
#      'homeText': 'Nevada Offensive REBOUND by Davidson, Nick'},
#     {'score': '',
#      'time': '14:30',
#      'visitorText': '',
#      'homeText': "3 Pointer MISSED by Nevada's Rolison, Tyler"},
#     {'score': '',
#      'time': '14:25',
#      'visitorText': 'SJSU Defensive REBOUND by Diongue, Adrame',
#      'homeText': ''},
#     {'score': '',
#      'time': '14:13',
#      'visitorText': '',
#      'homeText': "Foul on Nevada's Rolison, Tyler"},
#     {'score': '',
#      'time': '14:04',
#      'visitorText': "3 Pointer MISSED by SJSU's Cardenas, Alvaro",
#      'homeText': ''},
#     {'score': '',
#      'time': '14:01',
#      'visitorText': '',
#      'homeText': 'Nevada Defensive REBOUND by Coleman, Tre'},
#     {'score': '',
#      'time': '13:54',
#      'visitorText': '',
#      'homeText': "3 Pointer MISSED by Nevada's Davidson, Nick"},
#     {'score': '',
#      'time': '13:49',
#      'visitorText': 'SJSU Defensive REBOUND by Diongue, Adrame',
#      'homeText': ''},
#     {'score': '',
#      'time': '13:45',
#      'visitorText': "3 Pointer MISSED by SJSU's Anderson, Trey",
#      'homeText': ''},
#     {'score': '',
#      'time': '13:43',
#      'visitorText': 'SJSU Offensive REBOUND by team',
#      'homeText': ''},
#     {'score': '',
#      'time': '13:43',
#      'visitorText': '',
#      'homeText': 'Subbing out for Nevada - Coleman, Tre'},
#     {'score': '',
#      'time': '13:43',
#      'visitorText': '',
#      'homeText': 'Subbing out for Nevada - Davidson, Nick'},
#     {'score': '',
#      'time': '13:43',
#      'visitorText': '',
#      'homeText': 'Subbing in for Nevada - Pope, Tylan'},
#     {'score': '',
#      'time': '13:43',
#      'visitorText': '',
#      'homeText': 'Subbing in for Nevada - Hymes, K.j.'},
#     {'score': '',
#      'time': '13:30',
#      'visitorText': "Jumper MISSED by SJSU's Anderson, Trey",
#      'homeText': ''},
#     {'score': '',
#      'time': '13:30',
#      'visitorText': '',
#      'homeText': 'Nevada Block by Hymes, K.j.'},
#     {'score': '',
#      'time': '13:25',
#      'visitorText': 'SJSU Offensive REBOUND by Mitchell jr., Rickey',
#      'homeText': ''},
#     {'score': '',
#      'time': '13:23',
#      'visitorText': "Layup MISSED by SJSU's Cardenas, Alvaro",
#      'homeText': ''},
#     {'score': '',
#      'time': '13:19',
#      'visitorText': 'SJSU Offensive REBOUND by Diongue, Adrame',
#      'homeText': ''},
#     {'score': '',
#      'time': '13:19',
#      'visitorText': "Layup MISSED by SJSU's Diongue, Adrame",
#      'homeText': ''},
#     {'score': '',
#      'time': '13:18',
#      'visitorText': '',
#      'homeText': 'Nevada Defensive REBOUND by Pope, Tylan'},
#     {'score': '',
#      'time': '13:03',
#      'visitorText': '',
#      'homeText': "Jumper MISSED by Nevada's Lucas, Jarod"},
#     {'score': '',
#      'time': '12:58',
#      'visitorText': 'SJSU Defensive REBOUND by Davis, Latrell',
#      'homeText': ''},
#     {'score': '31-69',
#      'time': '12:44',
#      'visitorText': "Layup GOOD by SJSU's Anderson, Trey",
#      'homeText': ''},
#     {'score': '',
#      'time': '12:44',
#      'visitorText': 'SJSU Assist by Cardenas, Alvaro',
#      'homeText': ''},
#     {'score': '',
#      'time': '12:23',
#      'visitorText': "Foul on SJSU's Diongue, Adrame",
#      'homeText': ''},
#     {'score': '31-70',
#      'time': '12:23',
#      'visitorText': '',
#      'homeText': "Free Throw GOOD by Nevada's Hymes, K.j."},
#     {'score': '',
#      'time': '12:23',
#      'visitorText': '',
#      'homeText': 'Subbing out for Nevada - Lucas, Jarod'},
#     {'score': '',
#      'time': '12:23',
#      'visitorText': '',
#      'homeText': 'Subbing in for Nevada - Mcintosh, Hunter'},
#     {'score': '',
#      'time': '12:23',
#      'visitorText': 'Subbing out for SJSU - Mitchell jr., Rickey',
#      'homeText': ''},
#     {'score': '',
#      'time': '12:23',
#      'visitorText': 'Subbing out for SJSU - Diongue, Adrame',
#      'homeText': ''},
#     {'score': '',
#      'time': '12:23',
#      'visitorText': 'Subbing out for SJSU - Davis, Latrell',
#      'homeText': ''},
#     {'score': '',
#      'time': '12:23',
#      'visitorText': 'Subbing in for SJSU - Amey jr., Myron',
#      'homeText': ''},
#     {'score': '',
#      'time': '12:23',
#      'visitorText': 'Subbing in for SJSU - Gorener, Tibet',
#      'homeText': ''},
#     {'score': '',
#      'time': '12:23',
#      'visitorText': 'Subbing in for SJSU - Seixas, Diogo',
#      'homeText': ''},
#     {'score': '31-71',
#      'time': '12:23',
#      'visitorText': '',
#      'homeText': "Free Throw GOOD by Nevada's Hymes, K.j."},
#     {'score': '',
#      'time': '12:02',
#      'visitorText': "3 Pointer MISSED by SJSU's Gorener, Tibet",
#      'homeText': ''},
#     {'score': '',
#      'time': '11:56',
#      'visitorText': '',
#      'homeText': 'Nevada Defensive REBOUND by Hymes, K.j.'},
#     {'score': '',
#      'time': '11:53',
#      'visitorText': "Foul on SJSU's Cardenas, Alvaro",
#      'homeText': ''},
#     {'score': '',
#      'time': '11:53',
#      'visitorText': 'Media timeout',
#      'homeText': ''},
#     {'score': '31-72',
#      'time': '11:53',
#      'visitorText': '',
#      'homeText': "Free Throw GOOD by Nevada's Rolison, Tyler"},
#     {'score': '31-73',
#      'time': '11:53',
#      'visitorText': '',
#      'homeText': "Free Throw GOOD by Nevada's Rolison, Tyler"},
#     {'score': '',
#      'time': '11:42',
#      'visitorText': "3 Pointer MISSED by SJSU's Amey jr., Myron",
#      'homeText': ''},
#     {'score': '',
#      'time': '11:40',
#      'visitorText': 'SJSU Offensive REBOUND by Gorener, Tibet',
#      'homeText': ''},
#     {'score': '',
#      'time': '11:40',
#      'visitorText': '',
#      'homeText': "Foul on Nevada's Hymes, K.j."},
#     {'score': '',
#      'time': '11:26',
#      'visitorText': '',
#      'homeText': "Foul on Nevada's Rolison, Tyler"},
#     {'score': '',
#      'time': '11:26',
#      'visitorText': "Free Throw MISSED by SJSU's Amey jr., Myron",
#      'homeText': ''},
#     {'score': '',
#      'time': '11:26',
#      'visitorText': 'SJSU gets a REBOUND from a dead ball.',
#      'homeText': ''},
#     {'score': '32-73',
#      'time': '11:26',
#      'visitorText': "Free Throw GOOD by SJSU's Amey jr., Myron",
#      'homeText': ''},
#     {'score': '',
#      'time': '11:15',
#      'visitorText': '',
#      'homeText': "Foul on Nevada's Pope, Tylan"},
#     {'score': '',
#      'time': '11:15',
#      'visitorText': '',
#      'homeText': 'Nevada Turnover by Pope, Tylan'},
#     {'score': '35-73',
#      'time': '10:53',
#      'visitorText': "3 Pointer GOOD by SJSU's Anderson, Trey",
#      'homeText': ''},
#     {'score': '',
#      'time': '10:53',
#      'visitorText': 'SJSU Assist by Amey jr., Myron',
#      'homeText': ''},
#     {'score': '35-75',
#      'time': '10:38',
#      'visitorText': '',
#      'homeText': "Layup GOOD by Nevada's Pope, Tylan"},
#     {'score': '',
#      'time': '10:38',
#      'visitorText': '',
#      'homeText': 'Nevada Assist by Hymes, K.j.'},
#     {'score': '',
#      'time': '10:38',
#      'visitorText': "Foul on SJSU's Anderson, Trey",
#      'homeText': ''},
#     {'score': '',
#      'time': '10:38',
#      'visitorText': '',
#      'homeText': 'Subbing out for Nevada - Rolison, Tyler'},
#     {'score': '',
#      'time': '10:38',
#      'visitorText': '',
#      'homeText': 'Subbing in for Nevada - Blackshear, Kenan'},
#     {'score': '',
#      'time': '10:38',
#      'visitorText': 'Subbing out for SJSU - Seixas, Diogo',
#      'homeText': ''},
#     {'score': '',
#      'time': '10:38',
#      'visitorText': 'Subbing in for SJSU - Wise, Christian',
#      'homeText': ''},
#     {'score': '',
#      'time': '10:38',
#      'visitorText': '',
#      'homeText': "Free Throw MISSED by Nevada's Pope, Tylan"},
#     {'score': '',
#      'time': '10:36',
#      'visitorText': 'SJSU Defensive REBOUND by Wise, Christian',
#      'homeText': ''},
#     {'score': '38-75',
#      'time': '10:08',
#      'visitorText': "3 Pointer GOOD by SJSU's Gorener, Tibet",
#      'homeText': ''},
#     {'score': '',
#      'time': '10:08',
#      'visitorText': 'SJSU Assist by Cardenas, Alvaro',
#      'homeText': ''},
#     {'score': '',
#      'time': '09:51',
#      'visitorText': '',
#      'homeText': "3 Pointer MISSED by Nevada's Foster, Daniel"},
#     {'score': '',
#      'time': '09:44',
#      'visitorText': 'SJSU Defensive REBOUND by Amey jr., Myron',
#      'homeText': ''},
#     {'score': '',
#      'time': '09:38',
#      'visitorText': "3 Pointer MISSED by SJSU's Amey jr., Myron",
#      'homeText': ''},
#     {'score': '',
#      'time': '09:33',
#      'visitorText': '',
#      'homeText': 'Nevada Defensive REBOUND by Pope, Tylan'},
#     {'score': '38-77',
#      'time': '09:28',
#      'visitorText': '',
#      'homeText': "Layup GOOD by Nevada's Pope, Tylan"},
#     {'score': '',
#      'time': '09:28',
#      'visitorText': '',
#      'homeText': 'Nevada Assist by Mcintosh, Hunter'},
#     {'score': '41-77',
#      'time': '09:00',
#      'visitorText': "3 Pointer GOOD by SJSU's Cardenas, Alvaro",
#      'homeText': ''},
#     {'score': '',
#      'time': '09:00',
#      'visitorText': 'SJSU Assist by Amey jr., Myron',
#      'homeText': ''},
#     {'score': '',
#      'time': '08:58',
#      'visitorText': 'SJSU takes a 30-second time out.',
#      'homeText': ''},
#     {'score': '',
#      'time': '08:58',
#      'visitorText': '',
#      'homeText': 'Subbing out for Nevada - Mcintosh, Hunter'},
#     {'score': '',
#      'time': '08:58',
#      'visitorText': '',
#      'homeText': 'Subbing out for Nevada - Foster, Daniel'},
#     {'score': '',
#      'time': '08:58',
#      'visitorText': '',
#      'homeText': 'Subbing out for Nevada - Pope, Tylan'},
#     {'score': '',
#      'time': '08:58',
#      'visitorText': '',
#      'homeText': 'Subbing in for Nevada - Lucas, Jarod'},
#     {'score': '',
#      'time': '08:58',
#      'visitorText': '',
#      'homeText': 'Subbing in for Nevada - Coleman, Tre'},
#     {'score': '',
#      'time': '08:58',
#      'visitorText': '',
#      'homeText': 'Subbing in for Nevada - Davidson, Nick'},
#     {'score': '',
#      'time': '08:58',
#      'visitorText': 'Subbing out for SJSU - Amey jr., Myron',
#      'homeText': ''},
#     {'score': '',
#      'time': '08:58',
#      'visitorText': 'Subbing out for SJSU - Gorener, Tibet',
#      'homeText': ''},
#     {'score': '',
#      'time': '08:58',
#      'visitorText': 'Subbing in for SJSU - Anderson, Garrett',
#      'homeText': ''},
#     {'score': '',
#      'time': '08:58',
#      'visitorText': 'Subbing in for SJSU - Seixas, Diogo',
#      'homeText': ''},
#     {'score': '',
#      'time': '08:46',
#      'visitorText': '',
#      'homeText': 'Nevada Turnover by Davidson, Nick'},
#     {'score': '',
#      'time': '08:46',
#      'visitorText': 'SJSU Steal by Wise, Christian',
#      'homeText': ''},
#     {'score': '44-77',
#      'time': '08:40',
#      'visitorText': "3 Pointer GOOD by SJSU's Cardenas, Alvaro",
#      'homeText': ''},
#     {'score': '',
#      'time': '08:07',
#      'visitorText': '',
#      'homeText': "Jumper MISSED by Nevada's Blackshear, Kenan"},
#     {'score': '',
#      'time': '08:01',
#      'visitorText': '',
#      'homeText': 'Nevada Offensive REBOUND by Hymes, K.j.'},
#     {'score': '',
#      'time': '08:01',
#      'visitorText': '',
#      'homeText': "3 Pointer MISSED by Nevada's Lucas, Jarod"},
#     {'score': '',
#      'time': '08:00',
#      'visitorText': '',
#      'homeText': 'Nevada Offensive REBOUND by Davidson, Nick'},
#     {'score': '',
#      'time': '08:00',
#      'visitorText': "Foul on SJSU's Seixas, Diogo",
#      'homeText': ''},
#     {'score': '',
#      'time': '08:00',
#      'visitorText': 'Subbing out for SJSU - Seixas, Diogo',
#      'homeText': ''},
#     {'score': '',
#      'time': '08:00',
#      'visitorText': 'Subbing in for SJSU - Diongue, Adrame',
#      'homeText': ''},
#     {'score': '44-79',
#      'time': '07:58',
#      'visitorText': '',
#      'homeText': "Jumper GOOD by Nevada's Lucas, Jarod"},
#     {'score': '',
#      'time': '07:58',
#      'visitorText': '',
#      'homeText': 'Nevada Assist by Blackshear, Kenan'},
#     {'score': '',
#      'time': '07:42',
#      'visitorText': '',
#      'homeText': "Foul on Nevada's Coleman, Tre"},
#     {'score': '',
#      'time': '07:42',
#      'visitorText': 'Media timeout',
#      'homeText': ''},
#     {'score': '45-79',
#      'time': '07:42',
#      'visitorText': "Free Throw GOOD by SJSU's Cardenas, Alvaro",
#      'homeText': ''},
#     {'score': '',
#      'time': '07:41',
#      'visitorText': "Free Throw MISSED by SJSU's Cardenas, Alvaro",
#      'homeText': ''},
#     {'score': '',
#      'time': '07:40',
#      'visitorText': 'SJSU Offensive REBOUND by Cardenas, Alvaro',
#      'homeText': ''},
#     {'score': '',
#      'time': '07:36',
#      'visitorText': "3 Pointer MISSED by SJSU's Anderson, Trey",
#      'homeText': ''},
#     {'score': '',
#      'time': '07:31',
#      'visitorText': '',
#      'homeText': 'Nevada Defensive REBOUND by Lucas, Jarod'},
#     {'score': '45-81',
#      'time': '07:25',
#      'visitorText': '',
#      'homeText': "Layup GOOD by Nevada's Davidson, Nick"},
#     {'score': '',
#      'time': '07:25',
#      'visitorText': '',
#      'homeText': 'Nevada Assist by Lucas, Jarod'},
#     {'score': '',
#      'time': '07:07',
#      'visitorText': 'SJSU Turnover by Diongue, Adrame',
#      'homeText': ''},
#     {'score': '',
#      'time': '07:07',
#      'visitorText': '',
#      'homeText': 'Nevada Steal by Coleman, Tre'},
#     {'score': '',
#      'time': '06:54',
#      'visitorText': '',
#      'homeText': "3 Pointer MISSED by Nevada's Davidson, Nick"},
#     {'score': '',
#      'time': '06:50',
#      'visitorText': '',
#      'homeText': 'Nevada Offensive REBOUND by team'},
#     {'score': '45-83',
#      'time': '06:43',
#      'visitorText': '',
#      'homeText': "Jumper GOOD by Nevada's Blackshear, Kenan"},
#     {'score': '',
#      'time': '06:22',
#      'visitorText': "Jumper MISSED by SJSU's Anderson, Trey",
#      'homeText': ''},
#     {'score': '',
#      'time': '06:20',
#      'visitorText': 'SJSU Offensive REBOUND by Wise, Christian',
#      'homeText': ''},
#     {'score': '47-83',
#      'time': '06:18',
#      'visitorText': "Layup GOOD by SJSU's Wise, Christian",
#      'homeText': ''},
#     {'score': '',
#      'time': '06:07',
#      'visitorText': "Foul on SJSU's Anderson, Garrett",
#      'homeText': ''},
#     {'score': '',
#      'time': '06:07',
#      'visitorText': '',
#      'homeText': 'Subbing out for Nevada - Hymes, K.j.'},
#     {'score': '',
#      'time': '06:07',
#      'visitorText': '',
#      'homeText': 'Subbing in for Nevada - Foster, Daniel'},
#     {'score': '',
#      'time': '06:07',
#      'visitorText': 'Subbing out for SJSU - Diongue, Adrame',
#      'homeText': ''},
#     {'score': '',
#      'time': '06:07',
#      'visitorText': 'Subbing out for SJSU - Anderson, Trey',
#      'homeText': ''},
#     {'score': '',
#      'time': '06:07',
#      'visitorText': 'Subbing in for SJSU - Davis, Latrell',
#      'homeText': ''},
#     {'score': '',
#      'time': '06:07',
#      'visitorText': 'Subbing in for SJSU - Humer, William',
#      'homeText': ''},
#     {'score': '',
#      'time': '06:07',
#      'visitorText': '',
#      'homeText': "Free Throw MISSED by Nevada's Blackshear, Kenan"},
#     {'score': '',
#      'time': '06:07',
#      'visitorText': 'SJSU Defensive REBOUND by Wise, Christian',
#      'homeText': ''},
#     {'score': '49-83',
#      'time': '06:07',
#      'visitorText': "Jumper GOOD by SJSU's Davis, Latrell",
#      'homeText': ''},
#     {'score': '',
#      'time': '06:07',
#      'visitorText': 'SJSU Assist by Cardenas, Alvaro',
#      'homeText': ''},
#     {'score': '',
#      'time': '06:07',
#      'visitorText': '',
#      'homeText': "Layup MISSED by Nevada's Davidson, Nick"},
#     {'score': '',
#      'time': '06:07',
#      'visitorText': 'SJSU Block by Wise, Christian',
#      'homeText': ''},
#     {'score': '',
#      'time': '06:01',
#      'visitorText': 'SJSU Defensive REBOUND by team',
#      'homeText': ''},
#     {'score': '',
#      'time': '05:55',
#      'visitorText': 'Subbing out for SJSU - Cardenas, Alvaro',
#      'homeText': ''},
#     {'score': '',
#      'time': '05:55',
#      'visitorText': 'Subbing in for SJSU - Mitchell jr., Rickey',
#      'homeText': ''},
#     {'score': '',
#      'time': '05:00',
#      'visitorText': "Layup MISSED by SJSU's Anderson, Garrett",
#      'homeText': ''},
#     {'score': '',
#      'time': '05:00',
#      'visitorText': 'SJSU Offensive REBOUND by Wise, Christian',
#      'homeText': ''},
#     {'score': '',
#      'time': '05:00',
#      'visitorText': '',
#      'homeText': 'Nevada Block by Coleman, Tre'},
#     {'score': '',
#      'time': '04:53',
#      'visitorText': '',
#      'homeText': 'Subbing out for Nevada - Lucas, Jarod'},
#     {'score': '',
#      'time': '04:53',
#      'visitorText': '',
#      'homeText': 'Subbing out for Nevada - Coleman, Tre'},
#     {'score': '',
#      'time': '04:53',
#      'visitorText': '',
#      'homeText': 'Subbing out for Nevada - Blackshear, Kenan'},
#     {'score': '',
#      'time': '04:53',
#      'visitorText': '',
#      'homeText': 'Subbing in for Nevada - Mcintosh, Hunter'},
#     {'score': '',
#      'time': '04:53',
#      'visitorText': '',
#      'homeText': 'Subbing in for Nevada - Rolison, Tyler'},
#     {'score': '',
#      'time': '04:53',
#      'visitorText': '',
#      'homeText': 'Subbing in for Nevada - Robinson, Amire'},
#     {'score': '51-83',
#      'time': '04:47',
#      'visitorText': "Jumper GOOD by SJSU's Mitchell jr., Rickey",
#      'homeText': ''},
#     {'score': '51-85',
#      'time': '04:30',
#      'visitorText': '',
#      'homeText': "Slam Dunk GOOD by Nevada's Foster, Daniel"},
#     {'score': '',
#      'time': '04:30',
#      'visitorText': '',
#      'homeText': 'Nevada Assist by Davidson, Nick'},
#     {'score': '53-85',
#      'time': '04:11',
#      'visitorText': "Jumper GOOD by SJSU's Wise, Christian",
#      'homeText': ''},
#     {'score': '',
#      'time': '03:54',
#      'visitorText': "Foul on SJSU's Anderson, Garrett",
#      'homeText': ''},
#     {'score': '',
#      'time': '03:54',
#      'visitorText': 'Media timeout',
#      'homeText': ''},
#     {'score': '',
#      'time': '03:54',
#      'visitorText': '',
#      'homeText': 'Subbing out for Nevada - Foster, Daniel'},
#     {'score': '',
#      'time': '03:54',
#      'visitorText': '',
#      'homeText': 'Subbing in for Nevada - Pope, Tylan'},
#     {'score': '',
#      'time': '03:54',
#      'visitorText': '',
#      'homeText': "Free Throw MISSED by Nevada's Davidson, Nick"},
#     {'score': '',
#      'time': '03:52',
#      'visitorText': 'SJSU Defensive REBOUND by Wise, Christian',
#      'homeText': ''},
#     {'score': '56-85',
#      'time': '03:37',
#      'visitorText': "3 Pointer GOOD by SJSU's Davis, Latrell",
#      'homeText': ''},
#     {'score': '',
#      'time': '03:37',
#      'visitorText': 'SJSU Assist by Humer, William',
#      'homeText': ''},
#     {'score': '',
#      'time': '03:01',
#      'visitorText': '',
#      'homeText': "Jumper MISSED by Nevada's Rolison, Tyler"},
#     {'score': '',
#      'time': '02:59',
#      'visitorText': '',
#      'homeText': 'Nevada Offensive REBOUND by team'},
#     {'score': '',
#      'time': '02:59',
#      'visitorText': '',
#      'homeText': 'Subbing out for Nevada - Davidson, Nick'},
#     {'score': '',
#      'time': '02:59',
#      'visitorText': '',
#      'homeText': 'Subbing in for Nevada - Gardner, Jazz'},
#     {'score': '',
#      'time': '02:59',
#      'visitorText': 'Subbing out for SJSU - Anderson, Garrett',
#      'homeText': ''},
#     {'score': '',
#      'time': '02:59',
#      'visitorText': 'Subbing in for SJSU - Blackerby, Bennett',
#      'homeText': ''},
#     {'score': '',
#      'time': '02:47',
#      'visitorText': "Foul on SJSU's Wise, Christian",
#      'homeText': ''},
#     {'score': '56-86',
#      'time': '02:47',
#      'visitorText': '',
#      'homeText': "Free Throw GOOD by Nevada's Gardner, Jazz"},
#     {'score': '56-87',
#      'time': '02:47',
#      'visitorText': '',
#      'homeText': "Free Throw GOOD by Nevada's Gardner, Jazz"},
#     {'score': '58-87',
#      'time': '02:38',
#      'visitorText': "Jumper GOOD by SJSU's Mitchell jr., Rickey",
#      'homeText': ''},
#     {'score': '',
#      'time': '02:19',
#      'visitorText': '',
#      'homeText': "Jumper MISSED by Nevada's Gardner, Jazz"},
#     {'score': '',
#      'time': '02:15',
#      'visitorText': 'SJSU Defensive REBOUND by Wise, Christian',
#      'homeText': ''},
#     {'score': '60-87',
#      'time': '02:11',
#      'visitorText': "Jumper GOOD by SJSU's Davis, Latrell",
#      'homeText': ''},
#     {'score': '',
#      'time': '02:08',
#      'visitorText': '',
#      'homeText': 'Nevada takes a 30-second time out.'},
#     {'score': '',
#      'time': '02:08',
#      'visitorText': '',
#      'homeText': 'Subbing out for Nevada - Pope, Tylan'},
#     {'score': '',
#      'time': '02:08',
#      'visitorText': '',
#      'homeText': 'Subbing in for Nevada - Coleman, Jeriah'},
#     {'score': '',
#      'time': '01:51',
#      'visitorText': '',
#      'homeText': "Jumper MISSED by Nevada's Gardner, Jazz"},
#     {'score': '',
#      'time': '01:47',
#      'visitorText': '',
#      'homeText': 'Nevada Offensive REBOUND by Mcintosh, Hunter'},
#     {'score': '',
#      'time': '01:42',
#      'visitorText': '',
#      'homeText': "Layup MISSED by Nevada's Rolison, Tyler"},
#     {'score': '',
#      'time': '01:40',
#      'visitorText': '',
#      'homeText': 'Nevada Offensive REBOUND by Gardner, Jazz'},
#     {'score': '',
#      'time': '01:40',
#      'visitorText': '',
#      'homeText': 'Nevada Turnover by team'},
#     {'score': '',
#      'time': '01:31',
#      'visitorText': "3 Pointer MISSED by SJSU's Mitchell jr., Rickey",
#      'homeText': ''},
#     {'score': '',
#      'time': '01:28',
#      'visitorText': '',
#      'homeText': 'Nevada Defensive REBOUND by team'},
#     {'score': '60-89',
#      'time': '01:10',
#      'visitorText': '',
#      'homeText': "Layup GOOD by Nevada's Coleman, Jeriah"},
#     {'score': '',
#      'time': '01:10',
#      'visitorText': '',
#      'homeText': 'Nevada Assist by Mcintosh, Hunter'},
#     {'score': '',
#      'time': '00:57',
#      'visitorText': "Layup MISSED by SJSU's Davis, Latrell",
#      'homeText': ''},
#     {'score': '',
#      'time': '00:54',
#      'visitorText': '',
#      'homeText': 'Nevada Defensive REBOUND by Robinson, Amire'},
#     {'score': '',
#      'time': '00:48',
#      'visitorText': "Foul on SJSU's Mitchell jr., Rickey",
#      'homeText': ''},
#     {'score': '',
#      'time': '00:48',
#      'visitorText': '',
#      'homeText': "Free Throw MISSED by Nevada's Rolison, Tyler"},
#     {'score': '',
#      'time': '00:48',
#      'visitorText': '',
#      'homeText': 'Nevada gets a REBOUND from a dead ball.'},
#     {'score': '60-90',
#      'time': '00:48',
#      'visitorText': '',
#      'homeText': "Free Throw GOOD by Nevada's Rolison, Tyler"},
#     {'score': '',
#      'time': '00:29',
#      'visitorText': "Layup MISSED by SJSU's Davis, Latrell",
#      'homeText': ''},
#     {'score': '',
#      'time': '00:24',
#      'visitorText': 'SJSU Offensive REBOUND by Humer, William',
#      'homeText': ''},
#     {'score': '',
#      'time': '00:24',
#      'visitorText': "Layup MISSED by SJSU's Humer, William",
#      'homeText': ''},
#     {'score': '',
#      'time': '00:22',
#      'visitorText': '',
#      'homeText': 'Nevada Defensive REBOUND by Mcintosh, Hunter'}]}]}

# %%
# game2.to_excel('Second_Sample_Game.xlsx',index=False)

# %%
game3=pull_game_v2(6200082)

# %%
game3
# Out:
# {'data':      Period   TIME  Away  Home                                         PLAY
#  0         1  19:46     0     0       Layup MISSED by CU's Kalkbrenner, Ryan
#  1         1  19:43     0     0  Butler Defensive REBOUND by Telfort, Jahmyl
#  2         1  19:31     0     0  3 Pointer MISSED by Butler's Brooks, Pierre
#  3         1  19:27     0     0      CU Defensive REBOUND by Alexander, Trey
#  4         1  19:22     0     0                 Foul on CU's Alexander, Trey
#  ..      ...    ...   ...   ...                                          ...
#  420       2  00:05    99    98      Free Throw GOOD by CU's Alexander, Trey
#  421       2  00:05    99    98        Subbing out for CU - Ashworth, Steven
#  422       2  00:05    99    98            Subbing in for CU - Miller, Mason
#  423       2  00:00    99    98             Butler Turnover by Moore, Landon
#  424       2  00:00    99    98             CU Steal by Farabello, Francisco
#
#  [425 rows x 5 columns],
#  'teams':     home    id       name
#  0   true  1457  Creighton
#  1  false   488     Butler}

# %%
d = json.loads(r.content)

# %%
d['periods']
# Out:
# [{'periodNumber': '1',
#   'periodDisplay': '1st Half',
#   'playStats': [{'score': '',
#     'time': '19:46',
#     'visitorText': '',
#     'homeText': "Layup MISSED by CU's Kalkbrenner, Ryan"},
#    {'score': '',
#     'time': '19:43',
#     'visitorText': 'Butler Defensive REBOUND by Telfort, Jahmyl',
#     'homeText': ''},
#    {'score': '',
#     'time': '19:31',
#     'visitorText': "3 Pointer MISSED by Butler's Brooks, Pierre",
#     'homeText': ''},
#    {'score': '',
#     'time': '19:27',
#     'visitorText': '',
#     'homeText': 'CU Defensive REBOUND by Alexander, Trey'},
#    {'score': '',
#     'time': '19:22',
#     'visitorText': '',
#     'homeText': "Foul on CU's Alexander, Trey"},
#    {'score': '',
#     'time': '19:22',
#     'visitorText': '',
#     'homeText': 'CU Turnover by Alexander, Trey'},
#    {'score': '2-0',
#     'time': '19:02',
#     'visitorText': "Jumper GOOD by Butler's Telfort, Jahmyl",
#     'homeText': ''},
#    {'score': '2-2',
#     'time': '18:37',
#     'visitorText': '',
#     'homeText': "Jumper GOOD by CU's Alexander, Trey"},
#    {'score': '',
#     'time': '18:20',
#     'visitorText': "3 Pointer MISSED by Butler's Davis, Dj",
#     'homeText': ''},
#    {'score': '',
#     'time': '18:17',
#     'visitorText': '',
#     'homeText': 'CU Defensive REBOUND by Scheierman, Baylor'},
#    {'score': '',
#     'time': '18:01',
#     'visitorText': '',
#     'homeText': 'CU Turnover by Kalkbrenner, Ryan'},
#    {'score': '',
#     'time': '18:01',
#     'visitorText': 'Butler Steal by Davis, Dj',
#     'homeText': ''},
#    {'score': '',
#     'time': '17:56',
#     'visitorText': "Jumper MISSED by Butler's Davis, Dj",
#     'homeText': ''},
#    {'score': '',
#     'time': '17:52',
#     'visitorText': '',
#     'homeText': 'CU Defensive REBOUND by Scheierman, Baylor'},
#    {'score': '',
#     'time': '17:43',
#     'visitorText': '',
#     'homeText': "3 Pointer MISSED by CU's Scheierman, Baylor"},
#    {'score': '',
#     'time': '17:40',
#     'visitorText': 'Butler Defensive REBOUND by Thomas, Jalen',
#     'homeText': ''},
#    {'score': '5-2',
#     'time': '17:29',
#     'visitorText': "3 Pointer GOOD by Butler's Telfort, Jahmyl",
#     'homeText': ''},
#    {'score': '5-4',
#     'time': '17:17',
#     'visitorText': '',
#     'homeText': "Jumper GOOD by CU's Scheierman, Baylor"},
#    {'score': '',
#     'time': '17:17',
#     'visitorText': "Foul on Butler's Davis, Dj",
#     'homeText': ''},
#    {'score': '5-5',
#     'time': '17:17',
#     'visitorText': '',
#     'homeText': "Free Throw GOOD by CU's Scheierman, Baylor"},
#    {'score': '',
#     'time': '17:02',
#     'visitorText': "Jumper MISSED by Butler's Moore, Landon",
#     'homeText': ''},
#    {'score': '',
#     'time': '16:59',
#     'visitorText': 'Butler Offensive REBOUND by Thomas, Jalen',
#     'homeText': ''},
#    {'score': '7-5',
#     'time': '16:59',
#     'visitorText': "Layup GOOD by Butler's Thomas, Jalen",
#     'homeText': ''},
#    {'score': '7-8',
#     'time': '16:53',
#     'visitorText': '',
#     'homeText': "3 Pointer GOOD by CU's Ashworth, Steven"},
#    {'score': '',
#     'time': '16:34',
#     'visitorText': "3 Pointer MISSED by Butler's Thomas, Jalen",
#     'homeText': ''},
#    {'score': '',
#     'time': '16:31',
#     'visitorText': '',
#     'homeText': 'CU Defensive REBOUND by Alexander, Trey'},
#    {'score': '7-10',
#     'time': '16:16',
#     'visitorText': '',
#     'homeText': "Slam Dunk GOOD by CU's Kalkbrenner, Ryan"},
#    {'score': '',
#     'time': '16:16',
#     'visitorText': '',
#     'homeText': 'CU Assist by Ashworth, Steven'},
#    {'score': '',
#     'time': '16:16',
#     'visitorText': "Foul on Butler's Thomas, Jalen",
#     'homeText': ''},
#    {'score': '7-11',
#     'time': '16:16',
#     'visitorText': '',
#     'homeText': "Free Throw GOOD by CU's Kalkbrenner, Ryan"},
#    {'score': '9-11',
#     'time': '15:55',
#     'visitorText': "Jumper GOOD by Butler's Davis, Dj",
#     'homeText': ''},
#    {'score': '',
#     'time': '15:55',
#     'visitorText': 'Butler Assist by Brooks, Pierre',
#     'homeText': ''},
#    {'score': '',
#     'time': '15:37',
#     'visitorText': '',
#     'homeText': "Jumper MISSED by CU's Alexander, Trey"},
#    {'score': '',
#     'time': '15:34',
#     'visitorText': 'Butler Defensive REBOUND by Davis, Dj',
#     'homeText': ''},
#    {'score': '12-11',
#     'time': '15:21',
#     'visitorText': "3 Pointer GOOD by Butler's Moore, Landon",
#     'homeText': ''},
#    {'score': '',
#     'time': '15:21',
#     'visitorText': 'Butler Assist by Davis, Dj',
#     'homeText': ''},
#    {'score': '',
#     'time': '14:58',
#     'visitorText': '',
#     'homeText': "3 Pointer MISSED by CU's Miller, Mason"},
#    {'score': '',
#     'time': '14:57',
#     'visitorText': '',
#     'homeText': 'CU Offensive REBOUND by Kalkbrenner, Ryan'},
#    {'score': '',
#     'time': '14:57',
#     'visitorText': "Foul on Butler's Thomas, Jalen",
#     'homeText': ''},
#    {'score': '',
#     'time': '14:57',
#     'visitorText': 'Media timeout',
#     'homeText': ''},
#    {'score': '',
#     'time': '14:57',
#     'visitorText': 'Subbing out for Butler - Thomas, Jalen',
#     'homeText': ''},
#    {'score': '',
#     'time': '14:57',
#     'visitorText': 'Subbing out for Butler - Davis, Dj',
#     'homeText': ''},
#    {'score': '',
#     'time': '14:57',
#     'visitorText': 'Subbing in for Butler - Bizjack, Finley',
#     'homeText': ''},
#    {'score': '',
#     'time': '14:57',
#     'visitorText': 'Subbing in for Butler - Screen, Andre',
#     'homeText': ''},
#    {'score': '12-14',
#     'time': '14:51',
#     'visitorText': '',
#     'homeText': "3 Pointer GOOD by CU's Scheierman, Baylor"},
#    {'score': '',
#     'time': '14:51',
#     'visitorText': '',
#     'homeText': 'CU Assist by Miller, Mason'},
#    {'score': '',
#     'time': '14:27',
#     'visitorText': "Jumper MISSED by Butler's Screen, Andre",
#     'homeText': ''},
#    {'score': '',
#     'time': '14:24',
#     'visitorText': '',
#     'homeText': 'CU Defensive REBOUND by Scheierman, Baylor'},
#    {'score': '12-16',
#     'time': '14:18',
#     'visitorText': '',
#     'homeText': "Jumper GOOD by CU's Ashworth, Steven"},
#    {'score': '15-16',
#     'time': '13:52',
#     'visitorText': "3 Pointer GOOD by Butler's Telfort, Jahmyl",
#     'homeText': ''},
#    {'score': '',
#     'time': '13:52',
#     'visitorText': 'Butler Assist by Bizjack, Finley',
#     'homeText': ''},
#    {'score': '15-18',
#     'time': '13:38',
#     'visitorText': '',
#     'homeText': "Jumper GOOD by CU's Kalkbrenner, Ryan"},
#    {'score': '',
#     'time': '13:38',
#     'visitorText': '',
#     'homeText': 'CU Assist by Scheierman, Baylor'},
#    {'score': '',
#     'time': '13:20',
#     'visitorText': "Jumper MISSED by Butler's Telfort, Jahmyl",
#     'homeText': ''},
#    {'score': '',
#     'time': '13:16',
#     'visitorText': '',
#     'homeText': 'CU Defensive REBOUND by Miller, Mason'},
#    {'score': '',
#     'time': '13:14',
#     'visitorText': '',
#     'homeText': "3 Pointer MISSED by CU's Scheierman, Baylor"},
#    {'score': '',
#     'time': '13:09',
#     'visitorText': 'Butler Defensive REBOUND by Moore, Landon',
#     'homeText': ''},
#    {'score': '',
#     'time': '13:03',
#     'visitorText': "Jumper MISSED by Butler's Moore, Landon",
#     'homeText': ''},
#    {'score': '',
#     'time': '13:00',
#     'visitorText': '',
#     'homeText': 'CU Defensive REBOUND by Scheierman, Baylor'},
#    {'score': '',
#     'time': '12:57',
#     'visitorText': '',
#     'homeText': "3 Pointer MISSED by CU's Miller, Mason"},
#    {'score': '',
#     'time': '12:53',
#     'visitorText': 'Butler Defensive REBOUND by Brooks, Pierre',
#     'homeText': ''},
#    {'score': '',
#     'time': '12:40',
#     'visitorText': '',
#     'homeText': "Foul on CU's Scheierman, Baylor"},
#    {'score': '',
#     'time': '12:40',
#     'visitorText': "Free Throw MISSED by Butler's Brooks, Pierre",
#     'homeText': ''},
#    {'score': '',
#     'time': '12:40',
#     'visitorText': 'Butler gets a REBOUND from a dead ball.',
#     'homeText': ''},
#    {'score': '',
#     'time': '12:40',
#     'visitorText': '',
#     'homeText': 'Subbing out for CU - Kalkbrenner, Ryan'},
#    {'score': '',
#     'time': '12:40',
#     'visitorText': '',
#     'homeText': 'Subbing out for CU - Miller, Mason'},
#    {'score': '',
#     'time': '12:40',
#     'visitorText': '',
#     'homeText': 'Subbing in for CU - Farabello, Francisco'},
#    {'score': '',
#     'time': '12:40',
#     'visitorText': '',
#     'homeText': 'Subbing in for CU - King, Fredrick'},
#    {'score': '',
#     'time': '12:40',
#     'visitorText': 'Subbing out for Butler - Moore, Landon',
#     'homeText': ''},
#    {'score': '',
#     'time': '12:40',
#     'visitorText': 'Subbing in for Butler - Davis, Dj',
#     'homeText': ''},
#    {'score': '16-18',
#     'time': '12:40',
#     'visitorText': "Free Throw GOOD by Butler's Brooks, Pierre",
#     'homeText': ''},
#    {'score': '',
#     'time': '12:40',
#     'visitorText': 'Subbing out for Butler - Brooks, Pierre',
#     'homeText': ''},
#    {'score': '',
#     'time': '12:40',
#     'visitorText': 'Subbing in for Butler - Cassia, Augusto',
#     'homeText': ''},
#    {'score': '',
#     'time': '12:22',
#     'visitorText': '',
#     'homeText': 'CU Turnover by Ashworth, Steven'},
#    {'score': '',
#     'time': '12:22',
#     'visitorText': 'Butler Steal by Cassia, Augusto',
#     'homeText': ''},
#    {'score': '',
#     'time': '12:09',
#     'visitorText': "Foul on Butler's Cassia, Augusto",
#     'homeText': ''},
#    {'score': '',
#     'time': '12:09',
#     'visitorText': 'Butler Turnover by Cassia, Augusto',
#     'homeText': ''},
#    {'score': '16-20',
#     'time': '11:48',
#     'visitorText': '',
#     'homeText': "Jumper GOOD by CU's Alexander, Trey"},
#    {'score': '18-20',
#     'time': '11:21',
#     'visitorText': "Slam Dunk GOOD by Butler's Screen, Andre",
#     'homeText': ''},
#    {'score': '',
#     'time': '11:07',
#     'visitorText': '',
#     'homeText': "Slam Dunk MISSED by CU's King, Fredrick"},
#    {'score': '',
#     'time': '11:07',
#     'visitorText': 'Butler Block by Screen, Andre',
#     'homeText': ''},
#    {'score': '',
#     'time': '11:02',
#     'visitorText': 'Butler Defensive REBOUND by Screen, Andre',
#     'homeText': ''},
#    {'score': '20-20',
#     'time': '11:00',
#     'visitorText': "Layup GOOD by Butler's Cassia, Augusto",
#     'homeText': ''},
#    {'score': '',
#     'time': '11:00',
#     'visitorText': 'Butler Assist by Davis, Dj',
#     'homeText': ''},
#    {'score': '',
#     'time': '10:59',
#     'visitorText': '',
#     'homeText': 'CU takes a 30-second time out.'},
#    {'score': '',
#     'time': '10:59',
#     'visitorText': 'Media timeout',
#     'homeText': ''},
#    {'score': '',
#     'time': '10:59',
#     'visitorText': '',
#     'homeText': 'Subbing out for CU - King, Fredrick'},
#    {'score': '',
#     'time': '10:59',
#     'visitorText': '',
#     'homeText': 'Subbing in for CU - Kalkbrenner, Ryan'},
#    {'score': '',
#     'time': '10:59',
#     'visitorText': 'Subbing out for Butler - Telfort, Jahmyl',
#     'homeText': ''},
#    {'score': '',
#     'time': '10:59',
#     'visitorText': 'Subbing out for Butler - Screen, Andre',
#     'homeText': ''},
#    {'score': '',
#     'time': '10:59',
#     'visitorText': 'Subbing in for Butler - Brooks, Pierre',
#     'homeText': ''},
#    {'score': '',
#     'time': '10:59',
#     'visitorText': 'Subbing in for Butler - Kapke, Boden',
#     'homeText': ''},
#    {'score': '',
#     'time': '10:42',
#     'visitorText': "Foul on Butler's Kapke, Boden",
#     'homeText': ''},
#    {'score': '20-21',
#     'time': '10:42',
#     'visitorText': '',
#     'homeText': "Free Throw GOOD by CU's Kalkbrenner, Ryan"},
#    {'score': '20-22',
#     'time': '10:42',
#     'visitorText': '',
#     'homeText': "Free Throw GOOD by CU's Kalkbrenner, Ryan"},
#    {'score': '23-22',
#     'time': '10:27',
#     'visitorText': "3 Pointer GOOD by Butler's Bizjack, Finley",
#     'homeText': ''},
#    {'score': '23-25',
#     'time': '10:12',
#     'visitorText': '',
#     'homeText': "3 Pointer GOOD by CU's Ashworth, Steven"},
#    {'score': '',
#     'time': '10:12',
#     'visitorText': '',
#     'homeText': 'CU Assist by Kalkbrenner, Ryan'},
#    {'score': '26-25',
#     'time': '09:59',
#     'visitorText': "3 Pointer GOOD by Butler's Davis, Dj",
#     'homeText': ''},
#    {'score': '',
#     'time': '09:50',
#     'visitorText': '',
#     'homeText': 'CU Turnover by Scheierman, Baylor'},
#    {'score': '',
#     'time': '09:50',
#     'visitorText': 'Subbing out for Butler - Cassia, Augusto',
#     'homeText': ''},
#    {'score': '',
#     'time': '09:50',
#     'visitorText': 'Subbing in for Butler - Telfort, Jahmyl',
#     'homeText': ''},
#    {'score': '29-25',
#     'time': '09:36',
#     'visitorText': "3 Pointer GOOD by Butler's Kapke, Boden",
#     'homeText': ''},
#    {'score': '',
#     'time': '09:36',
#     'visitorText': 'Butler Assist by Davis, Dj',
#     'homeText': ''},
#    {'score': '29-28',
#     'time': '09:22',
#     'visitorText': '',
#     'homeText': "3 Pointer GOOD by CU's Scheierman, Baylor"},
#    {'score': '',
#     'time': '09:22',
#     'visitorText': '',
#     'homeText': 'CU Assist by Alexander, Trey'},
#    {'score': '',
#     'time': '09:04',
#     'visitorText': "Jumper MISSED by Butler's Davis, Dj",
#     'homeText': ''},
#    {'score': '',
#     'time': '09:00',
#     'visitorText': '',
#     'homeText': 'CU Defensive REBOUND by Kalkbrenner, Ryan'},
#    {'score': '',
#     'time': '08:56',
#     'visitorText': '',
#     'homeText': "Jumper MISSED by CU's Scheierman, Baylor"},
#    {'score': '',
#     'time': '08:53',
#     'visitorText': 'Butler Defensive REBOUND by Kapke, Boden',
#     'homeText': ''},
#    {'score': '',
#     'time': '08:46',
#     'visitorText': "Jumper MISSED by Butler's Bizjack, Finley",
#     'homeText': ''},
#    {'score': '',
#     'time': '08:44',
#     'visitorText': '',
#     'homeText': 'CU Defensive REBOUND by Ashworth, Steven'},
#    {'score': '29-30',
#     'time': '08:30',
#     'visitorText': '',
#     'homeText': "Jumper GOOD by CU's Alexander, Trey"},
#    {'score': '',
#     'time': '08:08',
#     'visitorText': "3 Pointer MISSED by Butler's Brooks, Pierre",
#     'homeText': ''},
#    {'score': '',
#     'time': '08:05',
#     'visitorText': '',
#     'homeText': 'CU Defensive REBOUND by Scheierman, Baylor'},
#    {'score': '29-32',
#     'time': '07:52',
#     'visitorText': '',
#     'homeText': "Jumper GOOD by CU's Alexander, Trey"},
#    {'score': '',
#     'time': '07:34',
#     'visitorText': 'Media timeout',
#     'homeText': ''},
#    {'score': '',
#     'time': '07:34',
#     'visitorText': 'Subbing out for Butler - Bizjack, Finley',
#     'homeText': ''},
#    {'score': '',
#     'time': '07:34',
#     'visitorText': 'Subbing in for Butler - Moore, Landon',
#     'homeText': ''},
#    {'score': '',
#     'time': '07:21',
#     'visitorText': "Jumper MISSED by Butler's Telfort, Jahmyl",
#     'homeText': ''},
#    {'score': '',
#     'time': '07:21',
#     'visitorText': 'Butler gets a REBOUND from a dead ball.',
#     'homeText': ''},
#    {'score': '',
#     'time': '07:21',
#     'visitorText': 'Butler Turnover by team',
#     'homeText': ''},
#    {'score': '',
#     'time': '07:07',
#     'visitorText': '',
#     'homeText': "Jumper MISSED by CU's Alexander, Trey"},
#    {'score': '',
#     'time': '07:04',
#     'visitorText': 'Butler Defensive REBOUND by Kapke, Boden',
#     'homeText': ''},
#    {'score': '31-32',
#     'time': '06:53',
#     'visitorText': "Jumper GOOD by Butler's Telfort, Jahmyl",
#     'homeText': ''},
#    {'score': '31-34',
#     'time': '06:37',
#     'visitorText': '',
#     'homeText': "Jumper GOOD by CU's Kalkbrenner, Ryan"},
#    {'score': '',
#     'time': '06:37',
#     'visitorText': '',
#     'homeText': 'CU Assist by Alexander, Trey'},
#    {'score': '',
#     'time': '06:19',
#     'visitorText': "Layup MISSED by Butler's Brooks, Pierre",
#     'homeText': ''},
#    {'score': '',
#     'time': '06:16',
#     'visitorText': '',
#     'homeText': 'CU Defensive REBOUND by Farabello, Francisco'},
#    {'score': '',
#     'time': '06:11',
#     'visitorText': '',
#     'homeText': 'CU Turnover by Alexander, Trey'},
#    {'score': '',
#     'time': '06:11',
#     'visitorText': 'Butler Steal by Davis, Dj',
#     'homeText': ''},
#    {'score': '33-34',
#     'time': '06:01',
#     'visitorText': "Jumper GOOD by Butler's Davis, Dj",
#     'homeText': ''},
#    {'score': '33-36',
#     'time': '05:55',
#     'visitorText': '',
#     'homeText': "Slam Dunk GOOD by CU's Scheierman, Baylor"},
#    {'score': '',
#     'time': '05:55',
#     'visitorText': '',
#     'homeText': 'CU Assist by Ashworth, Steven'},
#    {'score': '',
#     'time': '05:28',
#     'visitorText': "Jumper MISSED by Butler's Moore, Landon",
#     'homeText': ''},
#    {'score': '',
#     'time': '05:24',
#     'visitorText': '',
#     'homeText': 'CU Defensive REBOUND by Farabello, Francisco'},
#    {'score': '',
#     'time': '05:22',
#     'visitorText': '',
#     'homeText': "3 Pointer MISSED by CU's Scheierman, Baylor"},
#    {'score': '',
#     'time': '05:16',
#     'visitorText': 'Butler Defensive REBOUND by Kapke, Boden',
#     'homeText': ''},
#    {'score': '',
#     'time': '05:04',
#     'visitorText': "3 Pointer MISSED by Butler's Kapke, Boden",
#     'homeText': ''},
#    {'score': '',
#     'time': '05:00',
#     'visitorText': '',
#     'homeText': 'CU Defensive REBOUND by Ashworth, Steven'},
#    {'score': '33-38',
#     'time': '04:53',
#     'visitorText': '',
#     'homeText': "Layup GOOD by CU's Scheierman, Baylor"},
#    {'score': '',
#     'time': '04:53',
#     'visitorText': '',
#     'homeText': 'CU Assist by Farabello, Francisco'},
#    {'score': '35-38',
#     'time': '04:33',
#     'visitorText': "Jumper GOOD by Butler's Telfort, Jahmyl",
#     'homeText': ''},
#    {'score': '',
#     'time': '04:11',
#     'visitorText': '',
#     'homeText': "3 Pointer MISSED by CU's Ashworth, Steven"},
#    {'score': '',
#     'time': '04:07',
#     'visitorText': 'Butler Defensive REBOUND by Davis, Dj',
#     'homeText': ''},
#    {'score': '',
#     'time': '04:03',
#     'visitorText': "Jumper MISSED by Butler's Brooks, Pierre",
#     'homeText': ''},
#    {'score': '',
#     'time': '04:00',
#     'visitorText': '',
#     'homeText': 'CU Defensive REBOUND by Alexander, Trey'},
#    {'score': '35-40',
#     'time': '03:54',
#     'visitorText': '',
#     'homeText': "Jumper GOOD by CU's Alexander, Trey"},
#    {'score': '37-40',
#     'time': '03:37',
#     'visitorText': "Layup GOOD by Butler's Telfort, Jahmyl",
#     'homeText': ''},
#    {'score': '',
#     'time': '03:28',
#     'visitorText': "Foul on Butler's Davis, Dj",
#     'homeText': ''},
#    {'score': '',
#     'time': '03:28',
#     'visitorText': 'Media timeout',
#     'homeText': ''},
#    {'score': '',
#     'time': '03:28',
#     'visitorText': 'Subbing out for Butler - Davis, Dj',
#     'homeText': ''},
#    {'score': '',
#     'time': '03:28',
#     'visitorText': 'Subbing out for Butler - Brooks, Pierre',
#     'homeText': ''},
#    {'score': '',
#     'time': '03:28',
#     'visitorText': 'Subbing out for Butler - Kapke, Boden',
#     'homeText': ''},
#    {'score': '',
#     'time': '03:28',
#     'visitorText': 'Subbing in for Butler - Cassia, Augusto',
#     'homeText': ''},
#    {'score': '',
#     'time': '03:28',
#     'visitorText': 'Subbing in for Butler - Bizjack, Finley',
#     'homeText': ''},
#    {'score': '',
#     'time': '03:28',
#     'visitorText': 'Subbing in for Butler - Screen, Andre',
#     'homeText': ''},
#    {'score': '37-42',
#     'time': '03:17',
#     'visitorText': '',
#     'homeText': "Jumper GOOD by CU's Farabello, Francisco"},
#    {'score': '',
#     'time': '03:04',
#     'visitorText': "3 Pointer MISSED by Butler's Telfort, Jahmyl",
#     'homeText': ''},
#    {'score': '',
#     'time': '03:01',
#     'visitorText': '',
#     'homeText': 'CU Defensive REBOUND by Alexander, Trey'},
#    {'score': '',
#     'time': '02:50',
#     'visitorText': "Foul on Butler's Cassia, Augusto",
#     'homeText': ''},
#    {'score': '',
#     'time': '02:50',
#     'visitorText': 'Subbing out for Butler - Cassia, Augusto',
#     'homeText': ''},
#    {'score': '',
#     'time': '02:50',
#     'visitorText': 'Subbing in for Butler - Brooks, Pierre',
#     'homeText': ''},
#    {'score': '37-43',
#     'time': '02:50',
#     'visitorText': '',
#     'homeText': "Free Throw GOOD by CU's Scheierman, Baylor"},
#    {'score': '37-44',
#     'time': '02:50',
#     'visitorText': '',
#     'homeText': "Free Throw GOOD by CU's Scheierman, Baylor"},
#    {'score': '',
#     'time': '02:27',
#     'visitorText': "Layup MISSED by Butler's Screen, Andre",
#     'homeText': ''},
#    {'score': '',
#     'time': '02:24',
#     'visitorText': '',
#     'homeText': 'CU Defensive REBOUND by Scheierman, Baylor'},
#    {'score': '37-47',
#     'time': '02:17',
#     'visitorText': '',
#     'homeText': "3 Pointer GOOD by CU's Alexander, Trey"},
#    {'score': '',
#     'time': '02:17',
#     'visitorText': '',
#     'homeText': 'CU Assist by Scheierman, Baylor'},
#    {'score': '',
#     'time': '02:12',
#     'visitorText': 'Butler takes a 30-second time out.',
#     'homeText': ''},
#    {'score': '',
#     'time': '01:58',
#     'visitorText': '',
#     'homeText': "Foul on CU's Farabello, Francisco"},
#    {'score': '39-47',
#     'time': '01:49',
#     'visitorText': "Jumper GOOD by Butler's Moore, Landon",
#     'homeText': ''},
#    {'score': '',
#     'time': '01:36',
#     'visitorText': "Foul on Butler's Telfort, Jahmyl",
#     'homeText': ''},
#    {'score': '',
#     'time': '01:36',
#     'visitorText': '',
#     'homeText': "Free Throw MISSED by CU's Kalkbrenner, Ryan"},
#    {'score': '',
#     'time': '01:35',
#     'visitorText': 'Butler Defensive REBOUND by Telfort, Jahmyl',
#     'homeText': ''},
#    {'score': '',
#     'time': '01:14',
#     'visitorText': "Jumper MISSED by Butler's Bizjack, Finley",
#     'homeText': ''},
#    {'score': '',
#     'time': '01:11',
#     'visitorText': '',
#     'homeText': 'CU Defensive REBOUND by Ashworth, Steven'},
#    {'score': '39-49',
#     'time': '00:59',
#     'visitorText': '',
#     'homeText': "Layup GOOD by CU's Scheierman, Baylor"},
#    {'score': '42-49',
#     'time': '00:42',
#     'visitorText': "3 Pointer GOOD by Butler's Brooks, Pierre",
#     'homeText': ''},
#    {'score': '',
#     'time': '00:42',
#     'visitorText': 'Butler Assist by Telfort, Jahmyl',
#     'homeText': ''},
#    {'score': '',
#     'time': '00:05',
#     'visitorText': '',
#     'homeText': "3 Pointer MISSED by CU's Ashworth, Steven"},
#    {'score': '',
#     'time': '00:01',
#     'visitorText': 'Butler Defensive REBOUND by Moore, Landon',
#     'homeText': ''},
#    {'score': '45-49',
#     'time': '00:00',
#     'visitorText': "3 Pointer GOOD by Butler's Bizjack, Finley",
#     'homeText': ''},
#    {'score': '',
#     'time': '00:00',
#     'visitorText': 'Butler Assist by Moore, Landon',
#     'homeText': ''}]},
#  {'periodNumber': '2',
#   'periodDisplay': '2nd Half',
#   'playStats': [{'score': '',
#     'time': '20:00',
#     'visitorText': '',
#     'homeText': 'Subbing out for CU - Farabello, Francisco'},
#    {'score': '',
#     'time': '20:00',
#     'visitorText': '',
#     'homeText': 'Subbing in for CU - Miller, Mason'},
#    {'score': '',
#     'time': '20:00',
#     'visitorText': 'Subbing out for Butler - Bizjack, Finley',
#     'homeText': ''},
#    {'score': '',
#     'time': '20:00',
#     'visitorText': 'Subbing out for Butler - Screen, Andre',
#     'homeText': ''},
#    {'score': '',
#     'time': '20:00',
#     'visitorText': 'Subbing in for Butler - Thomas, Jalen',
#     'homeText': ''},
#    {'score': '',
#     'time': '20:00',
#     'visitorText': 'Subbing in for Butler - Davis, Dj',
#     'homeText': ''},
#    {'score': '',
#     'time': '19:42',
#     'visitorText': "Jumper MISSED by Butler's Thomas, Jalen",
#     'homeText': ''},
#    {'score': '',
#     'time': '19:36',
#     'visitorText': '',
#     'homeText': 'CU Defensive REBOUND by Alexander, Trey'},
#    {'score': '',
#     'time': '19:32',
#     'visitorText': '',
#     'homeText': "Foul on CU's Kalkbrenner, Ryan"},
#    {'score': '',
#     'time': '19:32',
#     'visitorText': '',
#     'homeText': 'CU Turnover by Kalkbrenner, Ryan'},
#    {'score': '47-49',
#     'time': '19:19',
#     'visitorText': "Layup GOOD by Butler's Brooks, Pierre",
#     'homeText': ''},
#    {'score': '',
#     'time': '19:19',
#     'visitorText': 'Butler Assist by Telfort, Jahmyl',
#     'homeText': ''},
#    {'score': '47-52',
#     'time': '18:49',
#     'visitorText': '',
#     'homeText': "3 Pointer GOOD by CU's Ashworth, Steven"},
#    {'score': '',
#     'time': '18:49',
#     'visitorText': '',
#     'homeText': 'CU Assist by Alexander, Trey'},
#    {'score': '',
#     'time': '18:30',
#     'visitorText': '',
#     'homeText': "Foul on CU's Ashworth, Steven"},
#    {'score': '48-52',
#     'time': '18:30',
#     'visitorText': "Free Throw GOOD by Butler's Davis, Dj",
#     'homeText': ''},
#    {'score': '49-52',
#     'time': '18:30',
#     'visitorText': "Free Throw GOOD by Butler's Davis, Dj",
#     'homeText': ''},
#    {'score': '50-52',
#     'time': '18:30',
#     'visitorText': "Free Throw GOOD by Butler's Davis, Dj",
#     'homeText': ''},
#    {'score': '',
#     'time': '18:19',
#     'visitorText': "Foul on Butler's Thomas, Jalen",
#     'homeText': ''},
#    {'score': '',
#     'time': '18:18',
#     'visitorText': '',
#     'homeText': "3 Pointer MISSED by CU's Alexander, Trey"},
#    {'score': '',
#     'time': '18:13',
#     'visitorText': '',
#     'homeText': 'CU Offensive REBOUND by Kalkbrenner, Ryan'},
#    {'score': '',
#     'time': '18:05',
#     'visitorText': '',
#     'homeText': "Jumper MISSED by CU's Alexander, Trey"},
#    {'score': '',
#     'time': '18:02',
#     'visitorText': 'Butler Defensive REBOUND by Thomas, Jalen',
#     'homeText': ''},
#    {'score': '53-52',
#     'time': '17:56',
#     'visitorText': "3 Pointer GOOD by Butler's Brooks, Pierre",
#     'homeText': ''},
#    {'score': '',
#     'time': '17:56',
#     'visitorText': 'Butler Assist by Davis, Dj',
#     'homeText': ''},
#    {'score': '53-54',
#     'time': '17:44',
#     'visitorText': '',
#     'homeText': "Jumper GOOD by CU's Ashworth, Steven"},
#    {'score': '55-54',
#     'time': '17:26',
#     'visitorText': "Layup GOOD by Butler's Brooks, Pierre",
#     'homeText': ''},
#    {'score': '',
#     'time': '17:26',
#     'visitorText': 'Butler Assist by Davis, Dj',
#     'homeText': ''},
#    {'score': '',
#     'time': '17:20',
#     'visitorText': "Foul on Butler's Moore, Landon",
#     'homeText': ''},
#    {'score': '',
#     'time': '17:15',
#     'visitorText': '',
#     'homeText': "3 Pointer MISSED by CU's Scheierman, Baylor"},
#    {'score': '',
#     'time': '17:10',
#     'visitorText': '',
#     'homeText': 'CU Offensive REBOUND by Kalkbrenner, Ryan'},
#    {'score': '55-56',
#     'time': '17:09',
#     'visitorText': '',
#     'homeText': "Layup GOOD by CU's Kalkbrenner, Ryan"},
#    {'score': '57-56',
#     'time': '16:54',
#     'visitorText': "Jumper GOOD by Butler's Telfort, Jahmyl",
#     'homeText': ''},
#    {'score': '',
#     'time': '16:34',
#     'visitorText': '',
#     'homeText': "3 Pointer MISSED by CU's Alexander, Trey"},
#    {'score': '',
#     'time': '16:32',
#     'visitorText': 'Butler Defensive REBOUND by team',
#     'homeText': ''},
#    {'score': '',
#     'time': '16:32',
#     'visitorText': 'Subbing out for Butler - Thomas, Jalen',
#     'homeText': ''},
#    {'score': '',
#     'time': '16:32',
#     'visitorText': 'Subbing in for Butler - Kapke, Boden',
#     'homeText': ''},
#    {'score': '60-56',
#     'time': '16:23',
#     'visitorText': "3 Pointer GOOD by Butler's Kapke, Boden",
#     'homeText': ''},
#    {'score': '',
#     'time': '16:23',
#     'visitorText': 'Butler Assist by Moore, Landon',
#     'homeText': ''},
#    {'score': '60-58',
#     'time': '16:01',
#     'visitorText': '',
#     'homeText': "Jumper GOOD by CU's Scheierman, Baylor"},
#    {'score': '',
#     'time': '15:36',
#     'visitorText': "Jumper MISSED by Butler's Brooks, Pierre",
#     'homeText': ''},
#    {'score': '',
#     'time': '15:33',
#     'visitorText': '',
#     'homeText': 'CU Defensive REBOUND by Kalkbrenner, Ryan'},
#    {'score': '',
#     'time': '15:27',
#     'visitorText': '',
#     'homeText': 'CU Turnover by Scheierman, Baylor'},
#    {'score': '',
#     'time': '15:27',
#     'visitorText': 'Media timeout',
#     'homeText': ''},
#    {'score': '',
#     'time': '15:27',
#     'visitorText': '',
#     'homeText': 'Subbing out for CU - Miller, Mason'},
#    {'score': '',
#     'time': '15:27',
#     'visitorText': '',
#     'homeText': 'Subbing in for CU - Farabello, Francisco'},
#    {'score': '',
#     'time': '15:27',
#     'visitorText': 'Subbing out for Butler - Telfort, Jahmyl',
#     'homeText': ''},
#    {'score': '',
#     'time': '15:27',
#     'visitorText': 'Subbing in for Butler - Cassia, Augusto',
#     'homeText': ''},
#    {'score': '62-58',
#     'time': '15:16',
#     'visitorText': "Jumper GOOD by Butler's Davis, Dj",
#     'homeText': ''},
#    {'score': '',
#     'time': '15:04',
#     'visitorText': "Foul on Butler's Cassia, Augusto",
#     'homeText': ''},
#    {'score': '',
#     'time': '14:55',
#     'visitorText': "Foul on Butler's Brooks, Pierre",
#     'homeText': ''},
#    {'score': '62-59',
#     'time': '14:55',
#     'visitorText': '',
#     'homeText': "Free Throw GOOD by CU's Scheierman, Baylor"},
#    {'score': '',
#     'time': '14:55',
#     'visitorText': '',
#     'homeText': "Free Throw MISSED by CU's Scheierman, Baylor"},
#    {'score': '',
#     'time': '14:52',
#     'visitorText': 'Butler Defensive REBOUND by Cassia, Augusto',
#     'homeText': ''},
#    {'score': '',
#     'time': '14:40',
#     'visitorText': 'Butler Turnover by Davis, Dj',
#     'homeText': ''},
#    {'score': '',
#     'time': '14:40',
#     'visitorText': '',
#     'homeText': 'CU Steal by Kalkbrenner, Ryan'},
#    {'score': '62-61',
#     'time': '14:20',
#     'visitorText': '',
#     'homeText': "Layup GOOD by CU's Farabello, Francisco"},
#    {'score': '',
#     'time': '14:20',
#     'visitorText': '',
#     'homeText': 'CU Assist by Alexander, Trey'},
#    {'score': '',
#     'time': '14:01',
#     'visitorText': '',
#     'homeText': "Foul on CU's Farabello, Francisco"},
#    {'score': '63-61',
#     'time': '14:01',
#     'visitorText': "Free Throw GOOD by Butler's Moore, Landon",
#     'homeText': ''},
#    {'score': '64-61',
#     'time': '14:01',
#     'visitorText': "Free Throw GOOD by Butler's Moore, Landon",
#     'homeText': ''},
#    {'score': '',
#     'time': '14:01',
#     'visitorText': 'Subbing out for Butler - Davis, Dj',
#     'homeText': ''},
#    {'score': '',
#     'time': '14:01',
#     'visitorText': 'Subbing out for Butler - Brooks, Pierre',
#     'homeText': ''},
#    {'score': '',
#     'time': '14:01',
#     'visitorText': 'Subbing in for Butler - Telfort, Jahmyl',
#     'homeText': ''},
#    {'score': '',
#     'time': '14:01',
#     'visitorText': 'Subbing in for Butler - Bizjack, Finley',
#     'homeText': ''},
#    {'score': '65-61',
#     'time': '14:01',
#     'visitorText': "Free Throw GOOD by Butler's Moore, Landon",
#     'homeText': ''},
#    {'score': '',
#     'time': '13:39',
#     'visitorText': '',
#     'homeText': "Jumper MISSED by CU's Ashworth, Steven"},
#    {'score': '',
#     'time': '13:35',
#     'visitorText': 'Butler Defensive REBOUND by Cassia, Augusto',
#     'homeText': ''},
#    {'score': '',
#     'time': '13:29',
#     'visitorText': "3 Pointer MISSED by Butler's Moore, Landon",
#     'homeText': ''},
#    {'score': '',
#     'time': '13:25',
#     'visitorText': '',
#     'homeText': 'CU Defensive REBOUND by Alexander, Trey'},
#    {'score': '65-63',
#     'time': '13:13',
#     'visitorText': '',
#     'homeText': "Jumper GOOD by CU's Ashworth, Steven"},
#    {'score': '67-63',
#     'time': '12:47',
#     'visitorText': "Jumper GOOD by Butler's Telfort, Jahmyl",
#     'homeText': ''},
#    {'score': '67-65',
#     'time': '12:39',
#     'visitorText': '',
#     'homeText': "Slam Dunk GOOD by CU's Scheierman, Baylor"},
#    {'score': '',
#     'time': '12:39',
#     'visitorText': "Foul on Butler's Kapke, Boden",
#     'homeText': ''},
#    {'score': '',
#     'time': '12:39',
#     'visitorText': 'Subbing out for Butler - Cassia, Augusto',
#     'homeText': ''},
#    {'score': '',
#     'time': '12:39',
#     'visitorText': 'Subbing in for Butler - Brooks, Pierre',
#     'homeText': ''},
#    {'score': '',
#     'time': '12:39',
#     'visitorText': '',
#     'homeText': 'CU Assist by Ashworth, Steven'},
#    {'score': '67-66',
#     'time': '12:39',
#     'visitorText': '',
#     'homeText': "Free Throw GOOD by CU's Scheierman, Baylor"},
#    {'score': '',
#     'time': '12:25',
#     'visitorText': "Jumper MISSED by Butler's Telfort, Jahmyl",
#     'homeText': ''},
#    {'score': '',
#     'time': '12:22',
#     'visitorText': '',
#     'homeText': 'CU Defensive REBOUND by Scheierman, Baylor'},
#    {'score': '67-68',
#     'time': '12:15',
#     'visitorText': '',
#     'homeText': "Jumper GOOD by CU's Alexander, Trey"},
#    {'score': '69-68',
#     'time': '11:57',
#     'visitorText': "Jumper GOOD by Butler's Bizjack, Finley",
#     'homeText': ''},
#    {'score': '',
#     'time': '11:46',
#     'visitorText': "Foul on Butler's Kapke, Boden",
#     'homeText': ''},
#    {'score': '',
#     'time': '11:46',
#     'visitorText': 'Media timeout',
#     'homeText': ''},
#    {'score': '',
#     'time': '11:46',
#     'visitorText': 'Subbing out for Butler - Moore, Landon',
#     'homeText': ''},
#    {'score': '',
#     'time': '11:46',
#     'visitorText': 'Subbing out for Butler - Kapke, Boden',
#     'homeText': ''},
#    {'score': '',
#     'time': '11:46',
#     'visitorText': 'Subbing in for Butler - Davis, Dj',
#     'homeText': ''},
#    {'score': '',
#     'time': '11:46',
#     'visitorText': 'Subbing in for Butler - Screen, Andre',
#     'homeText': ''},
#    {'score': '',
#     'time': '11:29',
#     'visitorText': '',
#     'homeText': "Jumper MISSED by CU's Ashworth, Steven"},
#    {'score': '',
#     'time': '11:26',
#     'visitorText': '',
#     'homeText': 'CU Offensive REBOUND by team'},
#    {'score': '',
#     'time': '11:12',
#     'visitorText': '',
#     'homeText': "Jumper MISSED by CU's Scheierman, Baylor"},
#    {'score': '',
#     'time': '11:12',
#     'visitorText': '',
#     'homeText': 'CU Offensive REBOUND by Scheierman, Baylor'},
#    {'score': '',
#     'time': '11:12',
#     'visitorText': "Foul on Butler's Bizjack, Finley",
#     'homeText': ''},
#    {'score': '',
#     'time': '11:12',
#     'visitorText': '',
#     'homeText': "Free Throw MISSED by CU's Scheierman, Baylor"},
#    {'score': '',
#     'time': '11:12',
#     'visitorText': '',
#     'homeText': 'CU gets a REBOUND from a dead ball.'},
#    {'score': '69-69',
#     'time': '11:12',
#     'visitorText': '',
#     'homeText': "Free Throw GOOD by CU's Scheierman, Baylor"},
#    {'score': '71-69',
#     'time': '10:56',
#     'visitorText': "Layup GOOD by Butler's Screen, Andre",
#     'homeText': ''},
#    {'score': '',
#     'time': '10:56',
#     'visitorText': 'Butler Assist by Telfort, Jahmyl',
#     'homeText': ''},
#    {'score': '',
#     'time': '10:30',
#     'visitorText': '',
#     'homeText': "Layup MISSED by CU's Farabello, Francisco"},
#    {'score': '',
#     'time': '10:25',
#     'visitorText': 'Butler Defensive REBOUND by Screen, Andre',
#     'homeText': ''},
#    {'score': '73-69',
#     'time': '10:14',
#     'visitorText': "Jumper GOOD by Butler's Telfort, Jahmyl",
#     'homeText': ''},
#    {'score': '73-72',
#     'time': '09:55',
#     'visitorText': '',
#     'homeText': "3 Pointer GOOD by CU's Ashworth, Steven"},
#    {'score': '',
#     'time': '09:55',
#     'visitorText': '',
#     'homeText': 'CU Assist by Scheierman, Baylor'},
#    {'score': '75-72',
#     'time': '09:31',
#     'visitorText': "Jumper GOOD by Butler's Telfort, Jahmyl",
#     'homeText': ''},
#    {'score': '',
#     'time': '09:22',
#     'visitorText': '',
#     'homeText': "3 Pointer MISSED by CU's Ashworth, Steven"},
#    {'score': '',
#     'time': '09:19',
#     'visitorText': 'Butler Defensive REBOUND by Brooks, Pierre',
#     'homeText': ''},
#    {'score': '',
#     'time': '09:07',
#     'visitorText': "Layup MISSED by Butler's Brooks, Pierre",
#     'homeText': ''},
#    {'score': '',
#     'time': '09:07',
#     'visitorText': 'Butler Offensive REBOUND by Screen, Andre',
#     'homeText': ''},
#    {'score': '',
#     'time': '09:07',
#     'visitorText': '',
#     'homeText': 'CU Block by Kalkbrenner, Ryan'},
#    {'score': '',
#     'time': '09:03',
#     'visitorText': "Layup MISSED by Butler's Screen, Andre",
#     'homeText': ''},
#    {'score': '',
#     'time': '09:00',
#     'visitorText': '',
#     'homeText': 'CU Defensive REBOUND by Alexander, Trey'},
#    {'score': '',
#     'time': '08:59',
#     'visitorText': "Foul on Butler's Bizjack, Finley",
#     'homeText': ''},
#    {'score': '75-73',
#     'time': '08:59',
#     'visitorText': '',
#     'homeText': "Free Throw GOOD by CU's Kalkbrenner, Ryan"},
#    {'score': '75-74',
#     'time': '08:59',
#     'visitorText': '',
#     'homeText': "Free Throw GOOD by CU's Kalkbrenner, Ryan"},
#    {'score': '77-74',
#     'time': '08:44',
#     'visitorText': "Jumper GOOD by Butler's Brooks, Pierre",
#     'homeText': ''},
#    {'score': '77-77',
#     'time': '08:31',
#     'visitorText': '',
#     'homeText': "3 Pointer GOOD by CU's Alexander, Trey"},
#    {'score': '',
#     'time': '08:31',
#     'visitorText': '',
#     'homeText': 'CU Assist by Ashworth, Steven'},
#    {'score': '79-77',
#     'time': '08:11',
#     'visitorText': "Layup GOOD by Butler's Davis, Dj",
#     'homeText': ''},
#    {'score': '',
#     'time': '08:11',
#     'visitorText': 'Butler Assist by Screen, Andre',
#     'homeText': ''},
#    {'score': '',
#     'time': '07:58',
#     'visitorText': "Foul on Butler's Screen, Andre",
#     'homeText': ''},
#    {'score': '79-78',
#     'time': '07:58',
#     'visitorText': '',
#     'homeText': "Free Throw GOOD by CU's Ashworth, Steven"},
#    {'score': '',
#     'time': '07:58',
#     'visitorText': 'Subbing out for Butler - Brooks, Pierre',
#     'homeText': ''},
#    {'score': '',
#     'time': '07:58',
#     'visitorText': 'Subbing out for Butler - Screen, Andre',
#     'homeText': ''},
#    {'score': '',
#     'time': '07:58',
#     'visitorText': 'Subbing in for Butler - Cassia, Augusto',
#     'homeText': ''},
#    {'score': '',
#     'time': '07:58',
#     'visitorText': 'Subbing in for Butler - Thomas, Jalen',
#     'homeText': ''},
#    {'score': '79-79',
#     'time': '07:58',
#     'visitorText': '',
#     'homeText': "Free Throw GOOD by CU's Ashworth, Steven"},
#    {'score': '82-79',
#     'time': '07:40',
#     'visitorText': "3 Pointer GOOD by Butler's Bizjack, Finley",
#     'homeText': ''},
#    {'score': '',
#     'time': '07:40',
#     'visitorText': 'Butler Assist by Cassia, Augusto',
#     'homeText': ''},
#    {'score': '82-82',
#     'time': '07:22',
#     'visitorText': '',
#     'homeText': "3 Pointer GOOD by CU's Kalkbrenner, Ryan"},
#    {'score': '84-82',
#     'time': '06:58',
#     'visitorText': "Jumper GOOD by Butler's Thomas, Jalen",
#     'homeText': ''},
#    {'score': '',
#     'time': '06:58',
#     'visitorText': 'Butler Assist by Bizjack, Finley',
#     'homeText': ''},
#    {'score': '',
#     'time': '06:39',
#     'visitorText': '',
#     'homeText': "3 Pointer MISSED by CU's Alexander, Trey"},
#    {'score': '',
#     'time': '06:37',
#     'visitorText': 'Butler Defensive REBOUND by Thomas, Jalen',
#     'homeText': ''},
#    {'score': '87-82',
#     'time': '06:14',
#     'visitorText': "3 Pointer GOOD by Butler's Davis, Dj",
#     'homeText': ''},
#    {'score': '87-84',
#     'time': '05:57',
#     'visitorText': '',
#     'homeText': "Jumper GOOD by CU's Ashworth, Steven"},
#    {'score': '',
#     'time': '05:57',
#     'visitorText': 'Media timeout',
#     'homeText': ''},
#    {'score': '',
#     'time': '05:57',
#     'visitorText': 'Subbing out for Butler - Cassia, Augusto',
#     'homeText': ''},
#    {'score': '',
#     'time': '05:57',
#     'visitorText': 'Subbing in for Butler - Brooks, Pierre',
#     'homeText': ''},
#    {'score': '',
#     'time': '05:42',
#     'visitorText': "Layup MISSED by Butler's Brooks, Pierre",
#     'homeText': ''},
#    {'score': '',
#     'time': '05:42',
#     'visitorText': '',
#     'homeText': 'CU Block by Kalkbrenner, Ryan'},
#    {'score': '',
#     'time': '05:38',
#     'visitorText': 'Butler Offensive REBOUND by Brooks, Pierre',
#     'homeText': ''},
#    {'score': '',
#     'time': '05:35',
#     'visitorText': "3 Pointer MISSED by Butler's Davis, Dj",
#     'homeText': ''},
#    {'score': '',
#     'time': '05:31',
#     'visitorText': '',
#     'homeText': 'CU Defensive REBOUND by Kalkbrenner, Ryan'},
#    {'score': '87-86',
#     'time': '05:07',
#     'visitorText': '',
#     'homeText': "Layup GOOD by CU's Kalkbrenner, Ryan"},
#    {'score': '89-86',
#     'time': '04:42',
#     'visitorText': "Jumper GOOD by Butler's Davis, Dj",
#     'homeText': ''},
#    {'score': '89-88',
#     'time': '04:15',
#     'visitorText': '',
#     'homeText': "Jumper GOOD by CU's Scheierman, Baylor"},
#    {'score': '',
#     'time': '04:09',
#     'visitorText': 'Butler takes a 30-second time out.',
#     'homeText': ''},
#    {'score': '92-88',
#     'time': '04:05',
#     'visitorText': "3 Pointer GOOD by Butler's Davis, Dj",
#     'homeText': ''},
#    {'score': '',
#     'time': '04:05',
#     'visitorText': 'Butler Assist by Telfort, Jahmyl',
#     'homeText': ''},
#    {'score': '',
#     'time': '03:45',
#     'visitorText': '',
#     'homeText': "Jumper MISSED by CU's Scheierman, Baylor"},
#    {'score': '',
#     'time': '03:42',
#     'visitorText': '',
#     'homeText': 'CU Offensive REBOUND by Kalkbrenner, Ryan'},
#    {'score': '',
#     'time': '03:36',
#     'visitorText': '',
#     'homeText': "Jumper MISSED by CU's Kalkbrenner, Ryan"},
#    {'score': '',
#     'time': '03:33',
#     'visitorText': 'Butler Defensive REBOUND by Davis, Dj',
#     'homeText': ''},
#    {'score': '',
#     'time': '03:08',
#     'visitorText': "Jumper MISSED by Butler's Telfort, Jahmyl",
#     'homeText': ''},
#    {'score': '',
#     'time': '03:04',
#     'visitorText': '',
#     'homeText': 'CU Defensive REBOUND by Scheierman, Baylor'},
#    {'score': '',
#     'time': '03:02',
#     'visitorText': "Foul on Butler's Davis, Dj",
#     'homeText': ''},
#    {'score': '',
#     'time': '03:02',
#     'visitorText': 'Media timeout',
#     'homeText': ''},
#    {'score': '92-89',
#     'time': '03:02',
#     'visitorText': '',
#     'homeText': "Free Throw GOOD by CU's Ashworth, Steven"},
#    {'score': '92-90',
#     'time': '03:02',
#     'visitorText': '',
#     'homeText': "Free Throw GOOD by CU's Ashworth, Steven"},
#    {'score': '',
#     'time': '02:45',
#     'visitorText': "Jumper MISSED by Butler's Brooks, Pierre",
#     'homeText': ''},
#    {'score': '',
#     'time': '02:45',
#     'visitorText': 'Butler Offensive REBOUND by Brooks, Pierre',
#     'homeText': ''},
#    {'score': '',
#     'time': '02:45',
#     'visitorText': '',
#     'homeText': "Foul on CU's Alexander, Trey"},
#    {'score': '93-90',
#     'time': '02:45',
#     'visitorText': "Free Throw GOOD by Butler's Brooks, Pierre",
#     'homeText': ''},
#    {'score': '',
#     'time': '02:45',
#     'visitorText': "Free Throw MISSED by Butler's Brooks, Pierre",
#     'homeText': ''},
#    {'score': '',
#     'time': '02:44',
#     'visitorText': '',
#     'homeText': 'CU Defensive REBOUND by Kalkbrenner, Ryan'},
#    {'score': '',
#     'time': '02:32',
#     'visitorText': '',
#     'homeText': "Foul on CU's Kalkbrenner, Ryan"},
#    {'score': '',
#     'time': '02:32',
#     'visitorText': '',
#     'homeText': 'CU Turnover by Kalkbrenner, Ryan'},
#    {'score': '',
#     'time': '02:32',
#     'visitorText': 'Subbing out for Butler - Telfort, Jahmyl',
#     'homeText': ''},
#    {'score': '',
#     'time': '02:32',
#     'visitorText': 'Subbing in for Butler - Moore, Landon',
#     'homeText': ''},
#    {'score': '',
#     'time': '02:21',
#     'visitorText': "3 Pointer MISSED by Butler's Brooks, Pierre",
#     'homeText': ''},
#    {'score': '',
#     'time': '02:19',
#     'visitorText': '',
#     'homeText': 'CU Defensive REBOUND by Scheierman, Baylor'},
#    {'score': '93-92',
#     'time': '02:11',
#     'visitorText': '',
#     'homeText': "Jumper GOOD by CU's Ashworth, Steven"},
#    {'score': '',
#     'time': '02:10',
#     'visitorText': 'Subbing out for Butler - Moore, Landon',
#     'homeText': ''},
#    {'score': '',
#     'time': '02:10',
#     'visitorText': 'Subbing in for Butler - Telfort, Jahmyl',
#     'homeText': ''},
#    {'score': '95-92',
#     'time': '01:51',
#     'visitorText': "Jumper GOOD by Butler's Telfort, Jahmyl",
#     'homeText': ''},
#    {'score': '',
#     'time': '01:33',
#     'visitorText': '',
#     'homeText': "3 Pointer MISSED by CU's Scheierman, Baylor"},
#    {'score': '',
#     'time': '01:30',
#     'visitorText': 'Butler Defensive REBOUND by Bizjack, Finley',
#     'homeText': ''},
#    {'score': '',
#     'time': '01:10',
#     'visitorText': "Jumper MISSED by Butler's Brooks, Pierre",
#     'homeText': ''},
#    {'score': '',
#     'time': '01:08',
#     'visitorText': '',
#     'homeText': 'CU Defensive REBOUND by Alexander, Trey'},
#    {'score': '',
#     'time': '01:08',
#     'visitorText': "Foul on Butler's Thomas, Jalen",
#     'homeText': ''},
#    {'score': '95-93',
#     'time': '01:08',
#     'visitorText': '',
#     'homeText': "Free Throw GOOD by CU's Alexander, Trey"},
#    {'score': '95-94',
#     'time': '01:08',
#     'visitorText': '',
#     'homeText': "Free Throw GOOD by CU's Alexander, Trey"},
#    {'score': '97-94',
#     'time': '00:49',
#     'visitorText': "Jumper GOOD by Butler's Telfort, Jahmyl",
#     'homeText': ''},
#    {'score': '',
#     'time': '00:43',
#     'visitorText': '',
#     'homeText': "3 Pointer MISSED by CU's Ashworth, Steven"},
#    {'score': '',
#     'time': '00:38',
#     'visitorText': 'Butler Defensive REBOUND by Brooks, Pierre',
#     'homeText': ''},
#    {'score': '',
#     'time': '00:33',
#     'visitorText': '',
#     'homeText': "Foul on CU's Ashworth, Steven"},
#    {'score': '',
#     'time': '00:33',
#     'visitorText': '',
#     'homeText': 'CU takes a 30-second time out.'},
#    {'score': '',
#     'time': '00:33',
#     'visitorText': 'Butler takes a 30-second time out.',
#     'homeText': ''},
#    {'score': '',
#     'time': '00:33',
#     'visitorText': '',
#     'homeText': "Foul on CU's Alexander, Trey"},
#    {'score': '',
#     'time': '00:33',
#     'visitorText': "Free Throw MISSED by Butler's Brooks, Pierre",
#     'homeText': ''},
#    {'score': '',
#     'time': '00:32',
#     'visitorText': '',
#     'homeText': 'CU Defensive REBOUND by Scheierman, Baylor'},
#    {'score': '',
#     'time': '00:23',
#     'visitorText': '',
#     'homeText': "3 Pointer MISSED by CU's Alexander, Trey"},
#    {'score': '',
#     'time': '00:20',
#     'visitorText': '',
#     'homeText': 'CU Offensive REBOUND by Kalkbrenner, Ryan'},
#    {'score': '',
#     'time': '00:13',
#     'visitorText': '',
#     'homeText': "3 Pointer MISSED by CU's Alexander, Trey"},
#    {'score': '',
#     'time': '00:12',
#     'visitorText': 'Subbing out for Butler - Bizjack, Finley',
#     'homeText': ''},
#    {'score': '',
#     'time': '00:12',
#     'visitorText': 'Subbing in for Butler - Cassia, Augusto',
#     'homeText': ''},
#    {'score': '',
#     'time': '00:11',
#     'visitorText': '',
#     'homeText': 'CU Offensive REBOUND by team'},
#    {'score': '',
#     'time': '00:10',
#     'visitorText': "Foul on Butler's Thomas, Jalen",
#     'homeText': ''},
#    {'score': '',
#     'time': '00:10',
#     'visitorText': 'Subbing out for Butler - Cassia, Augusto',
#     'homeText': ''},
#    {'score': '',
#     'time': '00:10',
#     'visitorText': 'Subbing out for Butler - Thomas, Jalen',
#     'homeText': ''},
#    {'score': '',
#     'time': '00:10',
#     'visitorText': 'Subbing in for Butler - Bizjack, Finley',
#     'homeText': ''},
#    {'score': '',
#     'time': '00:10',
#     'visitorText': 'Subbing in for Butler - Kapke, Boden',
#     'homeText': ''},
#    {'score': '97-95',
#     'time': '00:10',
#     'visitorText': '',
#     'homeText': "Free Throw GOOD by CU's Kalkbrenner, Ryan"},
#    {'score': '97-96',
#     'time': '00:10',
#     'visitorText': '',
#     'homeText': "Free Throw GOOD by CU's Kalkbrenner, Ryan"},
#    {'score': '',
#     'time': '00:10',
#     'visitorText': '',
#     'homeText': 'CU takes a 30-second time out.'},
#    {'score': '',
#     'time': '00:10',
#     'visitorText': '',
#     'homeText': 'Subbing out for CU - Ashworth, Steven'},
#    {'score': '',
#     'time': '00:10',
#     'visitorText': '',
#     'homeText': 'Subbing in for CU - Miller, Mason'},
#    {'score': '',
#     'time': '00:10',
#     'visitorText': 'Butler Turnover by Davis, Dj',
#     'homeText': ''},
#    {'score': '',
#     'time': '00:10',
#     'visitorText': '',
#     'homeText': 'Subbing out for CU - Miller, Mason'},
#    {'score': '',
#     'time': '00:10',
#     'visitorText': '',
#     'homeText': 'Subbing in for CU - Ashworth, Steven'},
#    {'score': '',
#     'time': '00:10',
#     'visitorText': 'Subbing out for Butler - Bizjack, Finley',
#     'homeText': ''},
#    {'score': '',
#     'time': '00:10',
#     'visitorText': 'Subbing out for Butler - Kapke, Boden',
#     'homeText': ''},
#    {'score': '',
#     'time': '00:10',
#     'visitorText': 'Subbing in for Butler - Cassia, Augusto',
#     'homeText': ''},
#    {'score': '',
#     'time': '00:10',
#     'visitorText': 'Subbing in for Butler - Screen, Andre',
#     'homeText': ''},
#    {'score': '',
#     'time': '00:07',
#     'visitorText': '',
#     'homeText': 'CU Turnover by Alexander, Trey'},
#    {'score': '',
#     'time': '00:07',
#     'visitorText': '',
#     'homeText': 'Subbing out for CU - Ashworth, Steven'},
#    {'score': '',
#     'time': '00:07',
#     'visitorText': '',
#     'homeText': 'Subbing in for CU - Miller, Mason'},
#    {'score': '',
#     'time': '00:07',
#     'visitorText': 'Subbing out for Butler - Cassia, Augusto',
#     'homeText': ''},
#    {'score': '',
#     'time': '00:07',
#     'visitorText': 'Subbing out for Butler - Screen, Andre',
#     'homeText': ''},
#    {'score': '',
#     'time': '00:07',
#     'visitorText': 'Subbing in for Butler - Bizjack, Finley',
#     'homeText': ''},
#    {'score': '',
#     'time': '00:07',
#     'visitorText': 'Subbing in for Butler - Moore, Landon',
#     'homeText': ''},
#    {'score': '',
#     'time': '00:06',
#     'visitorText': '',
#     'homeText': "Foul on CU's Farabello, Francisco"},
#    {'score': '',
#     'time': '00:06',
#     'visitorText': '',
#     'homeText': 'Subbing out for CU - Miller, Mason'},
#    {'score': '',
#     'time': '00:06',
#     'visitorText': '',
#     'homeText': 'Subbing in for CU - Ashworth, Steven'},
#    {'score': '',
#     'time': '00:06',
#     'visitorText': 'Subbing out for Butler - Davis, Dj',
#     'homeText': ''},
#    {'score': '',
#     'time': '00:06',
#     'visitorText': 'Subbing in for Butler - Kapke, Boden',
#     'homeText': ''},
#    {'score': '98-96',
#     'time': '00:06',
#     'visitorText': "Free Throw GOOD by Butler's Kapke, Boden",
#     'homeText': ''},
#    {'score': '99-96',
#     'time': '00:06',
#     'visitorText': "Free Throw GOOD by Butler's Kapke, Boden",
#     'homeText': ''},
#    {'score': '',
#     'time': '00:06',
#     'visitorText': 'Subbing out for Butler - Kapke, Boden',
#     'homeText': ''},
#    {'score': '',
#     'time': '00:06',
#     'visitorText': 'Subbing in for Butler - Cassia, Augusto',
#     'homeText': ''},
#    {'score': '',
#     'time': '00:05',
#     'visitorText': "Foul on Butler's Cassia, Augusto",
#     'homeText': ''},
#    {'score': '99-97',
#     'time': '00:05',
#     'visitorText': '',
#     'homeText': "Free Throw GOOD by CU's Alexander, Trey"},
#    {'score': '',
#     'time': '00:05',
#     'visitorText': 'Subbing out for Butler - Cassia, Augusto',
#     'homeText': ''},
#    {'score': '',
#     'time': '00:05',
#     'visitorText': 'Subbing in for Butler - Kapke, Boden',
#     'homeText': ''},
#    {'score': '',
#     'time': '00:05',
#     'visitorText': 'Subbing out for Butler - Bizjack, Finley',
#     'homeText': ''},
#    {'score': '',
#     'time': '00:05',
#     'visitorText': 'Subbing in for Butler - Cassia, Augusto',
#     'homeText': ''},
#    {'score': '99-98',
#     'time': '00:05',
#     'visitorText': '',
#     'homeText': "Free Throw GOOD by CU's Alexander, Trey"},
#    {'score': '',
#     'time': '00:05',
#     'visitorText': '',
#     'homeText': 'Subbing out for CU - Ashworth, Steven'},
#    {'score': '',
#     'time': '00:05',
#     'visitorText': '',
#     'homeText': 'Subbing in for CU - Miller, Mason'},
#    {'score': '',
#     'time': '00:00',
#     'visitorText': 'Butler Turnover by Moore, Landon',
#     'homeText': ''},
#    {'score': '',
#     'time': '00:00',
#     'visitorText': '',
#     'homeText': 'CU Steal by Farabello, Francisco'}]}]

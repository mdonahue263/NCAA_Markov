# %%
import numpy as np
import pandas as pd
from itertools import product
from helper_functions.clean_transitions import clean_transition_column

# %%
data = pd.read_excel('ALL_VALID_TRANSITIONS.xlsx')

# %%
data.head()
# Out:
#        Transition  Period                                           filename  \
# 0  ('Bi0', 'Ai3')       1  6197002_Play-By-Play for Colgate vs Weber St.....
# 1  ('Ai3', 'Ar0')       1  6197002_Play-By-Play for Colgate vs Weber St.....
# 2  ('Ar0', 'Ar0')       1  6197002_Play-By-Play for Colgate vs Weber St.....
# 3  ('Ar0', 'Br0')       1  6197002_Play-By-Play for Colgate vs Weber St.....
# 4  ('Br0', 'Ar0')       1  6197002_Play-By-Play for Colgate vs Weber St.....
#
#    is_valid
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True

# %%
#going to test a lopsided game - marquette vs depaul on 2/21/2024 where marquette won 105-71

# %%
marq_data = data[data['filename'].str.contains('Marquette')].copy().reset_index(drop=True)

# %%
#is number of games reasonable
len(marq_data['filename'].unique())
# Out:
# 19

# %%
#let's force marquette as team A and depaul as team B

# %%
marq_data
# Out:
#           Transition  Period  \
# 0     ('Bi0', 'Ai2')       1
# 1     ('Ai2', 'Br0')       1
# 2     ('Br0', 'Ar0')       1
# 3     ('Ar0', 'Bi3')       1
# 4     ('Bi3', 'Ar0')       1
# ...              ...     ...
# 3742  ('Bi3', 'Bf0')       2
# 3743  ('Bf0', 'Br0')       2
# 3744  ('Br0', 'Ar0')       2
# 3745  ('Ar0', 'Ai0')       2
# 3746  ('Ai0', 'Br0')       2
#
#                                               filename  is_valid
# 0      6197093_Play-By-Play for Marquette vs UCLA.xlsx      True
# 1      6197093_Play-By-Play for Marquette vs UCLA.xlsx      True
# 2      6197093_Play-By-Play for Marquette vs UCLA.xlsx      True
# 3      6197093_Play-By-Play for Marquette vs UCLA.xlsx      True
# 4      6197093_Play-By-Play for Marquette vs UCLA.xlsx      True
# ...                                                ...       ...
# 3742  6200793_Play-By-Play for UConn vs Marquette.xlsx      True
# 3743  6200793_Play-By-Play for UConn vs Marquette.xlsx      True
# 3744  6200793_Play-By-Play for UConn vs Marquette.xlsx      True
# 3745  6200793_Play-By-Play for UConn vs Marquette.xlsx      True
# 3746  6200793_Play-By-Play for UConn vs Marquette.xlsx      True
#
# [3747 rows x 4 columns]

# %%
#primitive method - iterate through unique games. Wherever "marquette" comes after "vs",
#operate on transition column. Replace "A" with "TEMP", replace "B" with "A", replace "TEMP" with "B"

#can't quite get this. even more primitive - iterate through all rows...

# %%
for fname in marq_data['filename'].unique():
    if fname.find('Marquette')>fname.find('vs'):
        marq_data.loc[marq_data['filename']==fname, 'Transition'] = marq_data.loc[marq_data['filename']==fname, 'Transition'].str.replace('A','TEMP')
        marq_data.loc[marq_data['filename']==fname, 'Transition'] = marq_data.loc[marq_data['filename']==fname, 'Transition'].str.replace('B','A')
        marq_data.loc[marq_data['filename']==fname, 'Transition'] = marq_data.loc[marq_data['filename']==fname, 'Transition'].str.replace('TEMP','B')

# %%
# for i in range(len(marq_data)):
#     curr_name = marq_data['filename'][i]
#     if curr_name.find('Marquette')>curr_name.find('vs'):
#         string_copy = marq_data['Transition'][i]
#         new_string = string_copy.replace('A','TEMP').replace('B','A').replace('TEMP','B')
#         marq_data.loc[i, 'Transition']=new_string

# %%
#now clean transition column
marq_data['Transition']=clean_transition_column(marq_data['Transition'])

# %%
possible_states = ['Ai0',
'Ai1',
'Ai2',
'Ai3',
'Ar0',
'Af0',
'Af1',
'Af2',
'Af3',
'Bi0',
'Bi1',
'Bi2',
'Bi3',
'Br0',
'Bf0',
'Bf1',
'Bf2',
'Bf3']

possible_transitions = list(product(possible_states,possible_states))

# %%
transitions_agg_marq = marq_data.groupby('Transition')['Period'].count().reset_index()

# %%
for t in possible_transitions:
    if t not in list(transitions_agg_marq['Transition'].values):
        curr_row = pd.DataFrame([[t, 0]], columns=['Transition','Period'])
        transitions_agg_marq=pd.concat([transitions_agg_marq,curr_row])

# %%
transitions_agg_marq = transitions_agg_marq.rename(columns={'Period':'Count'})

# %%
transitions_agg_marq
# Out:
#     Transition  Count
# 0   (Af0, Af0)     33
# 1   (Af0, Af1)     90
# 2   (Af0, Ar0)      1
# 3   (Af0, Bi0)      1
# 4   (Af0, Bi1)     25
# ..         ...    ...
# 0   (Bf3, Br0)      0
# 0   (Bf3, Bf0)      0
# 0   (Bf3, Bf1)      0
# 0   (Bf3, Bf2)      0
# 0   (Bf3, Bf3)      0
#
# [324 rows x 2 columns]

# %%
transitions_agg_marq['Starting_State'] = [x[0] for x in transitions_agg_marq['Transition']]
transitions_agg_marq['Ending_State'] = [x[1] for x in transitions_agg_marq['Transition']]

# %%
transitions_agg_marq=transitions_agg_marq[['Starting_State','Ending_State','Count']]

# %%
transition_matrix_marq = transitions_agg_marq.pivot(index='Starting_State', columns='Ending_State', values='Count').fillna(0)

# %%
transition_matrix_marq = transition_matrix_marq.div(transition_matrix_marq.sum(axis=1), axis=0)

# %%
transition_matrix_marq=transition_matrix_marq.fillna(0)

# %%
transition_matrix_marq
# Out:
# Ending_State         Af0       Af1       Af2  Af3       Ai0       Ai1  \
# Starting_State
# Af0             0.200000  0.545455  0.000000  0.0  0.000000  0.000000
# Af1             0.000000  0.042105  0.000000  0.0  0.000000  0.000000
# Af2             0.000000  0.000000  0.000000  0.0  0.000000  0.000000
# Af3             0.000000  0.000000  0.000000  0.0  0.000000  0.000000
# Ai0             0.068027  0.000000  0.006803  0.0  0.047619  0.000000
# Ai1             0.084906  0.000000  0.000000  0.0  0.047170  0.000000
# Ai2             0.058182  0.000000  0.021818  0.0  0.076364  0.000000
# Ai3             0.082278  0.000000  0.031646  0.0  0.056962  0.000000
# Ar0             0.089800  0.000000  0.011086  0.0  0.059867  0.000000
# Bf0             0.000000  0.000000  0.000000  0.0  0.000000  0.137255
# Bf1             0.000000  0.000000  0.000000  0.0  0.000000  0.747475
# Bf2             0.000000  0.000000  0.000000  0.0  0.000000  0.600000
# Bf3             0.000000  0.000000  0.000000  0.0  0.000000  1.000000
# Bi0             0.000000  0.000000  0.000000  0.0  0.045161  0.000000
# Bi1             0.000000  0.000000  0.000000  0.0  0.009259  0.000000
# Bi2             0.000000  0.000000  0.000000  0.0  0.023256  0.000000
# Bi3             0.000000  0.000000  0.000000  0.0  0.017857  0.000000
# Br0             0.000000  0.000000  0.000000  0.0  0.018116  0.000000
#
# Ending_State         Ai2       Ai3       Ar0       Bf0       Bf1       Bf2  \
# Starting_State
# Af0             0.000000  0.000000  0.006061  0.000000  0.000000  0.000000
# Af1             0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# Af2             0.000000  0.000000  0.045455  0.000000  0.000000  0.000000
# Af3             0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# Ai0             0.000000  0.000000  0.340136  0.000000  0.000000  0.000000
# Ai1             0.000000  0.000000  0.094340  0.000000  0.000000  0.000000
# Ai2             0.000000  0.000000  0.120000  0.000000  0.000000  0.000000
# Ai3             0.000000  0.000000  0.088608  0.000000  0.000000  0.000000
# Ar0             0.000000  0.000000  0.098670  0.000000  0.000000  0.000000
# Bf0             0.000000  0.000000  0.071895  0.176471  0.614379  0.000000
# Bf1             0.000000  0.000000  0.181818  0.010101  0.060606  0.000000
# Bf2             0.000000  0.000000  0.400000  0.000000  0.000000  0.000000
# Bf3             0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# Bi0             0.116129  0.064516  0.445161  0.038710  0.000000  0.012903
# Bi1             0.138889  0.101852  0.481481  0.074074  0.000000  0.018519
# Bi2             0.183140  0.090116  0.427326  0.058140  0.000000  0.020349
# Bi3             0.148810  0.172619  0.375000  0.059524  0.000000  0.005952
# Br0             0.184783  0.094203  0.421498  0.099034  0.000000  0.010870
#
# Ending_State         Bf3       Bi0       Bi1       Bi2       Bi3       Br0
# Starting_State
# Af0             0.000000  0.006061  0.151515  0.000000  0.000000  0.090909
# Af1             0.000000  0.000000  0.768421  0.000000  0.000000  0.189474
# Af2             0.000000  0.000000  0.636364  0.000000  0.000000  0.318182
# Af3             0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# Ai0             0.000000  0.027211  0.000000  0.149660  0.108844  0.251701
# Ai1             0.000000  0.009434  0.000000  0.188679  0.122642  0.452830
# Ai2             0.000000  0.010909  0.000000  0.214545  0.109091  0.389091
# Ai3             0.000000  0.012658  0.000000  0.202532  0.082278  0.443038
# Ar0             0.000000  0.012195  0.000000  0.231707  0.107539  0.389135
# Bf0             0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# Bf1             0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# Bf2             0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# Bf3             0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# Bi0             0.000000  0.045161  0.000000  0.000000  0.000000  0.232258
# Bi1             0.000000  0.092593  0.000000  0.000000  0.000000  0.083333
# Bi2             0.000000  0.081395  0.000000  0.000000  0.000000  0.116279
# Bi3             0.000000  0.077381  0.000000  0.000000  0.000000  0.142857
# Br0             0.002415  0.068841  0.000000  0.000000  0.000000  0.100242

# %%
dep_data = data[data['filename'].str.contains('DePaul')].copy().reset_index(drop=True)

# %%
len(dep_data['filename'].unique())
# Out:
# 18

# %%
for fname in dep_data['filename'].unique():
    if fname.find('DePaul')<fname.find('vs'):
        dep_data.loc[dep_data['filename']==fname, 'Transition'] = dep_data.loc[dep_data['filename']==fname, 'Transition'].str.replace('A','TEMP')
        dep_data.loc[dep_data['filename']==fname, 'Transition'] = dep_data.loc[dep_data['filename']==fname, 'Transition'].str.replace('B','A')
        dep_data.loc[dep_data['filename']==fname, 'Transition'] = dep_data.loc[dep_data['filename']==fname, 'Transition'].str.replace('TEMP','B')

# %%
#now clean transition column
dep_data['Transition']=clean_transition_column(dep_data['Transition'])

# %%
transitions_agg_dep = dep_data.groupby('Transition')['Period'].count().reset_index()

# %%
for t in possible_transitions:
    if t not in list(transitions_agg_dep['Transition'].values):
        curr_row = pd.DataFrame([[t, 0]], columns=['Transition','Period'])
        transitions_agg_dep=pd.concat([transitions_agg_dep,curr_row])

# %%
transitions_agg_dep = transitions_agg_dep.rename(columns={'Period':'Count'})

# %%
transitions_agg_dep['Starting_State'] = [x[0] for x in transitions_agg_dep['Transition']]
transitions_agg_dep['Ending_State'] = [x[1] for x in transitions_agg_dep['Transition']]

# %%
transitions_agg_dep=transitions_agg_dep[['Starting_State','Ending_State','Count']]

# %%
transition_matrix_dep = transitions_agg_dep.pivot(index='Starting_State', columns='Ending_State', values='Count').fillna(0)

# %%
transition_matrix_dep = transition_matrix_dep.div(transition_matrix_dep.sum(axis=1), axis=0)

# %%
transition_matrix_dep=transition_matrix_dep.fillna(0)

# %%
transition_matrix_dep
# Out:
# Ending_State         Af0       Af1       Af2      Af3       Ai0       Ai1  \
# Starting_State
# Af0             0.180851  0.601064  0.000000  0.00000  0.000000  0.000000
# Af1             0.008547  0.034188  0.000000  0.00000  0.000000  0.000000
# Af2             0.000000  0.000000  0.000000  0.00000  0.000000  0.000000
# Af3             0.000000  0.000000  0.000000  0.00000  0.000000  0.000000
# Ai0             0.065041  0.000000  0.024390  0.00000  0.065041  0.000000
# Ai1             0.084746  0.000000  0.000000  0.00000  0.016949  0.000000
# Ai2             0.066421  0.000000  0.025830  0.00369  0.055351  0.000000
# Ai3             0.126214  0.000000  0.029126  0.00000  0.029126  0.000000
# Ar0             0.118451  0.000000  0.013667  0.00000  0.056948  0.000000
# Bf0             0.000000  0.000000  0.000000  0.00000  0.000000  0.128866
# Bf1             0.000000  0.000000  0.000000  0.00000  0.000000  0.747664
# Bf2             0.000000  0.000000  0.000000  0.00000  0.000000  0.761905
# Bf3             0.000000  0.000000  0.000000  0.00000  0.000000  0.000000
# Bi0             0.000000  0.000000  0.000000  0.00000  0.027972  0.000000
# Bi1             0.000000  0.000000  0.000000  0.00000  0.000000  0.000000
# Bi2             0.000000  0.000000  0.000000  0.00000  0.021084  0.000000
# Bi3             0.000000  0.000000  0.000000  0.00000  0.035088  0.000000
# Br0             0.000000  0.000000  0.000000  0.00000  0.014903  0.000000
#
# Ending_State         Ai2       Ai3       Ar0       Bf0       Bf1       Bf2  \
# Starting_State
# Af0             0.000000  0.000000  0.031915  0.000000  0.000000  0.000000
# Af1             0.000000  0.000000  0.042735  0.000000  0.000000  0.000000
# Af2             0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# Af3             0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# Ai0             0.000000  0.000000  0.325203  0.000000  0.000000  0.000000
# Ai1             0.000000  0.000000  0.161017  0.000000  0.000000  0.000000
# Ai2             0.000000  0.000000  0.088561  0.000000  0.000000  0.000000
# Ai3             0.000000  0.000000  0.126214  0.000000  0.000000  0.000000
# Ar0             0.000000  0.000000  0.123007  0.000000  0.000000  0.000000
# Bf0             0.000000  0.000000  0.123711  0.201031  0.546392  0.000000
# Bf1             0.000000  0.000000  0.224299  0.009346  0.018692  0.000000
# Bf2             0.000000  0.000000  0.142857  0.000000  0.000000  0.000000
# Bf3             0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# Bi0             0.195804  0.062937  0.391608  0.048951  0.000000  0.013986
# Bi1             0.279070  0.023256  0.387597  0.093023  0.000000  0.023256
# Bi2             0.147590  0.054217  0.478916  0.135542  0.000000  0.015060
# Bi3             0.169591  0.076023  0.497076  0.087719  0.000000  0.005848
# Br0             0.189270  0.090909  0.408346  0.110283  0.000000  0.016393
#
# Ending_State    Bf3       Bi0       Bi1       Bi2       Bi3       Br0
# Starting_State
# Af0             0.0  0.000000  0.132979  0.000000  0.000000  0.053191
# Af1             0.0  0.000000  0.760684  0.000000  0.000000  0.153846
# Af2             0.0  0.000000  0.833333  0.000000  0.000000  0.166667
# Af3             0.0  0.000000  1.000000  0.000000  0.000000  0.000000
# Ai0             0.0  0.040650  0.000000  0.154472  0.089431  0.235772
# Ai1             0.0  0.016949  0.000000  0.194915  0.135593  0.389831
# Ai2             0.0  0.014760  0.000000  0.206642  0.136531  0.402214
# Ai3             0.0  0.009709  0.000000  0.145631  0.135922  0.398058
# Ar0             0.0  0.011390  0.000000  0.248292  0.107062  0.321185
# Bf0             0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# Bf1             0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# Bf2             0.0  0.000000  0.000000  0.000000  0.000000  0.095238
# Bf3             0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# Bi0             0.0  0.048951  0.000000  0.000000  0.000000  0.209790
# Bi1             0.0  0.085271  0.000000  0.000000  0.000000  0.108527
# Bi2             0.0  0.048193  0.000000  0.000000  0.000000  0.099398
# Bi3             0.0  0.076023  0.000000  0.000000  0.000000  0.052632
# Br0             0.0  0.086438  0.000000  0.000000  0.000000  0.083458

# %%
#first, try combining them by discrete "beneficial" columns then re-normalize
marq_sub_matrix = transition_matrix_marq[['Af0', 'Af1', 'Af2', 'Af3', 'Ai0', 'Ar0', 'Bi1', 'Bi2', 'Bi3']].copy()
dep_sub_matrix = transition_matrix_dep[['Bf0', 'Bf1', 'Bf2', 'Bf3', 'Bi0', 'Br0', 'Ai1', 'Ai2', 'Ai3']].copy()

combined_transitions_1 = pd.concat([marq_sub_matrix,dep_sub_matrix], axis=1)

# %%
combined_transitions_1 = combined_transitions_1.div(combined_transitions_1.sum(axis=1), axis=0)

# %%
combined_transitions_1.to_excel('Marquette_A_DePaul_B_Transitions_v1.xlsx')

# %%
combined_transitions_2 = (transition_matrix_marq + transition_matrix_dep)/2

# %%
combined_transitions_2 = combined_transitions_2.div(combined_transitions_2.sum(axis=1), axis=0)

# %%
combined_transitions_2.to_excel('Marquette_A_DePaul_B_Transitions_v2.xlsx')

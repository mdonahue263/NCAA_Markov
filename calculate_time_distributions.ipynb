# %%
from helper_functions.clean_transitions import clean_transition_column
import pandas as pd
from itertools import product
from matplotlib import pyplot as plt

# %%
transition_times = pd.read_excel('All_Transition_With_Times_Not_Aggregated.xlsx')
# c1=transition_times.copy()

# %%
transition_times['Transition'] = clean_transition_column(transition_times['Transition'])

# %%
valid_transitions = pd.read_excel('ALL_VALID_TRANSITIONS.xlsx')

# %%
valid_transitions['Transition']=clean_transition_column(valid_transitions['Transition'])

# %%
unique_valid_trans = valid_transitions['Transition'].unique()

# %%
#we have a list of all valid transitions. Going to get a list of all transitions including invalid ones just so we can assign 0 score to invalid ones (since they happen in real games)
possible_states = ['Ai0',
'Ai1',
'Ai2',
'Ai3',
'Ar0',
'Af0',
'Af1',
'Af2',
'Af3',
'Bi0',
'Bi1',
'Bi2',
'Bi3',
'Br0',
'Bf0',
'Bf1',
'Bf2',
'Bf3']

possible_transitions = list(product(possible_states,possible_states))

# %%
#some basic ground rules - any F to F transition should be 0 seconds
unique_trans = transition_times['Transition'].unique()
for t in unique_trans:
    if (('f' in t[0]) & ('f' in t[1]))|(t not in list(unique_valid_trans)):
        transition_times.loc[transition_times['Transition'] == t, 'Time'] = 0

# %%
transition_times
# Out:
#         Transition  Time
# 0       (Bi0, Ai3)    24
# 1       (Ai3, Ar0)    32
# 2       (Ar0, Ar0)    22
# 3       (Ar0, Br0)     0
# 4       (Br0, Ar0)    26
# ...            ...   ...
# 764695  (Bi3, Ar0)    16
# 764696  (Ar0, Af0)     2
# 764697  (Af0, Af1)     0
# 764698  (Af1, Bi1)     0
# 764699  (Bi1, Ar0)     8
#
# [764700 rows x 2 columns]

# %%
#find interquartile range of each transition's time durations
quartiles = transition_times.groupby('Transition')['Time'].quantile([0.25, 0.75]).unstack()

# %%
#merge original DF with interquartile range df to filter
df_merged = pd.merge(transition_times, quartiles, left_on='Transition', right_index=True, suffixes=('', '_quartile'))

filtered_df = df_merged[(df_merged['Time'] >= df_merged[0.25]) & (df_merged['Time'] <= df_merged[0.75])]

# %%
smaller_ranged_times = filtered_df[['Transition','Time']].copy()

# %%
group_aggs = smaller_ranged_times.groupby('Transition').agg(['mean','std','count']).reset_index()

# %%
pd.DataFrame(group_aggs.values, columns = ['Transition', 'Avg_Time','std','count'])
# Out:
#      Transition   Avg_Time       std  count
# 0    (Af0, Af0)        0.0       0.0   8151
# 1    (Af0, Af1)        0.0       0.0  23206
# 2    (Af0, Af2)        0.0       0.0      4
# 3    (Af0, Af3)        0.0       NaN      1
# 4    (Af0, Ai0)        0.0       0.0     37
# ..          ...        ...       ...    ...
# 274  (Br0, Bi0)   2.516716  3.209838   8405
# 275  (Br0, Bi1)        0.0       0.0      9
# 276  (Br0, Bi2)        0.0       0.0    277
# 277  (Br0, Bi3)        0.0       0.0    118
# 278  (Br0, Br0)  12.691328  3.992033  10597
#
# [279 rows x 4 columns]

# %%
#we have reduced dataframe for times but we want to use original for probabilities/frequencies.
#this is incomplete as in not all possible state combinations are represented, but that should be fine since only VALID transitions should be called

smaller_ranged_times.to_excel('Transition_times_reduced.xlsx',index=False)
# Out:
# C:\Users\mdona\AppData\Local\Temp/ipykernel_19424/2998021345.py:3: UserWarning: Pandas requires version '3.0.3' or newer of 'xlsxwriter' (version '3.0.1' currently installed).
#   smaller_ranged_times.to_excel('Transition_times_reduced.xlsx',index=False)

# %%
transitions_agg = valid_transitions.groupby('Transition')['Period'].count().reset_index()

# %%
for t in possible_transitions:
    if t not in list(transitions_agg['Transition'].values):
        curr_row = pd.DataFrame([[t, 0]], columns=['Transition','Period'])
        transitions_agg=pd.concat([transitions_agg,curr_row])

# %%
transitions_agg = transitions_agg.rename(columns={'Period':'Count'})

# %%
transitions_agg['Starting_State'] = [x[0] for x in transitions_agg['Transition']]
transitions_agg['Ending_State'] = [x[1] for x in transitions_agg['Transition']]

# %%
transitions_agg
# Out:
#     Transition  Count Starting_State Ending_State
# 0   (Af0, Af0)   8149            Af0          Af0
# 1   (Af0, Af1)  23206            Af0          Af1
# 2   (Af0, Ar0)    748            Af0          Ar0
# 3   (Af0, Bi0)     13            Af0          Bi0
# 4   (Af0, Bi1)   6022            Af0          Bi1
# ..         ...    ...            ...          ...
# 0   (Bf3, Bi3)      0            Bf3          Bi3
# 0   (Bf3, Bf0)      0            Bf3          Bf0
# 0   (Bf3, Bf1)      0            Bf3          Bf1
# 0   (Bf3, Bf2)      0            Bf3          Bf2
# 0   (Bf3, Bf3)      0            Bf3          Bf3
#
# [324 rows x 4 columns]

# %%
transition_counts = transitions_agg.groupby(['Starting_State', 'Ending_State'])['Count'].sum().reset_index()

# %%
transition_matrix = transition_counts.pivot(index='Starting_State', columns='Ending_State', values='Count').fillna(0)

# %%
transition_matrix
# Out:
# Ending_State      Af0    Af1   Af2  Af3    Ai0    Ai1    Ai2    Ai3    Ar0  \
# Starting_State
# Af0              8149  23206     0    0      0      0      0      0    748
# Af1               245    677     0    0      0      0      0      0    849
# Af2                 0      0     0    0      0      0      0      0    356
# Af3                 0      0     0    0      0      0      0      0     27
# Ai0              1933      0   384   28   1713      0      0      0   7558
# Ai1              2778      0   503   25   1254      0      0      0   3235
# Ai2              5771      0  1135   61   3454      0      0      0   6863
# Ai3              2552      0   445   36   1532      0      0      0   2926
# Ar0             19820      0  3847  170  11833      0      0      0  21887
# Bf0                 0      0     0    0     16   5257      0      0   3536
# Bf1                 0      0     0    0      6  15087      0      0   4114
# Bf2                 0      0     0    0     14   3622      0      0   1500
# Bf3                 0      0     0    0      4    149      0      0     65
# Bi0                 0      0     0    0    592      0   4506   1933  10897
# Bi1                 0      0     0    0    539      0   4662   2171  11564
# Bi2                 0      0     0    0   1183      0  10778   5520  27553
# Bi3                 0      0     0    0    531      0   4789   2379  11972
# Br0                 0      0     0    0   2726      0  32987  12896  62180
#
# Ending_State      Bf0    Bf1   Bf2  Bf3    Bi0    Bi1    Bi2    Bi3    Br0
# Starting_State
# Af0                 0      0     0    0     13   6022      0      0   3656
# Af1                 0      0     0    0      5  18117      0      0   4425
# Af2                 0      0     0    0     13   4158      0      0   1641
# Af3                 0      0     0    0      3    188      0      0     60
# Ai0                 0      0     0    0    597      0   4767   2119   9764
# Ai1                 0      0     0    0    448      0   4178   1941   8977
# Ai2                 0      0     0    0   1056      0  10786   5700  22918
# Ai3                 0      0     0    0    457      0   4696   2411   9891
# Ar0                 0      0     0    0   2975      0  38294  15242  60824
# Bf0              7356  19837     0    0      0      0      0      0    517
# Bf1               181    630     0    0      0      0      0      0    587
# Bf2                 0      0     0    0      0      0      0      0    268
# Bf3                 0      0     0    0      0      0      0      0     23
# Bi0              1766      0   319   27   1811      0      0      0   7043
# Bi1              2741      0   540   55   1498      0      0      0   3626
# Bi2              5414      0  1051   61   3816      0      0      0   7049
# Bi3              2417      0   425   27   1803      0      0      0   2983
# Br0             16345      0  3247  137  11120      0      0      0  18677

# %%
transition_matrix = transition_matrix.div(transition_matrix.sum(axis=1), axis=0)

# %%
transition_matrix.to_excel('first_transition_matrix.xlsx')
# Out:
# C:\Users\mdona\AppData\Local\Temp/ipykernel_19424/763296221.py:1: UserWarning: Pandas requires version '3.0.3' or newer of 'xlsxwriter' (version '3.0.1' currently installed).
#   transition_matrix.to_excel('first_transition_matrix.xlsx')

# %%
transition_matrix
# Out:
# Ending_State         Af0       Af1       Af2       Af3       Ai0       Ai1  \
# Starting_State
# Af0             0.194980  0.555247  0.000000  0.000000  0.000000  0.000000
# Af1             0.010075  0.027839  0.000000  0.000000  0.000000  0.000000
# Af2             0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# Af3             0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# Ai0             0.066972  0.000000  0.013304  0.000970  0.059349  0.000000
# Ai1             0.119028  0.000000  0.021552  0.001071  0.053730  0.000000
# Ai2             0.099941  0.000000  0.019656  0.001056  0.059816  0.000000
# Ai3             0.102301  0.000000  0.017839  0.001443  0.061413  0.000000
# Ar0             0.113327  0.000000  0.021996  0.000972  0.067659  0.000000
# Bf0             0.000000  0.000000  0.000000  0.000000  0.000438  0.143952
# Bf1             0.000000  0.000000  0.000000  0.000000  0.000291  0.732201
# Bf2             0.000000  0.000000  0.000000  0.000000  0.002591  0.670244
# Bf3             0.000000  0.000000  0.000000  0.000000  0.016598  0.618257
# Bi0             0.000000  0.000000  0.000000  0.000000  0.020489  0.000000
# Bi1             0.000000  0.000000  0.000000  0.000000  0.019674  0.000000
# Bi2             0.000000  0.000000  0.000000  0.000000  0.018951  0.000000
# Bi3             0.000000  0.000000  0.000000  0.000000  0.019432  0.000000
# Br0             0.000000  0.000000  0.000000  0.000000  0.017004  0.000000
#
# Ending_State         Ai2       Ai3       Ar0       Bf0       Bf1       Bf2  \
# Starting_State
# Af0             0.000000  0.000000  0.017897  0.000000  0.000000  0.000000
# Af1             0.000000  0.000000  0.034912  0.000000  0.000000  0.000000
# Af2             0.000000  0.000000  0.057717  0.000000  0.000000  0.000000
# Af3             0.000000  0.000000  0.097122  0.000000  0.000000  0.000000
# Ai0             0.000000  0.000000  0.261858  0.000000  0.000000  0.000000
# Ai1             0.000000  0.000000  0.138609  0.000000  0.000000  0.000000
# Ai2             0.000000  0.000000  0.118852  0.000000  0.000000  0.000000
# Ai3             0.000000  0.000000  0.117293  0.000000  0.000000  0.000000
# Ar0             0.000000  0.000000  0.125146  0.000000  0.000000  0.000000
# Bf0             0.000000  0.000000  0.096826  0.201429  0.543197  0.000000
# Bf1             0.000000  0.000000  0.199660  0.008784  0.030575  0.000000
# Bf2             0.000000  0.000000  0.277572  0.000000  0.000000  0.000000
# Bf3             0.000000  0.000000  0.269710  0.000000  0.000000  0.000000
# Bi0             0.155949  0.066900  0.377137  0.061120  0.000000  0.011040
# Bi1             0.170171  0.079245  0.422105  0.100051  0.000000  0.019711
# Bi2             0.172655  0.088426  0.441378  0.086728  0.000000  0.016836
# Bi3             0.175254  0.087060  0.438118  0.088451  0.000000  0.015553
# Br0             0.205764  0.080442  0.387861  0.101956  0.000000  0.020254
#
# Ending_State         Bf3       Bi0       Bi1       Bi2       Bi3       Br0
# Starting_State
# Af0             0.000000  0.000311  0.144088  0.000000  0.000000  0.087477
# Af1             0.000000  0.000206  0.745004  0.000000  0.000000  0.181964
# Af2             0.000000  0.002108  0.674125  0.000000  0.000000  0.266051
# Af3             0.000000  0.010791  0.676259  0.000000  0.000000  0.215827
# Ai0             0.000000  0.020684  0.000000  0.165160  0.073416  0.338288
# Ai1             0.000000  0.019195  0.000000  0.179014  0.083166  0.384635
# Ai2             0.000000  0.018288  0.000000  0.186790  0.098712  0.396890
# Ai3             0.000000  0.018320  0.000000  0.188247  0.096649  0.396496
# Ar0             0.000000  0.017010  0.000000  0.218958  0.087151  0.347780
# Bf0             0.000000  0.000000  0.000000  0.000000  0.000000  0.014157
# Bf1             0.000000  0.000000  0.000000  0.000000  0.000000  0.028488
# Bf2             0.000000  0.000000  0.000000  0.000000  0.000000  0.049593
# Bf3             0.000000  0.000000  0.000000  0.000000  0.000000  0.095436
# Bi0             0.000934  0.062677  0.000000  0.000000  0.000000  0.243753
# Bi1             0.002008  0.054680  0.000000  0.000000  0.000000  0.132355
# Bi2             0.000977  0.061129  0.000000  0.000000  0.000000  0.112920
# Bi3             0.000988  0.065981  0.000000  0.000000  0.000000  0.109163
# Br0             0.000855  0.069363  0.000000  0.000000  0.000000  0.116502
